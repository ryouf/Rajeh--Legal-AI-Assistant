# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-huggingface ragas datasets evaluate
# !pip install langchain==0.2.12 langchain-core==0.2.24 langchain-community==0.2.11 langchain-huggingface==0.0.6
# !pip install ragas==0.1.8 datasets==2.20.0 evaluate==0.4.3
# Out:
# Found existing installation: langchain 1.0.5
# Uninstalling langchain-1.0.5:
#   Successfully uninstalled langchain-1.0.5
# Found existing installation: langchain-core 1.0.4
# Uninstalling langchain-core-1.0.4:
#   Successfully uninstalled langchain-core-1.0.4
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# WARNING: Skipping langchain-huggingface as it is not installed.
# Found existing installation: ragas 0.1.8
# Uninstalling ragas-0.1.8:
#   Successfully uninstalled ragas-0.1.8
# Found existing installation: datasets 2.20.0
# Uninstalling datasets-2.20.0:
#   Successfully uninstalled datasets-2.20.0
# Found existing installation: evaluate 0.4.3
# Uninstalling evaluate-0.4.3:
#   Successfully uninstalled evaluate-0.4.3
# ...
#   Using cached langchain-0.2.12-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_core-0.2.24-py3-none-any.whl.metadata (6.2 kB)
# ...

# %%
import os
import requests
from bs4 import BeautifulSoup
import tempfile
from pathlib import Path
import re
import json
import pandas as pd
import random
import numpy as np
import pandas as pd
import torch

# %%
# !pip install docling

# %%
from docling.document_converter import DocumentConverter
from pathlib import Path

urls = [
    "https://laws.boe.gov.sa/BoeLaws/Laws/Print?Query=+&MatchSearchResult=false&TitlesOnly=true&TitlesOnly=false&LanguageId=1&FolderId=01f9d880-bccf-4350-a1b8-1f362fae4c46&PartId=&LawStatusId=3&SearchTypeId=&IssueDateFrom=&IssueDateTo=",
    "https://laws.boe.gov.sa/BoeLaws/Laws/Print?Query=+&MatchSearchResult=false&TitlesOnly=true&TitlesOnly=false&LanguageId=1&FolderId=ee88ea93-e592-47e4-ac2d-8f678a6d58a6&PartId=&LawStatusId=3&SearchTypeId=&IssueDateFrom=&IssueDateTo=",
    "https://laws.boe.gov.sa/BoeLaws/Laws/Print?Query=+&MatchSearchResult=true&MatchSearchResult=false&TitlesOnly=true&TitlesOnly=false&LanguageId=1&FolderId=30f6850d-7ca1-4e32-8aa7-6c04254c5619&PartId=&LawStatusId=3&SearchTypeId=&IssueDateFrom=&IssueDateTo=",
    "https://laws.boe.gov.sa/BoeLaws/Laws/Print?Query=+&MatchSearchResult=true&MatchSearchResult=false&TitlesOnly=true&TitlesOnly=false&LanguageId=1&FolderId=6a5cbe13-0baa-4700-8bf9-a2c0e94cfe6e&PartId=&LawStatusId=3&SearchTypeId=&IssueDateFrom=&IssueDateTo="
]

converter = DocumentConverter()
all_markdown = ""

for i, url in enumerate(urls, start=1):
    print(f" Processing link number{i} ...")
    resp = requests.get(url, verify=False, timeout=30)
    resp.raise_for_status()

    # Save a temporary file for each page
    tmp_dir = Path(tempfile.gettempdir())
    tmp_file = tmp_dir / f"law_page_{i}.html"
    tmp_file.write_text(resp.text, encoding="utf-8")

    # Convert the downloaded file to Markdown
    result = converter.convert(str(tmp_file))
    document = result.document
    markdown_output = document.export_to_markdown()

    # Add a separator between each document
    all_markdown += f"\n\n---\n\n### Document number{i}\n\n" + markdown_output

# Save the complete combined result into one file
output_file = Path("Saudi_law1_combined.md")
output_file.write_text(all_markdown, encoding="utf-8")

print(f"\n✅ All files have been saved together in one file:{output_file.resolve()}")
# Out:
#  Processing link number1 ...
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'laws.boe.gov.sa'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  Processing link number2 ...
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'laws.boe.gov.sa'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  Processing link number3 ...
# ...

# %%
# Split all the content returned from export_to_markdown() into lines
lines = all_markdown.splitlines()

titles = []  # All section titles
content_sections = []

for line in lines:
    line = line.strip()
    if line.startswith("## ") and not line.startswith("###"):  # Main section title
        titles.append(line.replace("## ", ""))
    elif line.startswith("### "):  # Subsection title
        content_sections.append(line.replace("### ", ""))

# Print all section titles found
print("📘 New section titles:")
for title in titles:
    print("- " + title)

print("\n📑 Subsection titles:")
for section in content_sections:
    print("-", section)
# Out:
# 📘 New section titles:
# - نظام هيئة البيعة
# - نظام مجلس الوزراء
# - النظام الأساسي للحكم
# - نظام مجلس الشورى
# - نظام المناطق
# - تنظيم المركز الوطني لسلامة النقل
# - تنظيم الهيئة السعودية لتسويق الاستثمار
# - نظام الطوارئ
# - تنظيم الهيئة الوطنية لإدارة الطوارئ
# - نظام المواد البترولية والبتروكيماوية
# - النظام الأساس لمستشفى الملك خالد التخصصي للعيون ومركز الأبحاث (مؤسسة مستقلة ذات طبيعة خاصة وغير هادفة للربح)
# - نظام ضريبة التصرفات العقارية
# - نظام السجل التجاري
# - نظام الأسماء التجارية
# - نظام القياس والمعايرة
# - نظام جمع التبرعات
# - نظام الاستثمار
# - نظام المواصفات والجودة
# - نظام سلامة المنتجات
# - نظام هيئة الرقابة ومكافحة الفساد
# - نظام التأمينات الاجتماعية
# - نظام الخطوط الحديدية
# - نظام حماية المبلغين والشهود والخبراء والضحايا
# - نظام صندوق البنية التحتية الوطني
# - نظام بيع وتأجير مشروعات عقارية على الخارطة
# - نظام صندوق التنمية الزراعية.
# - نظام حقوق الأشخاص ذوي الإعاقة
# - نظام استخدام وحماية شارة واسم الهلال الأحمر وما في حكمهما
# ...

# %%
lines = all_markdown.splitlines()

system_sections = {}  # Final result: {System Title: [List of Articles]}
current_title = None

for line in lines:
    line = line.strip()

    if line.startswith("## ") and not line.startswith("###"):  # System title
        current_title = line.replace("## ", "")
        system_sections[current_title] = []  # Start a new list for this system
    elif line.startswith("### ") and current_title:  # Article title under the current system
        material_title = line.replace("### ", "")
        system_sections[current_title].append(material_title)

# Print the final result
import json
print(json.dumps(system_sections, ensure_ascii=False, indent=2))
# Out:
# {
#   "نظام هيئة البيعة": [
#     "المادة الخامسة",
#     "المادة العاشرة",
#     "المادة الثانية عشرة",
#     "المادة الرابعة",
#     "المادة الثامنة",
#     "المادة الأولى",
#     "المادة السادسة",
#     "المادة الثانية",
#     "المادة الحادية عشرة",
#     "المادة السابعة",
#     "المادة التاسعة",
#     "المادة الثالثة",
#     "المادة الخامسة عشرة",
#     "المادة السابعة عشرة",
#     "المادة الثالثة والعشرون",
#     "المادة الثالثة عشرة",
#     "المادة العشرون",
#     "المادة الثانية والعشرون",
#     "المادة الرابعة عشرة",
#     "المادة التاسعة عشرة",
#     "المادة السادسة عشرة",
#     "المادة الرابعة والعشرون",
#     "المادة الحادية والعشرون",
#     "المادة الخامسة والعشرون",
#     "المادة الثامنة عشرة"
#   ],
#   "نظام مجلس الوزراء": [
#     "المادة (9)",
#     "المادة (15)",
#     "المادة (3)",
#     "المادة (20)",
#     "المادة (22)",
#     "المادة (27)",
#     "المادة (24)",
#     "المادة (23)",
#     "المادة (10)",
#     "المادة (11)",
#     "المادة (16)",
# ...

# %%
from langchain_core.documents import Document

def preprocess_text_arabic(text):
    """
    تنظيف النصوص العربية بشكل شامل:
    - إزالة التشكيل
    - توحيد الحروف
    - إزالة الرموز الغريبة
    - إزالة الفراغات المكررة
    """
    if not text:
        return ""

    text = text.strip()

    text = re.sub(r'[ًٌٍَُِّْـ]', '', text)


    text = re.sub(r'[أإآٱ]', 'ا', text)  # أ إ آ ٱ → ا
    text = text.replace("ى", "ي")
    text = text.replace("ة", "ه")


    text = re.sub(r'[^\u0600-\u06FF0-9\s.,؛:؟-]', '', text)


    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# %%
import re
from langchain_core.documents import Document

documents = []
current_system = None
current_material = None
current_content = []

for line in all_markdown.splitlines():
    line = line.strip()
    if not line:
        continue


    if line.startswith("## ") and not line.startswith("### "):
        if current_system and current_material and current_content:
            clean_text = preprocess_text_arabic("\n".join(current_content))
            documents.append(Document(
                page_content=clean_text,
                metadata={
                    "النظام": current_system,
                    "المادة": current_material
                }
            ))
            current_content = []

        current_system = line.replace("#", "").strip()
        current_material = None
        continue


    if line.startswith("###") or line.startswith(" ### "):
        if current_system and current_material and current_content:
            clean_text = preprocess_text_arabic("\n".join(current_content))
            documents.append(Document(
                page_content=clean_text,
                metadata={
                    "النظام": current_system,
                    "المادة": current_material
                }
            ))
            current_content = []

        current_material = line.replace("#", "").strip()
        continue


    current_content.append(line)


if current_system and current_material and current_content:
    clean_text = preprocess_text_arabic("\n".join(current_content))
    documents.append(Document(
        page_content=clean_text,
        metadata={
            "النظام": current_system,
            "المادة": current_material
        }
    ))

print(f"✅ تم استخراج {len(documents)} مادة من {len(set(d.metadata['النظام'] for d in documents))} نظام.\n")


print("🔹 أمثلة من أول 3 مواد بعد التنظيف:\n")
for i, doc in enumerate(documents[:3]):
    print(f"📘 النظام: {doc.metadata['النظام']}")
    print(f"📄 المادة: {doc.metadata['المادة']}")
    print(f"🧹 النص بعد التنظيف:\n{doc.page_content[:300]}...\n{'-'*60}\n")
# Out:
# ✅ تم استخراج 17325 مادة من 469 نظام.
#
# 🔹 أمثلة من أول 3 مواد بعد التنظيف:
#
# 📘 النظام: نظام هيئة البيعة
# 📄 المادة: المادة الخامسة
# 🧹 النص بعد التنظيف:
# --- - نتائج البحث -- -- -- -- -- -- -- -- طباعه النتائج يتضمن النظام مايلي : تكوين هيئه تسمي هيئه البيعه بموجب امر ملكي - مهام الهيئه - مقرها - قسم رئيس واعضاء الهيئه قبل ان يباشروا اعمالهم - رئاسه اداره اجتماعات الهيئه ومناقشاتها والتصويت علي قراراتها. تاريخ الاصدار: 14270101 ه تاريخ النشر: 1427010...
# ------------------------------------------------------------
#
# 📘 النظام: نظام هيئة البيعة
# 📄 المادة: المادة العاشرة
# 🧹 النص بعد التنظيف:
# تشكل الهيئه مجلسا مؤقتا للحكم من خمسه من اعضائها، ويتولي المجلس اداره شؤون الدوله، بصفه مؤقته في الحالات المنصوص عليها في هذا النظام. وفي كل الاحوال ليس لهذا المجلس اي صلاحيه لتعديل النظام الاساسي للحكم، او هذا النظام، او نظام مجلس الوزراء ، او نظام مجلس الشوري ، او نظام المناطق ، او نظام مجلس الامن...
# ------------------------------------------------------------
#
# ...

# %%
from collections import defaultdict
import json


duplicates = defaultdict(list)

for doc in documents:
    system = doc.metadata.get("النظام", "غير معروف")
    material = doc.metadata.get("المادة", "غير معروفة")
    key = (system, material)
    duplicates[key].append(doc.page_content.strip())


repeated_docs = {k: v for k, v in duplicates.items() if len(v) > 1}


merged_repeats = []
for (system, material), texts in repeated_docs.items():
    merged_text = "\n---\n".join(texts)
    merged_repeats.append({
        "النظام": system,
        "المادة": material,
        "النص_المدمج": merged_text
    })


if merged_repeats:
    print("✅ تم دمج النصوص المكرّرة فقط:\n")
    for item in merged_repeats:
        print(f"📘 النظام: {item['النظام']} | المادة: {item['المادة']}")
        print(item["النص_المدمج"][:200], "...\n")  # نعرض أول 200 حرف فقط
else:
    print("🌟 لا توجد مواد مكرّرة لدمجها.")


with open("merged_repeated5_docs.json", "w", encoding="utf-8") as f:
    json.dump(merged_repeats, f, ensure_ascii=False, indent=2)
# Out:
# ✅ تم دمج النصوص المكرّرة فقط:
#
# 📘 النظام: نظام مجلس الوزراء | المادة: المادة (30)
# يدخل في تشكيلات مجلس الوزراء الاداريه الاجهزه الاتيه: اولا - ديوان رئاسه مجلس الوزراء. ثانيا - الامانه العامه لمجلس الوزراء. ثالثا - هيئه الخبراء .ويبين النظام الداخلي لمجلس الوزراء تشكيلات هذه الاجهز ...
#
# 📘 النظام: النظام الأساسي للحكم | المادة: المادة الخامسة
# ا - نظام الحكم في المملكه العربيه السعوديه، ملكي.ب - يكون الحكم في ابناء الملك المؤسس عبد العزيز بن عبد الرحمن الفيصل ال سعود و ابناء الابناء، ويبايع الاصلح منهم للحكم علي كتاب الله تعالي وسنه رسوله ص ...
#
# 📘 النظام: نظام مجلس الشورى | المادة: المادة العاشرة
# يعين رئيس مجلس الشوري ، ونائبه والامين العام للمجلس، ويعفون باوامر ملكيه، وتحدد مراتبهم وحقوقهم وواجباتهم وكافه شؤونهم بامر ملكي. بالامر الملكي رقم ا181 وتاريخ 14 12 1428 ه . عدلت هذه الماده بالامر ال ...
#
# 📘 النظام: نظام مجلس الشورى | المادة: المادة السابعة عشرة
# ...

# %%
from collections import defaultdict
import json


duplicates = defaultdict(list)

for doc in documents:
    system = doc.metadata.get("النظام", "غير معروف")
    material = doc.metadata.get("المادة", "غير معروفة")
    key = (system, material)
    duplicates[key].append(doc.page_content.strip())


repeated_docs = {k: v for k, v in duplicates.items() if len(v) > 1}
unique_docs = {k: v for k, v in duplicates.items() if len(v) == 1}

merged_repeats = []


for (system, material), texts in repeated_docs.items():
    merged_text = "\n---\n".join(texts)
    merged_repeats.append({
        "النظام": system,
        "المادة": material,
        "النص": merged_text
    })


for (system, material), texts in unique_docs.items():
    merged_repeats.append({
        "النظام": system,
        "المادة": material,
        "النص": texts[0]
    })


with open("all_merged_docs.json", "w", encoding="utf-8") as f:
    json.dump(merged_repeats, f, ensure_ascii=False, indent=2)

print(f"✅ تم دمج المواد المكررة وإضافة {len(unique_docs)} مادة غير مكررة.")
print(f"📁 تم حفظ كل النتائج في ملف all_merged_docs.json")
# Out:
# ✅ تم دمج المواد المكررة وإضافة 14229 مادة غير مكررة.
# 📁 تم حفظ كل النتائج في ملف all_merged_docs.json

# %%
import re
from langchain_core.documents import Document

new2_documents = []

for item in merged_repeats:
    system = item.get("النظام", "Unknown System")
    article = item.get("المادة", "Unknown Article")
    text = item.get("النص", "")


    clean_text = re.sub(r"###\s*المادة\s*[^#: \n]+", "", text).strip()


    full_text = f"{article} من {system}: {clean_text}"

    new2_documents.append(Document(page_content=full_text, metadata={
        "النظام": system,
        "المادة": article
    }))

print(f"✅ تم إنشاء {len(new2_documents)} وثيقة بعد التنظيف.")
print(new2_documents[3].page_content)
# Out:
# ✅ تم إنشاء 15627 وثيقة بعد التنظيف.
# المادة السابعة عشرة من نظام مجلس الشورى: ترفع قرارات مجلس الشوري الي رئيس مجلس الوزراء، ويحيلها الي مجلس الوزراء للنظر فيها، فان اتفقت وجهات نظر المجلسين صدرت بعد موافقه الملك عليها، وان تباينت وجهات النظر فللملك اقرار ما يراه. بالامر الملكي رقم ا198 وتاريخ 2 10 1424 ه . عدلت هذه الماده بالامر الملكي رقم ا198 وتاريخ 2 10 1424 ه . 142903-633-4-956-8223721.
# ---
# تم تعديل هذه الماده بموجب الامر الملكي رقم ا 198 وتاريخ 2 10 1424ه ،لتصبح بالنص الاتي: ترفع قرارات مجلس الشوري الي الملك ويقرر ما يحال منها الي مجلس الوزراء .- اذا اتفقت وجهات نظر مجلسي الوزراء و الشوري تصدر القرارات بعد موافقه الملك عليها .- اذا تباينت وجهات نظر المجلسين يعاد الموضوع الي مجلس الشوري ليبدي ما يراه بشانه ويرفعه الي الملك لاتخاذ ما يراه .

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document


# Arabic-friendly: small chunks to maintain meaning
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=450,
    chunk_overlap=80,
    separators=["\n\n", "\n", " ", "،", "."]
)


chunked_documents = []

for doc in new2_documents:
    chunks = text_splitter.split_text(doc.page_content)
    for i, chunk in enumerate(chunks):
        new_doc = Document(
            page_content=chunk,
            metadata={
                "النظام": doc.metadata.get("النظام", "غير معروف"),
                "المادة": doc.metadata.get("المادة", "غير معروفة"),
                "chunk_id": i + 1
            }
        )
        chunked_documents.append(new_doc)


print(f"✅ تم إنشاء {len(chunked_documents)} أجزاء (chunks) من {len(new2_documents)} مواد.")
if len(chunked_documents) > 0:
    print("📘 مثال لأول جزء:")
    print(chunked_documents[0].metadata)
    print(chunked_documents[0].page_content[:300])
# Out:
# ✅ تم إنشاء 26543 أجزاء (chunks) من 15627 مواد.
# 📘 مثال لأول جزء:
# {'النظام': 'نظام مجلس الوزراء', 'المادة': 'المادة (30)', 'chunk_id': 1}
# المادة (30) من نظام مجلس الوزراء: يدخل في تشكيلات مجلس الوزراء الاداريه الاجهزه الاتيه: اولا - ديوان رئاسه مجلس الوزراء. ثانيا - الامانه العامه لمجلس الوزراء. ثالثا - هيئه الخبراء .ويبين النظام الداخلي لمجلس الوزراء تشكيلات هذه الاجهزه واختصاصاتها وكيفيه قيامها باعمالها.
# ---

# %%
# !pip install -U sentence-transformers
# !pip install faiss-cpu

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS


embedding_model = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large")


vectorstore = FAISS.from_documents(
    documents=new2_documents,
    embedding=embedding_model
)


vectorstore.save_local("New")

print("✅ تم إنشاء قاعدة بيانات FAISS الجديدة وحفظها بنجاح في المجلد 'New'")

# %%
from langchain_core.prompts import PromptTemplate

systems = list({d.metadata["النظام"] for d in new2_documents if "النظام" in d.metadata})
print(f"📘 تم استخراج {len(systems)} نظام:")
for s in systems:
    print("•", s)

def classify_system(question):
    global systems

    prompt_template = """
    صنّف السؤال التالي حسب النظام الأقرب من القائمة التالية:
    {systems}

    السؤال: {question}

    أجب فقط باسم النظام الأقرب بدون أي شرح إضافي.
    """
    prompt = PromptTemplate.from_template(prompt_template)
    response = llm.invoke(prompt.format(systems=", ".join(systems), question=question))
    return response.content.strip()

# %%
question = "ما هي إجراءات التصفية؟"


retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 4})
retrieved_docs = retriever.invoke(question)

retrieved_docs

# %%
context = '\n---------------------\n'.join([doc.page_content for doc in retrieved_docs])
print(context)

# %%
for doc in retrieved_docs:
    print("Metadata:", doc.metadata)
    print("Content:", doc.page_content)
    print("-----------")

# %%
for doc in retrieved_docs:
    #print("Metadata:", doc.metadata)
    print(doc.page_content)
    #print("-----------")

# %%
final_prompt = f"""


أنت مساعد قانوني متخصص في الأنظمة السعودية، وتقوم بالإجابة على أسئلة المستخدمين بناءً على السياق المقدم. أجب على السؤال التالي بطريقة شاملة وواضحة ومبسطة، دون الإخلال بالمعلومة، مع استخدام التعداد عند الحاجة لتوضيح النقاط. في نهاية الإجابة، اذكر اسم النظام ورقم المادة التي تم الاستناد إليها.

السياق:
{context}

السؤال:
{question}
"""

# %%
from openai import OpenAI

client = OpenAI(api_key=""
)

response = client.chat.completions.create(
    model="gpt-4",
    messages=[{"role": "user", "content": final_prompt}],
    temperature=0.7,
)

print(response.choices[0].message.content)

# %%
from datasets import Dataset

data = {
   "question": [
        "هل يمكن فصل العامل دون انذار؟",
        "متى يعتبر الفصل تعسفيا؟",
        "هل يحق لصاحب العمل خصم الراتب؟",
        "كم مدة الانذار قبل انهاء العقد؟",
        "ما هي حقوق العامل عند انتهاء عقده؟",
        "هل للعامل حق في اجازة سنوية مدفوعة؟",
        "ما هو الحد الاعلى لساعات العمل؟",
        "هل يمكن للعامل الاستقالة خلال فترة التجربة؟",
        "كيف يحسب تعويض المادة السابعه والسبعون من نظام العمل؟",
        "هل للموظف الحق في الاطلاع على لائحة العمل؟",
        "ماهي الية رفع دعوى في السعودية؟",
        "من هو المسؤول في رفع الدعوى لدى المحاكم السعودية؟",
        "كيف تكون أتعاب المحاماة لدى المكتب؟",
        "ماهي صلاحية لجنة المنازعات المصرفية في السعودية ؟",
        "كيف افتح سجل تجاري باسمي في السعودية ؟",
        "شروط وكيفية تأسيس فرع لشركة اجنبية بالسعودية ؟",
        "ماهي وثيقة التامين الشامل الخاصة بالمركبات ؟",
        "ماهي وثيقة التامين الالزامي للمركبات ؟",
        "بعد صدور الحكم وجدت اوراق مهمة يمكن ان تغير الحكم ؟",
        "هناك اخطاء في صك الحكم , ماذا نفعل ؟",
        "هل تكون المرافعة شفهية ام مكتوبة ؟",
        "يوجد لدينا وقف قديم , كيف يمكنني الاستفادة من هذا الوقف ؟",
        "ما هي أنواع القضايا التي يتعامل معها مكتب المحاماة الخاص بك؟",
        "ما هي المدة التي يستغرقها تنفيذ قرار في قضية عمالية؟",
        "ما المدة التي يستغرقها رفع إيقاف الخدمات في القانون السعودي ؟",
        "ما هو الوقت المستغرق للرد على الاستشارة القانونية ؟",
        "ماهي متطلبات تأسيس شركة مهنية مختلطة ؟",
        "كيف يمكن تحويل مؤسستي إلى شركة ؟",
        "ماهي شروط الحصول على شهادة منشأ ؟",
        "كم هي تكلفة الرسوم الحكومية لتسجيل علامة تجارية ؟",
        "هل تختص المحاكم التجارية بالنظر في دعاوى العقار؟",
        "كيف يمكنني حجز اسم تجاري؟",
        "كم هي مدة حماية العلامة التجارية؟",
        "هل استخراج الوكالة يحتاج موعدًا؟",
        "ما هي شروط استخراج حصر ورثة؟",
        "كيف أطلب الاستشارة أو الخدمات القانونية الأخرى؟",
        "كم تكلفة الخدمات القانونية؟",
        "كيف سيتم اطلاعي على سير قضيتي؟",
        "ما هي أفضل أساليب تطوير وتسويق الخدمات القانونية؟",
        "ما هي الخدمات القانونية؟",
        "هل مكتب المحاماة متخصص في قضايا معينة؟",
        "ما هي الخدمات القانونية المقدمة للأعمال والشركات؟",
        "كيف يمكن عمل فسخ النكاح بالسعودية؟",
        "ما الفرق بين الخلع وفسخ النكاح وفقًا للنظام السعودي؟",
        "كيف يمكنني طلب الطلاق من زوجي في السعودية؟",
        "هل تعتبر الهيئة العمالية مختصة بقضايا الهروب؟",
        "هل بالإمكان رفع دعوى عمالية بعد أن يتم توقيع المخالصة؟",
        "هل بالإمكان المطالبة بحقوق العامل بعد أن يتم نقل الكفالة؟",
        "هل تقدمون خدمات الخبرة القضائية؟",
        "ما هي القضايا الجنائية في السعودية؟",
        "كيف تتم صياغة العقد؟",
        "ما هي إجراءات التصفية؟",

        ],


    "contexts": [
المادة 47 من نظام خدمة الأفراد: ا- يستحق الفرد اجازه سنويه مدتها ثلاثون يوما في السنه. ب- لا يجوز منح الفرد اجازه سنويه للمره الاولي قبل مضي احد عشر شهرا من بدء تعيينه. ج- يجوز ضم الاجازات السنويه بعضها الي بعض بشرط لا تزيد مده او مدد الاجازه التي يتمتع بها الفرد في السنه الهجريه الواحده علي ستين يوما كما يجوز التمتع بالاجازه السنويه علي فترات بشرط ان لا تقل فتره التمتع بالاجازه عن خمسه عشر يوما ولا تزيد علي مرتين في السنه الهجريه الواحده. د- يجوز للوزير في حالات الضروره تمديد مدد التمتع بالاجازات المذكوره في الفقره ج ما لا يزيد عن 15 يوما واحتسابها من اجازات الفرد. ه- يجوز تاجيل الاجازه السنويه للفرد اذا اقتضت المصلحه العامه ذلك وفق هذه الحاله يحق له التمتع بها حالما تزول الاسباب التي اجلت الاجازه من اجلها.
---
- عدلت الفقره ج من هذه الماده، وذلك بموجب المرسوم الملكي رقم م28 وتاريخ 1442326ه. لتكون بالنص الاتي: يجوز ضم الاجازات السنويه بعضها الي بعض بشرط الا تزيد مده الاجازه التي يتمتع بها الفرد في السنه علي ستين يوما.

"""],
                 #-----------------------------------------------------------------------------------




                 ["""المادة الأولى بعد المائة : من نظام العمل: تم تعديل هذه الماده بموجب المرسوم الملكي رقم م 46 وتاريخ 5 6 1436 ه ؛ لتكون بالنص الاتي: تنظم ساعات العمل وفترات الراحه خلال اليوم، بحيث لا يعمل العامل اكثر من خمس ساعات متتاليه دون فتره للراحه والصلاه والطعام لا تقل عن نصف ساعه في المره الواحده خلال مجموع ساعات العمل، وبحيث لا يبقي العامل في مكان العمل اكثر من اثنتي عشره ساعه في اليوم الواحد.
---
تنظم ساعات العمل وفترات الراحه خلال اليوم، بحيث لا يعمل اي عامل اكثر من خمس ساعات متتاليه دون فتره للراحه والصلاه والطعام لا تقل عن نصف ساعه في المره الواحده خلال مجموع ساعات العمل، وبحيث لا يبقي العامل في مكان العمل اكثر من احدي عشره ساعه في اليوم الواحد.
المادة الثامنة والتسعون : من نظام العمل: لا يجوز تشغيل العامل تشغيلا فعليا اكثر من ثماني ساعات في اليوم الواحد، اذا اعتمد صاحب العمل المعيار اليومي، او اكثر من ثمان واربعين ساعه في الاسبوع، اذا اعتمد المعيار الاسبوعي. وتخفض ساعات العمل الفعليه خلال شهر رمضان للمسلمين، بحيث لا تزيد علي ست ساعات في اليوم، او ست وثلاثين ساعه في الاسبوع.
المادة المائة : من نظام العمل: يجوز لصاحب العمل- بموافقه الوزاره- في المنشات التي تقتضي طبيعه العمل فيها اداء العمل بالتناوب زياده ساعات العمل علي ثماني ساعات عمل في اليوم او ثمان واربعين ساعه في الاسبوع، بشرط الا يزيد متوسط ساعات العمل عند احتسابه لمده ثلاثه اسابيع او اقل علي ثماني ساعات يوميا او ثمان واربعين ساعه اسبوعيا.
المادة الثامنة والثمانون بعد المائة : من نظام العمل: لا تزيد ساعات العمل الفعليه التي يمضيها العامل تحت سطح الارض علي سبع ساعات في اليوم، ولا يجوز ابقاء العامل في مكان العمل سواء فوق سطح الارض او في باطنها مده تزيد علي عشر ساعات في اليوم، واذا كان العمل في باطن الارض فتشمل هذه المده الوقت الذي يستغرقه العامل للوصول من سطح الارض والوقت الذي يستغرقه للعوده من باطن الارض الي سطحها.
المادة الخمسون بعد الثلاثمائة من النظام البحري التجاري: اذا ابرم التامين بوثيقه عائمه وجب ان تشتمل علي الشروط التي يلتزم بمقتضاها كل من المؤمن والمؤمن له، والحد الاعلي للمبلغ الذي يتعهد المؤمن بدفعه عن كل شحنه, واقساط التامين التي يقوم المؤمن له بدفعها. اما البضائع المؤمن عليها والرحلات والسفن وغير ذلك من البيانات فتعين بملاحق لكل شحنه علي حده.
المادة الخامسة من نظام مزاولة نقل النقود والمعادن الثمينة والمستندات ذات القيمة: تلتزم جميع الجهات الحاصله علي ترخيص بمزاوله النشاط بابرام وثيقه تامين مع احدي شركات التامين المرخص لها بالعمل في المملكه تغطي قيمه جميع المنقولات.
المادة الثامنة من نظام المرور: ا - لا يجوز تسيير المركبات قبل تسجيلها ودفع الرسوم المقرره - وفقا لجداول الرسوم الملحقه بهذا النظام - وصدور رخصه السير الخاصه بها، ووضع لوحات عليها وفقا لاحكام هذا النظام ولائحته. ويستثني من ذلك المركبات العسكريه المستخدمه لاغراض عسكريه التي لا تستخدم الطرق العامه بصوره اعتياديه.ب - يجب تسديد الغرامات المروريه المترتبه علي مخالفات سابقه قبل البدء في اجراءات رخصه السير .ج - يلزم كل قائد مركبه - يحمل رخصه قياده ساريه المفعول، ويقود سيارته داخل المملكه - بالتامين، وفق ما تحدده اللائحه .
---
عدلت هذه الماده بموجب المرسوم الملكي رقم م115 وتاريخ 1439125 ه.
"""],
                 #-----------------------------------------------------------------------------------

["""المادة السبعون من النظام الأساسي للحكم: تصدر الانظمه ، والمعاهدات ، والاتفاقيات الدوليه ، والامتيازات ، ويتم تعديلها بموجب مراسيم ملكيه .
المادة الخامسة والعشرون من نظام هيئة البيعة: يتم تعديل احكام هذا النظام بامر ملكي بعد موافقه هيئه البيعه.
المادة الحادية والسبعون من النظام الأساسي للحكم: تنشر الانظمه في الجريده الرسميه، وتكون نافذه المفعول من تاريخ نشرها، ما لم ينص علي تاريخ اخر.
المادة الثانية والثمانون من النظام الأساسي للحكم: مع عدم الاخلال بما ورد في الماده السابعه من هذا النظام، لا يجوز باي حال من الاحوال تعطيل حكم من احكام هذا النظام، الا ان يكون ذلك مؤقتا في زمن الحرب، او في اثناء اعلان حاله الطوارئ . وعلي الوجه المبين بالنظام.
"""],
                 #-----------------------------------------------------------------------------------
["""المادة الحادية والسبعون بعد المائة: من نظام المرافعات الشرعية: تتولي المحكمه - بقرار تصدره بناء علي طلب احد الخصوم او من تلقاء نفسها - تصحيح ما قد يقع في صك الحكم من اخطاء ماديه بحته كتابيه او حسابيه.ويجري هذا التصحيح علي نسخه الحكم الاصليه، ويوقعه قاضي او قضاه المحكمه التي اصدرته، بعد تدوين القرار في ضبط القضيه.
المادة (548): من النظام التجاري ( نظام المحكمة التجارية): اذا وجد بالصك بعض سهو او نواقص لم تؤثر في نفس الحكم ولا متعلقاته فللهيئه اعادته الي المحكمه لتصحيح النواقص.
"""],
                 #-----------------------------------------------------------------------------------
["""المادة الحادية والأربعون: من نظام العلامات التجارية: تحدد الرسوم المستحقه طبقا لاحكام هذا النظام علي الوجه الاتي : اولا : الف ريال عن اي اجراء مما ياتي : ا - تقديم طلب تسجيل علامه تجاريه عن فئه واحده.ب - تقديم طلب تسجيل علامه تجاريه جماعيه عن فئه واحده.ج - طلب فحص علامه تجاريه جماعيه عن فئه واحده.د - الاطلاع علي السجل بشان علامه تجاريه عن فئه واحده.ه - كل صوره تؤخذ مما هو مدون بالسجل بشان علامه تجاريه عن فئه واحده.و - طلب التاشير بانتقال الملكيه او تحويلها لعلامه تجاريه عن فئه واحده. ز - طلب الترخيص باستخدام علامه تجاريه عن فئه واحده، وكذا التاشير برهنها وفقا للمواد الحاديه والثلاثين و الثانيه والثلاثين و الثالثه والثلاثين من هذا النظام.ح - لكل تعديل او اضافه في علامه تجاريه عن فئه واحده وفقا للماده الثامنه عشره من هذا النظام.ط - طلب اضافه او تغيير اي بيان لم يحدد له رسم في شان علامه تجاريه عن فئه واحده.ي - طلب تجديد تسجيل علامه تجاريه عن فئه واحده خلال الاشهر السته التاليه لمده حمايتها. ثانيا: ثلاثه الاف ريال عن اي اجراء مما ياتي : ا - تقديم طلب بالحمايه الوقتيه لعلامه تجاريه عن فئه واحده.ب - تسجيل علامه تجاريه عن فئه واحده.ج - تسجيل علامه تجاريه جماعيه عن فئه واحده.د - تجديد تسجيل علامه تجاريه عن فئه واحده.ه - تجديد تسجيل علامه تجاريه جماعيه عن فئه واحده.
مادة (14): من قانون (نظام) العلامات التجارية لدول مجلس التعاون لدول الخليج العربية: 1- اذا قبلت الجهه المختصه العلامه التجاريه، وجب عليها قبل تسجيلها ان تعلن عنها بوسيله النشر التي تحددها اللائحه التنفيذيه لهذا القانون النظام ويلزم طالب التسجيل بتكاليف الاشهار.2 - لكل ذي شان، خلال ستين يوما من تاريخ النشر، ان يقدم للجهه المختصه اعتراضا مكتوبا علي تسجيل العلامه. وعلي الجهه المختصه ان تبلغ طالب التسجيل بصوره من الاعتراض خلال ثلاثين يوما من تاريخ تقديمه، وعلي طالب التسجيل ان يقدم للجهه المختصه ردا مكتوبا علي الاعتراض خلال ستين يوما من تاريخ ابلاغه به، والا اعتبر متنازلا عن طلب التسجيل.
المادة الرابعة عشرة: من نظام العلامات التجارية: في حاله قبول تسجيل العلامه تقوم الاداره المختصه بالشهر عنها بالكيفيه والاجراءات التي تحددها اللائحه التنفيذيه، ويلزم طالب التسجيل بتكاليف الشهر.
المادة الرابعة والأربعون: من نظام العلامات التجارية: مع عدم الاخلال باي عقوبه اشد، يعاقب بالحبس مده لا تزيد علي ثلاثه اشهر وبغرامه لا تقل عن عشرين الف ريال، ولا تزيد علي مائتين وخمسين الف ريال او باحدي هاتين العقوبتين: ا - كل من استعمل علامه غير مسجله في الاحوال المنصوص عليها في الفقرات ب، ج، د، ه من الماده الثانيه من هذا النظام.ب - كل من دون بغير حق علي علاماته او اوراقه التجاريه بيانا يؤدي الي الاعتقاد بحصول تسجيلها.
المادة التسعون من نظام الإفلاس: تقضي المحكمه -من تلقاء نفسها او بناء علي طلب من ذي مصلحه- بافتتاح اجراء التصفيه او التصفيه الاداريه اذا تحققت الشروط الاتيه: ا - ان يكون المدين متعثرا او مفلسا. ب- استيفاء شروط افتتاح اجراء التصفيه او اجراء التصفيه الاداريه المراد افتتاحه. ج- ان يكون انهاء اجراء اعاده التنظيم المالي مبنيا علي الفقره ج او الفقره د او الفقره ه او الفقره و او الفقره ز من الماده السابعه والثمانين من النظام.
المادة الستون بعد المائة من نظام الإفلاس: يهدف اجراء التصفيه لصغار المدينين الي بيع اصول التفليسه وتوزيع حصيلته علي الدائنين خلال فتره معقوله عبر اجراءات يسيره بتكلفه منخفضه وكفايه عاليه، وذلك تحت اداره الامين.
"""],





                 ],


###### End ###########


                "ground_truth": [
        """نعم، يمكن فصل العامل دون إنذار، ولكن ذلك يكون فقط في الحالات التي نصت عليها المادة 80 من نظام العمل السعودي:

“لا يجوز لصاحب العمل فسخ العقد دون مكافأة أو تعويض أو إنذار العامل، إلا في حالات محددة منها: إذا وقع من العامل اعتداء على صاحب العمل أو أحد رؤسائه، أو تغيب بدون سبب مشروع أكثر من ثلاثين يومًا خلال السنة الواحدة أو أكثر من خمسة عشر يومًا متتالية، بشرط إنذاره كتابيًا بعد غيابه عشرين يومًا في الحالة الأولى وغيابه عشرة أيام في الحالة الثانية.”

وحالات فصل العامل دون إنذار متعددة، والتوسع في تفسيرها يحتاج الحصول على استشارات قانونية في نظام العمل السعودي، لتحليل حالتك القانونية بدقة وحماية حقوقك أمام الجهات المختصة. ومن بين هذه الحالات:

ارتكاب العامل اعتداءً على صاحب العمل أو أحد رؤسائه.
التغيب المتكرر دون عذر.
الإهمال الجسيم.
إفشاء أسرار العمل، وغيرها.
ومع ذلك، يُشترط أن يسبق الفصل تحقيق رسمي يُمكن فيه العامل من الدفاع عن نفسه، وأن يكون هناك دليل موثق على وقوع المخالفة.

أي فصل يتم دون هذه الشروط يُعد فصلًا تعسفيًا، مما يعطي العامل حق المطالبة بتعويض وفق المادة 77، التي تنظم آلية التعويض عند الفصل غير المشروع.""",

        """يُعد الفصل تعسفيًا إذا تم دون وجود سبب مشروع أو واضح، أو إذا كان الدافع وراءه هو تقديم العامل شكوى ضد صاحب العمل، أو مطالبته بحق مكفول له نظامًا، كالمطالبة براتب متأخر أو إجازة نظامية. هذا النوع من الفصل يُخالف مبدأ العدالة ويُعتبر إساءة لاستخدام الحق في إنهاء العقد، ويُعطي العامل الحق في المطالبة بالتعويض المالي المنصوص عليه في المادة 77 من نظام العمل السعودي:

“ما لم يتضمن العقد تعويضًا محددًا مقابل إنهائه من أحد الطرفين لسبب غير مشروع، يُستحق الطرف المتضرر من إنهاء العقد تعويضًا على النحو التالي: أجر خمسة عشر يومًا عن كل سنة من سنوات خدمة العامل، إذا كان العقد غير محدد المدة، وأجر المدة الباقية من العقد إذا كان العقد محدد المدة.”

من المهم أن يعلم العامل أن مجرد توجيه إنذار بالفصل لا يعني أن الإنهاء كان مشروعًا. بل يجب أن يكون السبب مُوثقًا ومبررًا وفق ما نص عليه النظام. لذلك، يُنصح كل من تعرض للفصل أن يحتفظ بنسخة من:

عقد العمل.
الإشعارات.
الخطابات.
المكاتبات التي جرت بينه وبين جهة العمل.
تُشكّل هذه الوثائق أدلة ضرورية عند تقديم شكوى رسمية أو رفع دعوى أمام المحكمة العمالية.""",

        """لا يحق لصاحب العمل خصم أي مبلغ من راتب العامل إلا في حالات محددة نصّ عليها نظام العمل السعودي، مثل:

الغياب غير المبرر.
استرداد السلف المالية.
تنفيذًا لحكم قضائي صادر من جهة مختصة.
ويُشترط أن تكون الخصومات موثقة، ولا يجوز أن تتجاوز 50% من أجر العامل الشهري إلا بموافقة كتابية منه، وفق ما ورد في المادة 91 من النظام.

في حال لاحظت خصومات غير مبررة أو غير مفسّرة في راتبك، فمن حقك طلب توضيح رسمي، وإذا لم تحصل عليه، يمكنك رفع شكوى إلى وزارة الموارد البشرية أو التواصل مع محامٍ مختص في قضايا العمل يُقدم لك أفضل استشارات قانونية في نظام العمل السعودي، للتحقق من قانونية الخصم ومباشرة الإجراءات القانونية لاسترداد حقوقك.""",

        """وفقًا للمادة 75 من نظام العمل السعودي، يجب إنذار العامل كتابيًا قبل إنهاء العقد بمدة لا تقل عن 60 يومًا إذا كان العقد غير محدد المدة، وبمدة لا تقل عن 30 يومًا إذا كان العقد محدد المدة، ما لم يتفق الطرفان على خلاف ذلك. ويُشترط أن يكون الإنذار واضحًا ومحدد التاريخ، مع بيان سبب الإنهاء إن وُجد. حيث نصت المادة 75 من نظام العمل السعودي:

“إذا كان العقد غير محدد المدة، جاز لأي من الطرفين إنهاؤه بناءً على سبب مشروع يجب بيانه، وأن يتم إشعار الطرف الآخر كتابةً قبل الإنهاء بستين يومًا إذا كان أجر العامل شهريًا، ولا يقل عن ثلاثين يومًا بالنسبة إلى غيره من العمال.”

ويُعد عدم الالتزام بفترة الإشعار إخلالًا بالعقد، ويُلزم الطرف المُنهِي بدفع أجر تلك المدة للطرف الآخر. كما أن توجيه الإنذار لا يُسقط حقوق العامل الأخرى مثل مكافأة نهاية الخدمة، بدل الإجازات، وأي مستحقات نظامية أخرى""",

        """عند انتهاء علاقة العمل، يضمن نظام العمل السعودي للعامل عدة حقوق أساسية يجب على صاحب العمل الالتزام بها، سواء كان العقد محددًا أو غير محدد المدة. وتشمل هذه الحقوق:

مكافأة نهاية الخدمة: وهي من أبرز الحقوق، وتحسب وفقًا للمادة 84 من النظام، حيث ينص على:

“إذا انتهت علاقة العمل وجب على صاحب العمل أن يدفع للعامل مكافأة نهاية الخدمة، وتُحتسب على أساس أجر نصف شهر عن كل سنة من السنوات الخمس الأولى، وأجر شهر عن كل سنة من السنوات التالية.”

وتحسب المكافأة بناءً على مدة الخدمة ونوع العقد (محدد أو غير محدد)، كما أن الاستقالة لا تسقط هذا الحق بالكامل بل تُنقصه بنسب معينة حسب سنوات الخدمة.

أجر الإجازات السنوية غير المستخدمة: للعامل الحق في الحصول على أجر مقابل أي رصيد إجازات متبقي لم يُستخدم أثناء مدة العقد، سواء كانت إجازة سنوية أو مرضية، ويُحسب هذا الرصيد على أساس الأجر اليومي الأخير.
شهادة الخدمة: يجب على صاحب العمل تزويد العامل بشهادة خبرة دون مقابل، توضح طبيعة العمل ومدته، دون أن تتضمن ما يسيء إليه، وذلك وفقًا للمادة 64 من النظام.
صرف كافة المستحقات المالية المتأخرة: مثل الحوافز، البدلات، أو العمولات، إن وُجدت، ويجب صرفها خلال فترة لا تتجاوز أسبوعين من تاريخ انتهاء العلاقة العمالية بحسب النظام.
تسليم المستندات الشخصية: من حق العامل استلام جميع وثائقه ومستنداته الشخصية التي أودعها لدى جهة العمل، ولا يجوز حجزها أو ربطها بتسوية مالية.""",

        """نعم، يحق لكل عامل إجازة سنوية مدتها 21 يومًا على الأقل، وتصل إلى 30 يومًا بعد مرور خمس سنوات من الخدمة، وذلك وفق المادة 109 من نظام العمل السعودي. كما لا يحق لصاحب العمل تأجيل الإجازة لأكثر من 90 يومًا إلا بموافقة كتابية من العامل.

تُعد هذه المسألة من أكثر ما يُطرح ضمن استشارات قانونية في نظام العمل السعودي، خصوصًا عند حرمان العامل من إجازته السنوية أو تأجيلها بشكل غير مبرر.""",

        """ساعات العمل الرسمية في السعودية هي 8 ساعات يوميًا أو 48 ساعة أسبوعيًا، وتُخفَّض في رمضان إلى 6 ساعات يوميًا.

ووفقًا للمادة 107 من نظام العمل السعودي:

“إذا عمل العامل وقتًا إضافيًا، وجب أن يُمنح أجرًا إضافيًا عن تلك الساعات يوازي أجر الساعة مضافًا إليه 50% من أجره الأساسي.”

أي أن العامل يستحق 150% من أجره الأساسي عن كل ساعة إضافية يعملها خارج ساعات العمل النظامية. لذلك، من المهم متابعة عدد ساعات العمل المسجلة بدقة، والمطالبة بالمستحقات في حال تجاوز الحد النظامي.""",

        """نعم، يمكن للعامل الاستقالة خلال فترة التجربة، بشرط إشعار صاحب العمل قبل مدة لا تقل عن يوم واحد، ما لم يُنص في العقد على خلاف ذلك. ويجوز أيضًا لصاحب العمل إنهاء العقد خلال هذه الفترة دون تعويض، ما دام ذلك ضمن الشروط المحددة في العقد ونظام العمل.

مع ذلك، فإن وجود العامل تحت التجربة لا يعني حرمانه من الأجر عن الأيام التي عمل خلالها أو من حقوقه الأساسية المرتبطة بتلك المدة، مثل مستحقات الإجازات والبدلات النسبية، في حال استحقاقها. وتُعد هذه النقطة من الأمور الشائعة ضمن استشارات قانونية في نظام العمل السعودي، خصوصًا عند وجود نزاع بعد انتهاء فترة التجربة.""",

        """في حال إنهاء عقد العمل دون سبب مشروع من أحد الطرفين، يُمنح الطرف المتضرر تعويضًا ماليًا بموجب المادة 77 من نظام العمل السعودي. وتختلف طريقة الحساب حسب نوع العقد:

إذا كان العقد غير محدد المدة، يُحسب التعويض على أساس أجر 15 يومًا عن كل سنة من سنوات الخدمة.
أما إذا كان العقد محدد المدة، فيُحسب التعويض على أساس الأجر عن المدة المتبقية من العقد.""",

        """نعم، يقر نظام العمل السعودي بحق الموظف في الاطلاع على لائحة تنظيم العمل المعتمدة داخل المنشأة، ويُلزم صاحب العمل بتوفيرها باللغة العربية، وتعليقها في مكان ظاهر يسهل على جميع العاملين الوصول إليه. هذا ما نصّت عليه المادة 12 من النظام، التي تنص على:

“يجب على صاحب العمل أن يعلّق في مكان ظاهر من أماكن العمل نسخة من لائحة تنظيم العمل المعتمدة، وتُكتب باللغة العربية.”""",

"""لرفع قضية في المحكمة يجب اتباع خطوات وتقديم عدة وثائق. وهذه الخطوات
هي تحديد النوع والمحكمة، ثم إعداد الشكوى أو الدعوى، وتقديم الشكوى للمحكمة، ثم سداد الرسوم واستدعاء الطرف
.اعمة وإذن للتوكيل (إن وجد) الث""",

  """""لرفع دعوى في المحاكم السعودية، المسؤول الأول هو المدعي أو الطرف الذي يرفع الدعوى. هذا الشخص يكون هو من يبدأ الإجراءات القانونية أمام المحكمة، كما يمكن للمدعي تقديم الدعوى بشكل مباشر أو من خلال محامي، فمثلا لرفع دعوى عمالية يجب على العامل أو صاحب العمل التأكد من استيفاء عدة شروط قانونية لضمان قبول الدعوى من قبل المحكمة العمالية، تشمل هذه الشروط الأهلية القانونية، حيث يجب أن يكون الطرف المدعي (العامل أو صاحب العمل) لديه الأهلية القانونية لرفع الدعوى.
    """,
  """يتم حساب أتعاب المحامي في السعودية بالاستناد إلى عدة عوامل تتمثل بالنقاط التالية، درجة تعقيد القضية، وخبرة المحامي، والجهد الذي قام به، إضافة إلى الوقت الذي استغرقته القضية، ووفقًا للأسعار المتعارف بها في الأرجاء القانونية، فإن نسبة أتعاب المحامي في القضايا الجنائية والجزائية تتراوح بين ٢٠% إلى ٤٠%، بينما في القضايا المدنية فإن أتعاب المحامي لا تتعدى ٥% إلى ٢٥% ويمكن أن تتراوح تكلفة الاستشارة بين ٣٠٠ ريال سعودي إلى ١٠٠٠ ريال سعودي""",

"""حرص المنظم على منح لجنة المنازعات المصرفية الصلاحيات اللازمة للفصل في النزاع وإصدار قرار بشأنه، ولها في سبيل ذلك الأمر بتقديم الاتفاقيات المبرمة بين الطرفين والمستندات المؤيدة للدعوى والاستعانة بالخبرة الفنية، كما مُنحت اللجنة بهدف إلزام المدين بتنفيذ القرارات القطعية ذات الصلة باختصاصها إصدار قرارات بالحجز على حساباته المصرفية والاستثمارية ومستحقاته لدى الجهات الحكومية، وكذلك منعه من التعامل مع الجهات الحكومية والبنوك، ومنعه من السفر، كما يجوز للجنة أن تضمن قراراتها بالنفاذ المعجل وفقاً لحالات محددة، كما نص الأمر الملكي رقم (٣٧٤٤١) وتاريخ ١٤٣٣ / ٨ / ١١ ه على إلزام الجهات المعنية -كل بحسب اختصاصه- تنفيذ القرارات النهائية الصادرة من أي من اللجان وقرارات اللجنة التنفيذية والقرارات المشمولة بالنفاذ المعجّل""",

"""يجب التسجيل في منصة "وزارة التجارة" الإلكترونية، ثم تعبئة البيانات المطلوبة، وبعدها يتم اختيار نوع النشاط التجاري من بين العديد من الخيارات مثل المقاولات، الاستشارات، التجارة العامة، وغيرها، ثم تحديد مدة السجل التجاري حيث يمكن اختيار مدة السجل بين سنة واحدة إلى خمس سنوات، ثم يتم دفع الرسوم، حيث تتفاوت رسوم استخراج السجل التجاري وفقًا لنوع النشاط ومدة السجل، كما يتم سداد الرسوم إلكترونيًا عبر نظام "سداد"، وبعد ذلك يتم إصدار السجل التجاري بشكل فوري، ويمكن تحميله وطباعته مباشرة من الموقع الإلكتروني.""",
"""من أجل الاستفادة من الوقف القديم يمكنك التوجه للمحكمة الشرعية أو الهيئة المعنية بالأوقاف في المملكة للاستفسار حول كيفية التصرف أو الاستفادة من هذا الوقف بما يتوافق مع الشروط القانونية، أما إذا كانت لديك تفاصيل دقيقة حول نوع الوقف أو حالته، يمكن استشارة محامي""",
"""قضايا الأحوال الشخصية، حيث نعمل على فهم قضايا الأحوال الشخصية بشكل أفضل مع نصائح قانونية متخصصة، معلومات حول كيفية إدارة الطلاق، والحضانة، والميراث بكفاءة. القضايا الجنائية الكبرى، حيث نعمل على جمع معلومات شاملة حول القضايا الجنانية الكبرى، دليل شامل لفرص الدفاع، التهم الخطيرة، واستراتيجيات الترافع في محاكم الجرائم الكبرى.""",

"""أما بالنسبة لمدة تنفيذ الحكم، فإنه بمجرد تقديم الشكوى أو التظلم إلى مكتب العمل، تبدأ مرحلة التسوية الودية للوصول إلى حل بين الطرفين، إذا لم يتم التوصل إلى تسوية خلال ٢١ يومًا، تُحال القضية إلى المحكمة العمالية للنظر فيها، وأما بالنسبة لحالات العمالة المنزلية، تُحال الشكوى إلى لجنة مختصة بالفصل في هذه النزاعات، حيث تُمنح اللجنة ٥ أيام للوصول إلى تسوية. وفي حالة الفشل، أمامها ١٠ أيام لإصدار حكم نهائي، وبعد صدور حكم المحكمة العمالية، يجب تنفيذه في غضون ٧ إلى ١٤ يومًا، ويُعطى الشخص خلال هذه الفترة لتنفيذ الحكم قبل التعرض للعقوبات في حالة التأخير.
""",
"""لا تتجاوز مدة إيقاف الخدمات في المرحلتين (الأولى) و(الثانية) المشار إليهما (٣٠) يوماً لكل مرحلة""",
"""لا يمكن تحديد وقت معين للرد على الاستشارة، ولكن نعمل جاهدين على إنهاء جميع الاستشارات القانونية بشكل دقيق، لنحقق درجة الرضا المطلوبة من العملاء.""",
"""ألا يكون السجل التجاري مشطوبًا أو موقوفًا أو منتهيًا، في حال كان أحد الشركاء شريكًا اعتباريًا. كما يجب أن يتم التحقق من الآتي في حال كانت صفة الشركة (مهنية) وجود رخصة مهنية سارية المفعول للشركاء، و ألا تقل نسبة الشريك السعودي المرخص عن ٢٥٪ في حال كانت الشركة مختلطة.""",
"""حتى تتمكن من إتمام عملية التحويل، لابد من تحديد نوع الشركة التي تريد التحويل إليها، ويمكنك استشارة محامي متخصص لمساعدتك في تحديد النوع المناسب، ثم إتباع جميع الإجراءات التي ينص عليها القانون السعودي، ثم استيفاء كافة الشروط التي تمكنك من تنفيذ عملية تحويل المؤسسة إلى شركة بنجاح، ثم تسديد جميع الرسوم المترتبة على هذه العملية، ويمكنك أيضًا إرفاق جميع المستندات المتعلقة بمؤسستك، بالإضافة إلى المستندات المطلوبة من أجل تحويلها إلى شركة.""",
"""ملء وتصديق الإفادة المناسبة، وتوفير فاتورة تصنيع أو فاتورة تجارية توضح مكان تصنيع البضائع، بعدها القيام بملئ نموذج شهادة المنشأ، ثم تقوم بتقديم الإفادة الموثقة وشهادة المنشأ والفواتير الأخرى إلى غرفة التجارة المحلي.""",
"""تشمل رسوم التسجيل عمومًا رسوم التسجيل الحكومية ورسوم الخدمات المقدمة من مكاتب المحاماة أو الشركات المختصة، وقد تتراوح هذه التكاليف عادة من عدة آلاف إلى عشرات الآلاف من الريالات السعودية. الرسوم الخاصة بطلب التسجيل هي ١٠٠٠ ريال سعودي. الرسوم الخاصة بالنشر في الموقع التابع لوزارة التجارة هي ١٥٠٠ ريال سعودي.""",
"""دعاوى العقارات وإيجاراتها لا تعد من الأعمال التجارية، بينما تختص المحاكم التجارية بالنظر في جميع المنازعات التجارية الأصلية والتبعية التي تحدث بين التجار. و الدعاوى التي تقام على التاجر بسبب أعماله التجارية الأصلية والتبعية.""",
"""تقديـم طلب لخدمة حجـز إسم تجـاري، يجب الضغط على ابدأ الخدمة، ثم الدخول إلى الحساب(اسم المستخدم و كلمة المرور أو النفاذ الوطني)، ثم في صفحة نظام الأسماء التجارية الضغط على أيقونة (حجز اسم)، ثم  في صفحة نظام الأسماء التجارية الضغط على أيقونة (حجز جديد)، ثم تعبئة حقول أنشطة الإسم التجاري، ومن ثم اختيار اسم مقترح أو اسم خاص، وفي حال تم اختيار اسم خاص يتم تعبئة حقول الأسامي التجارية، ثم بعد تعبئة الأسماء التجارية الضغط على أيقونة الاستعلام المبدئي ومن ثم تقديم الطلب، و يمكن التحقق من حالة االسم التجاري بعد حجزه و يظهر رقم الحجز .""",
"""مدة الحماية المترتبة على تسجيل العلامة عشرة سنوات، ولصاحب الحق إذا رغب في استمرار الحماية لمدد مماثلة، أن يقدم طلبًا بالتجديد خلال السنة الأخيرة، بالشروط المنصوص عليها في هذا القانون (النظام) ولائحته التنفيذية.""",
"""استخراج الوكالة لا يتطلب تحديد موعد مسبق في الغالب، حيث امكن للأفراد التوجه إلى مكاتب كاتب العدل أو المحاكم مباشرة في أوقات العمل الرسمية لتوثيق الوكالة، ومع ذلك، في بعض الحالات قد يكون من الأفضل الحجز مسبقًا عبر خدمات إلكترونية مثل بوابة ناجز.""",
"""في البداية يجب على الشخص الراغب في حصر الإرث طلب موعد مسبق من هيئة المحكمة الكبرى في المنطقة التي يقيم فيها. ومن أهم شروط استخراج وثيقة حصر الورثة هي تقديم بطاقة الأحوال فيجب تقديم نسخة واحدة من بطاقة الأحوال المدنية للشخص الذي يرغب في حصر الإرث.لابد من وجود شهود عددهم لا يقل عن اثنين، ويجب أن يكونوا أشخاصًا ذوي عقل وثقة. يتعين ألا يكونوا أقاربًا للورثة بشكل مباشر أو غير مباشر. وكما ذكرنا سابقا أن وجود شهادة الوفاة من أهم شروط استخراج وثيقة حصر الورثة حيث يجب تقديم نسخة أصلية ومصدقة من شهادة الوفاة للشخص المتوفى، ويمكن الحصول عليها من مكتب الخطابات بتقديم طلب من أحد الورثة. وفي صك حصر الورثة وصك الإعلان يجب على الورثة طلب صك حصر الورثة وصك الإعلان، والتي تثبت وتعلن توزيع التركة وحصص الورثة. كما يجب حضور أحد الورثة على الأقل لتقديم الطلبات والمستندات المطلوبة. إذا كان أحد الورثة غير قادر على الحضور، فيمكنه إرسال محامٍ لتمثيله في الإجراءات.""",
"""يمكن الحصول على استشارة قانونية عبر التواصل مع المحامي عبر الإنترنت، أو بمكالمة هاتفية، أو مقابلته بشكل مباشر للحصول على استشارة. ومن الجدير بالذكر، أن طرق الحصول على استشارة متنوعة، ويمكن أن تأخذ أشكال عدة، وهي استشارة قانونية خطية أو مكتوبة، بحيث تقدم كافة التفاصيل والبيانات المتعلقة بالمسألة القانونية، وتوجيه الأسئلة المطلوبة، بما يمكن المستشار القانوني أو المحامي من تحليل الموضوع والرد عليه باستشارة مكتوبة. استشارة قانونية مباشرة وشفهية، وتتم بحضور العميل إلى مكتب المحامي.""",
"""تتراوح أسعار أتعاب المحامين في السعودية بشكل عام، حيث أنه في القضايا المدنية تتراوح الأتعاب عادةً بين 500 إلى 5000 ريال سعودي، حسب طبيعة وتعقيد القضية. أما القضايا الجنائية، قد تتراوح الأتعاب من 2000 إلى 10000 ريال سعودي، خاصة في القضايا التي تشمل الاتهامات الخطيرة.""",
"""يمكنك على سير القضية من خلال ال تسجيل الدخول على بوابة ناجز بحساب النفاذ الوطني، ثم قم باختيار جميع الخدمات الإلكترونية، ثم اختيار باقة ""القضاء""، وبعدها يمكنك الدخول لخدمة ""الاطلاع على الأحكام ""، ثم قم الالإطلاع ضغط على أيقونة ""تقديم طلب جديد""، ثم قم باختيار القضية، واختيار الأحكام، ثم استعراض صك الحكم.  """,
"""تعد طرق تسويق الخدمات القانونية لمكتب المحاماة بمثابة منظومة متكاملة ومترابطة، لذلك عليك عدم الإعتماد على طريقة واحدة في تسويق الخدمات القانونية، ولكن كلما تعددت هذه الطرق كلما كانت النتائج أفضل، حيث يمكنك إنشاء موقع إلكتروني لمكتب المحاماة، ثم إعداد وكتابة محتوى الموقع الإلكتروني لمكتب المحاماة طبقاً لمتطلبات تحسين الظهور في محركات البحث كتابة، ويمكنك نشر المقالات القانونية على الموقع، و إدارة مواقع التواصل الإجتماعي للخدمات القانونية، وإعداد الأخبار القانونية ونشرها على الموقع. بالإضافة إلى أنه يمكن إنشاء مكتبة قانونية إلكترونية، وإعداد النشرات القانونية، وإعداد وتحرير مجلة قانونية إلكترونية، أو إنشاء مدونة قانونية إلكترونية.""",
"""تتضمن هذه الخدمات الاستشارات القانونية، تمثيل العملاء أمام المحاكم، تسجيل الشركات والعلامات التجارية، القضايا التجارية والعمالية، قضايا العقارات، قضايا الأسرة والطلاق، وغيرها من الخدمات القانونية الأخرى.""",
"""نعم، يوجد الكثير من مكاتب المحاماة المتخصصة في مجالات معينة، وذلك لتلبية احتياجات العملاء بشكل أفضل. كما أن مكتب المحاماة المتخصص في القضايا داخل المملكة العربية السعودية يشكّل نموذجًا مثاليًا لتلك المكاتب التي تقدّم خدمات قانونية على أعلى مستوى.""",
"""تقدم مكاتب المحاماة للأعمال والشركات خدمات قانونية تشمل حل النزاعات القانونية الكبيرة، وإبداء الرأي القانوني الصحيح بدون تحيز لأحد الأطراف، والفصل في جميع الشكاوى التي تحدث في الشركة، و عمل تقارير قانونية ودورية للشركة خاصة للصفقات التجارية ومدى نجاحها أو فشلها، كما تساعد في تطوير كافة الجوانب القانونية للشركات، وتقوم بمراجعة وصياغة العقود التجارية للشركات والأشخاص، كما تقوم بتوقيع الغرامات والجزاءات على موظفي الشركة في حالة حدوث مخالفات قانونية، وتساعد في إبداء الرأي القانوني الصحيح للمناقصات والمزايدات.""",
"""لتقديم طلب فسخ عقد الزواج في السعودية، يمكنك الدخول إلى منصة ناجز، وتعبئة النموذج الإلكتروني الخاص بطلب فسخ عقد النكاح، وإرفاق المستندات اللازمة. بعد تقديم الطلب، تتابع المحكمة الإجراءات المطلوبة""",
"""الخلع هو عقد اتفاقي بين الزوجين، يتم إنهاء الحياة الزوجية بموجبه، لقاء بدل مادي تدفعه الزوجة للزوج. بينما الفسخ دعوى قضائية يصدر بنهايتها حكم قضائي بالتفريق بين الزوجين، قد يكون بعوض أو بدون عوض تدفعه الزوجة للزوج.""",
"""يمكن للزوجين أن يتفقا على مبدأ إنهاء العلاقة الزوجية دون شروط، أو بشروط لا تتنافى مع أحكام مدوّنة الأُسْرَة ولا تضر بمصالح الأطفال. وعند وقوع هذا الاتفاق، يقدم الطرفان أو أحدهما طلب التطليق للمحكمة مرفقاً به الإذن بتوثيقه. وتحاول المحكمة الإصلاح بينهما ما أمكن، فإذا تعذر الإصلاح، أذنت بالإشهاد على الطلاق وتوثيقه.""",
"""الهيئات العمالية لا تختص في قضايا الهروب.""",
"""يمكنك ذلك ولكن بشرط أن تكون المخالصة لم يدون بها أية مبالغ تظهر القيمة الفعلية التي قد حصلت عليها، أو أن تكون المخالصة أقل من مستحقات العامل الحقيقية.""",
"""نقل الكفالة بشكل نظامي لا يسقط حقوق العامل المستحقة له من الكفيل السابق، حيث يجب على الكفيل السابق تسوية جميع المستحقات المالية للعامل مثل الرواتب المتأخرة ومكافأة نهاية الخدمة وأي تعويضات أخرى.""",
"""نعم، ولكن ذلك يعتمد على طبيعة القضية والمجال المتعلقة به.""",
"""تشمل الجرائم الجنائية الشائعة في السعودية مجموعة متنوعة من الجرائم مثل القتل، السرقة، والاحتيال. تختلف العقوبات المفروضة على هذه الجرائم حسب خطورتها وتأثيرها على المجتمع. يتعين على الأفراد فهم هذه الجرائم لتجنب الوقوع فيها، حيث أن العقوبات قد تتراوح بين السجن، الغرامات، وحتى الإعدام في بعض الحالات الخطيرة .""",
"""يجب توضيح نوع العقد، كما يجب اشتمال العقد على كافة البيانات الخاصة بأطرافه المتعاقدة، بعد التأكد من أهلية المتعاقدين، ثم التأكد من صحة الوثائق والمستندات التي سيتم صياغة العقد بناءً عليها، بالإضافة إلي التأكد من عدم مخالفة أي بند من بنود العقد للقوانين والأنظمة المتبعة في المملكة العربية السعودية، ثم التركيز على الحقوق والالتزامات الخاصة بكل طرف وتوضيحها ووصفها بشكل دقيق.""",
"""تشير التصفية إلى عملية ترتيب الوضع المالي للشركة حتى تتمكن من سداد ديونها بعائدات بيع أصولها. تحدث التصفية عادةً عندما تكون الشركة مفلسة أو على وشك الإفلاس، مما يشير إلى أنها عاجزة عن سداد ديونها عند استحقاقها.""",
        ],

###### End ###########





"response": [

    """نعم، يمكن فصل العامل دون إنذار في بعض الحالات المحددة في النظام السعودي للعمل. وفقاً للمادة الثمانون من نظام العمل السعودي بعد التعديل بموجب المرسوم الملكي رقم م 46 وتاريخ 5 6 1436 ه، يجوز لصاحب العمل فسخ العقد دون مكافأة العامل، أو إشعاره، أو تعويضه؛ في الحالات التالية:

1. إذا وقع من العامل اعتداء على صاحب العمل أو المدير المسؤول أو أحد رؤسائه أو مرؤوسيه أثناء العمل أو بسببه.
2. إذا لم يؤد العامل التزاماته الجوهرية المترتبة على عقد العمل أو لم يطع الأوامر المشروعة أو لم يراع عمدا التعليمات.
3. إذا ثبت اتباع العامل سلوكا سيئا، أو ارتكابه عملا مخلا بالشرف أو الأمانة.
4. إذا وقع من العامل عمدا فعل أو تقصير يقصد به الحاق خسارة مادية بصاحب العمل.
5. إذا ثبت أن العامل لجأ إلى التزوير للحصول على العمل.
6. إذا كان العامل معينا تحت الاختبار.
7. إذا تغيب العامل دون سبب مشروع أكثر من ثلاثين يوما خلال السنة العقدية الواحدة أو أكثر من خمسة عشر يوما متتالية.
8. إذا ثبت أن العامل استغل مركزه الوظيفي بطريقة غير مشروعة للحصول على نتائج ومكاسب شخصية.
9. إذا ثبت أن العامل أفشى الأسرار الصناعية أو التجارية الخاصة بالعمل الذي يعمل فيه.

وفي هذه الحالات، يجب على صاحب العمل أن يتيح للعامل الفرصة لكي يبدي أسباب معارضته للفسخ.
""",

    """" الفصل في العمل يعتبر تعسفياً في حالات معينة بحسب نظام العمل السعودي وتحديداً المادة الثالثة والثمانون التي تشير إلى أن الفصل يعتبر تعسفياً في الحالات التالية:

1. إذا لم يكن السبب للفصل متعلقاً بالعامل أو كان خارجاً عن إرادته.

2. إذا كان السبب مباشرة متعلقاً بحالة العامل الفنية أو الصحية نتيجة الإصابة أو المرض.

3. إذا كان العامل قد قدم شكوى أو دعوى ضد صاحب العمل وتعتبر هذه الدعوى سببًا للفصل.

4. إذا كان الفصل نتيجة لأي إجراءات اتخذتها العامل وفقا لحقوقه المنصوص عليها في نظام العمل.

ويجدر بالذكر أن في حالة الفصل التعسفي، يحق للعامل الحصول على تعويض من صاحب العمل يتم حسابه بناءً على الراتب ومدة الخدمة.

وهذا حسب المادة الثالثة والثمانون من نظام العمل في المملكة العربية السعودية.


""",

     """نعم، يحق لصاحب العمل خصم الراتب في بعض الحالات وذلك بناءً على نظام العمل السعودي والمواصفات التالية:

1- استرداد قروض صاحب العمل، مع الشرط أن لا يزيد ما يُحسم من العامل عن 10% من أجره.

2- الاشتراكات في التأمينات الاجتماعية وأي اشتراكات أخرى مستحقة على العامل ومقررة نظامًا.

3- الاشتراكات الخاصة بالعامل في صندوق الادخار والقروض المستحقة للصندوق.

4- الأقساط المتعلقة بأي مشروع يقوم به صاحب العمل لبناء المساكن للعمال أو أي مزايا أخرى.

5- الغرامات التي توقع على العامل بسبب المخالفات التي يرتكبها، وكذلك المبلغ الذي يُقتطع منه مقابل الأضرار التي يتسبب فيها.

6- استيفاء الديون بناءً على حكم قضائي، بحيث لا يزيد ما يُحسم شهريًا عن ربع الأجر المستحق للعامل، إلا إذا كان الحكم يتضمن خلاف ذلك.

ومع ذلك، يجب أن لا يتم الخصم من أجور العامل لقاء حقوق خاصة دون موافقته الخطية، إلا في الحالات المذكورة أعلاه.

هذا المعنى موضح في المادة الثانية والتسعون من نظام العمل السعودي.

""",

    """مدة الإنذار قبل إنهاء العقد تعتمد على نوع العقد والسياق القانوني المطروح:

1- بحسب المادة الحادية والستون من نظام الإفلاس، يجب على الأمين أن يبلغ المتعاقد خطيًا قبل الإنهاء ويكون العقد منقضيًا بعد مرور ثلاثين يومًا من تاريخ التبليغ في الحالات العادية، وتسعين يومًا في حال كان العقد عقد إيجار للعقار الذي يمارس فيه المدين نشاطه.

2- وفقاً للمادة السابعة والثلاثون من اللائحة التنفيذية لنظام الإفلاس، يجب على المدين أن يبلغ المتعاقد بموعد جلسة نظر المحكمة لطلب الإنهاء قبل خمسة أيام على الأقل من موعدها، وبقرار المحكمة بالإنهاء خلال خمسة أيام من تاريخ صدوره إذا لم يحضر المتعاقد الجلسة.

3- في المادة الثانية والثمانون بعد المائة من نظام العمل، يمكن لصاحب العمل إنهاء العقد دون سابق إعلان وبدون تعويض في بعض الحالات المحددة.

لذلك، يتفاوت الإنذار قبل إنهاء العقد حسب السياق القانوني ونوع العقد.
""",

    """حقوق العامل عند انتهاء عقده تشمل العديد من النقاط التي حددتها أنظمة العمل السعودية وهي:

1- يجب على صاحب العمل دفع أجر العامل وتصفية حقوقه خلال أسبوع على الأكثر من تاريخ انتهاء العلاقة العقدية، وإذا كان العامل هو الذي انهى العقد فيجب على صاحب العمل تصفية حقوقه الكاملة خلال مدة لا تزيد على أسبوعين (المادة الثامنة والثمانون).

2- يحق للعامل أن يترك العمل دون إشعار مع احتفاظه بحقوقه النظامية كلها في حالات معينة، مثل عدم وفاء صاحب العمل بالتزاماته العقدية أو النظامية الجوهرية (المادة الحادية والثمانون).

3- يجب على صاحب العمل أن يعطي العامل شهادة خدمة دون مقابل توضح تاريخ بداية ونهاية عمله، والعمل الذي كان يؤديه ومقدار أجره الأخير عندما يطلب العامل ذلك (المادة الرابعة والستون).

4- يجب على صاحب العمل دفع مكافأة للعامل عن مدة خدمته تحسب على أساس أجر نصف شهر عن كل سنة من السنوات الخمس الأولى، وأجر شهر عن كل سنة من السنوات التالية (المادة الرابعة والثمانون).

هذا بناء على نظام العمل الصادر بالمرسوم الملكي رقم (م/51) وتاريخ 23/8/1426هـ.
""",
    """نعم، للعامل حق في الحصول على إجازة سنوية مدفوعة الأجر بناءً على نظام العمل السعودي. النقاط الرئيسية في هذا السياق هي:

1. يستحق العامل إجازة سنوية لا تقل مدتها عن 21 يومًا، وتزيد إلى مدة لا تقل عن 30 يومًا إذا أمضى العامل في خدمة صاحب العمل خمس سنوات متصلة.
2. يجب أن يتمتع العامل بإجازته في سنة استحقاقها، ولا يجوز النزول عنها، أو أن يتقاضى بدلاً نقديًا عوضًا عن الحصول عليها أثناء خدمته.
3. للعامل الحق في الحصول على أجره عن أيام الإجازة المستحقة إذا ترك العمل قبل استعمالها.

هذا ما ورد في المادة التاسعة والعاشرة والحادية عشرة بعد المائة من نظام العمل السعودي.
""",
    """ساعات العمل في المملكة العربية السعودية تخضع لنظام العمل المعمول به وفقاً للمادة 98 والمادة 100 والمادة 188 من هذا النظام. وتتغير الساعات القانونية للعمل بناءً على السياق. وفقاً لهذه المواد، يمكن تلخيص الحد الأقصى لساعات العمل كالتالي:

1. المادة 98: لا يجوز تشغيل العامل أكثر من ثماني ساعات في اليوم الواحد أو أكثر من 48 ساعة في الأسبوع إذا اعتمد صاحب العمل المعيار الأسبوعي. خلال شهر رمضان، تخفض ساعات العمل الفعلية إلى ست ساعات في اليوم أو 36 ساعة في الأسبوع.

2. المادة 100: يمكن لصاحب العمل - بموافقة الوزارة - في المنشآت التي تتطلب طبيعة العمل فيها تناوب العمل، زيادة ساعات العمل على ثماني ساعات في اليوم أو 48 ساعة في الأسبوع، بشرط ألا يتجاوز متوسط ساعات العمل عند حسابه لمدة ثلاثة أسابيع أو أقل على ثماني ساعات يوميا أو 48 ساعة أسبوعيا.

3. المادة 188: لا تزيد ساعات العمل الفعلية التي يمضيها العامل تحت سطح الأرض على سبع ساعات في اليوم. ولا يجوز إبقاء العامل في مكان العمل سواء فوق سطح الأرض أو في باطنها مدة تزيد على عشر ساعات في اليوم.

وفقًا لتلك القواعد، يجب على صاحب العمل الالتزام بتنظيم ساعات العمل وفترات الراحة بحيث لا يعمل العامل أكثر من خمس ساعات متتالية دون فترة للراحة ولا يبقى العامل في مكان العمل أكثر من اثنتي عشرة ساعة في اليوم الواحد (المادة 101).
""",
    """نعم، يمكن للعامل الاستقالة خلال فترة التجربة. وفقاً لنظام العمل السعودي، يتمتع كل من الطرفين (العامل وصاحب العمل) بالحق في إنهاء العقد خلال فترة التجربة. ولكن، يجب الإشارة إلى النقاط التالية:

1. في حال إنهاء العقد خلال فترة التجربة، لا يستحق أي من الطرفين تعويضاً.
2. العامل لا يستحق مكافأة نهاية الخدمة عن فترة التجربة.
3. يجب أن يكون النص على التجربة صريحاً في عقد العمل وتحديدها بوضوح.
4. لا يمكن أن تتجاوز فترة التجربة تسعين يوماً، ولكن باستثناءات محددة يمكن تمديدها لتصل إلى مائة وثمانين يومًا.

وفقًا للمادة الرابعة والخمسون والمادة الثالثة والخمسون من نظام العمل في المملكة العربية السعودية.
""",
    """تعويض المادة السابعة والسبعون من نظام العمل في السعودية يحسب بناءً على النص المذكور، والذي يقدم التوجيهات التالية:

1. إذا كان العقد غير محدد المدة، يحسب التعويض بمعدل أجر 15 يوماً لكل سنة خدمة للعامل.

2. إذا كان العقد محدد المدة، يحسب التعويض بناءً على الأجر المتوقع للمدة المتبقية من العقد.

3. بغض النظر عن نوع العقد، لا يجب أن يقل التعويض المستحق عن أجر العامل لمدة شهرين على الأقل.

هذه الحسابات تكون مباشرة وواضحة في حالة الأجر الثابت، ولكن في حالة الأجر المتغير، قد يتم استخدام متوسط الأجر الشهري خلال الفترة السابقة لتحديد قيمة الأجر.

وفي حالة الإنهاء غير المشروع للعقد، يحق للطرف المتضرر الحصول على تعويض يحدده هيئة تسوية الخلافات العمالية، ويتم النظر في الأضرار المادية والأدبية التي لحقت بالطرف المتضرر، بالإضافة إلى الظروف المحيطة بالإنهاء.

هذه النقاط تستند إلى المادة السابعة والسبعون من نظام العمل بعد التعديل بموجب المرسوم الملكي رقم م 46 وتاريخ 5 6 1436 هـ.
""",
"""نعم، للموظف الحق في الاطلاع على لائحة العمل وفقا للأنظمة السعودية. وهذا الحق مدرج ضمن حقوق العامل والمفتشين في العمل، حيث يتضمن نظام العمل السعودي في المادة الثامنة والتسعين بعد المائة الحقوق التالية:

1- يحق للمفتشين دخول أي منشأة خاضعة لأحكام نظام العمل في أي وقت من أوقات النهار أو الليل، دون إشعار سابق.

2- القيام بأي فحص أو تحقيق لازم للتحقق من سلامة تنفيذ النظام.

3- لهم الحق في الاطلاع على جميع الدفاتر والسجلات والوثائق الأخرى اللازم الاحتفاظ بها طبقا لأحكام نظام العمل والقرارات الصادرة بمقتضاه، والحصول على صور ومستخرجات منها.

4- أخذ عينة أو عينات من المواد المستعملة أو المتداولة في العمليات الصناعية وغيرها الخاضعة للتفتيش، مما يظن أن لها تأثيرا ضارا على صحة العمال أو سلامتهم، وذلك لغرض تحليلها في المختبرات الحكومية، ولمعرفة مدى هذا التأثير، مع إبلاغ صاحب العمل أو ممثله بذلك.

وهذا وفقا لنظام العمل السعودي، المادة الثامنة والتسعين بعد المائة.
""",

"""الآلية لرفع دعوى في المملكة العربية السعودية تتألف من عدة خطوات حسب النظم القانونية السعودية، وهي كما يلي:

1- تقديم الدعوى: يتم تقديم الدعوى من خلال المدعي العام، وذلك بعد موافقة الملك، كما هو مبين في المادة الرابعة من نظام المرافعات الشرعية.

2- الاستجابة للدعوى: بعد مضي ستين يوما من تاريخ نشوء الحق المدعى به، يتم الاستماع للدعوى.

3- النظر في الدعوى: تختص محاكم المملكة بنظر الدعاوى التي ترفع على السعودي ولو لم يكن له محل إقامة عام ومختار في المملكة، باستثناء الدعاوى العينية المتعلقة بعقار خارج المملكة، حسب المادة الرابعة والعشرين من نظام المرافعات الشرعية.

4- رفع الدعوى التأديبية: ترفع الدعوى التأديبية بمذكرة تشتمل على التهمة الموجهة والأدلة المؤيدة لها، وتقدم إلى مجلس التأديب ليصدر قراره، بدعوة المتهم بالحضور أمام المجلس، وفقا للمادة الثامنة عشرة من نظام هيئة التحقيق والادعاء العام (نظام النيابة العامة).

وفي حالة تنفيذ حكم التحكيم، يجب الالتزام بالشروط المبينة في المادة الخامسة والخمسون من نظام التحكيم.

أرجو أن تكون هذه المعلومات مفيدة. في حال كان لديك أي أسئلة أخرى، فلا تتردد في طرحها.
""",
"""المسؤول في رفع الدعوى لدى المحاكم السعودية يعتمد على نوع الدعوى والأطراف المشتركة فيها. وفقا للمواد التي قدمت، يمكن تحديد المسؤولين على النحو التالي:

1. في حالة الدعاوي التي ترفع ضد غير السعودي الذي ليس له مكان إقامة في المملكة، فإن المحاكم السعودية تختص بنظر هذه الدعوى وفقًا للمادة السادسة والعشرون من نظام المرافعات الشرعية.

2. بالنسبة للدعاوي التي ترفع ضد السعوديين ولو لم يكن لديهم مكان إقامة في المملكة، فإن المحاكم السعودية تختص أيضا بنظر هذه الدعوى وفقا للمادة الرابعة والعشرون من نظام المرافعات الشرعية.

3. بالنسبة لدعاوى التعويض الناجمة عن الأضرار التي تسببها الطائرات، فإن ديوان المظالم هو المختص بنظر هذه الدعاوى وفقا للمادة الحادية والخمسون بعد المائة من نظام الطيران المدني.

4. أما بالنسبة للدعاوي التأديبية ضد المحامين، فقد تغيرت القواعد حسب التعديل الأخير للمادة الثلاثون من نظام المحاماة، حيث يصبح وزير العدل هو المسؤول عن تحديد قواعد وإجراءات الضبط ورفع الدعوى التأديبية ونظرها.
""",
"""أتعاب المحاماة في المملكة العربية السعودية تحدد بناءً على عدة قواعد وأنظمة:

1. الاتفاق بين المحامي والموكل: كما هو موضح في المادة السادسة والعشرون من نظام المحاماة، تحدد أتعاب المحامي وطريقة دفعها باتفاق يعقده مع موكله. يمكن للمحامي والموكل الاتفاق بحرية على مبلغ معين وطريقة الدفع.

2. قيمة الجهد المبذول من قبل المحامي: في حالة عدم وجود اتفاق أو إذا كان الاتفاق غير صالح أو تم فسخه، فإن المحكمة التي تنظر في القضية تقدر أتعاب المحامي على أساس الجهد الذي بذله المحامي، كما هو موضح في المادة الثامنة والعشرون من نظام المحاماة.

3. النفع الذي عاد على الموكل: يتم أيضاً أخذ النفع الذي عاد على الموكل في الاعتبار عند تحديد أتعاب المحامي.

4. الدفاع القانوني المجاني: كما هو موضح في المادة السابعة والتسعون من اللائحة التنفيذية لنظام الإجراءات الجزائية، للمحامي المندوب الحق في تقديم شهادة حضوره لكل جلسة للدفاع عن المتهم لتقديمها إلى الوزارة لصرف أتعابه، ولكنه لا يجوز له أن يتقاضى أي مقابل من المتهم.

الرجاء الرجوع إلى الأنظمة المذكورة لمزيد من التفاصيل والمعلومات.
""",
"""لجنة المنازعات المصرفية في السعودية لها صلاحيات محددة تشمل:

1. الفصل في المنازعات والخلافات بين البنوك والعملاء، أو بين البنوك نفسها.
2. الفصل في الشكاوى المقدمة من العملاء ضد البنوك.
3. الفصل في قضايا الاحتيال المصرفي والتزوير.
4. تقديم توصيات لتحسين الأنظمة والتشريعات المصرفية.
5. التحقق من تطبيق البنوك لتعليمات وقواعد البنك المركزي السعودي والتأكد من الامتثال لها.

تم تحديد هذه الصلاحيات في نظام البنك المركزي السعودي وتحديداً المادة الثامنة عشرة من النظام.
""",
"""فتح سجل تجاري في المملكة العربية السعودية يتطلب عدة خطوات وفقا للأنظمة السعودية. هنا هي الخطوات الأساسية التي يجب اتباعها:

1. اختيار الاسم التجاري: يجب عليك اتخاذ اسم تجاري وقيده في السجل التجاري كما هو موضح في المادة الثالثة من نظام الأسماء التجارية. يمكنك حجز الاسم التجاري لفترة مؤقتة لدى المسجل دون قيده في السجل التجاري.

2. تكوين الاسم التجاري: يمكن أن يتكون الاسم التجاري من اسمك الشخصي أو من اسم مميز أو منهما معا وهذا وفقا للمادة الرابعة من نظام الأسماء التجارية.

3. طلب حجز الاسم التجاري أو قيده: يجب تقديم طلب حجز الاسم التجاري أو قيده إلى المسجل، وفقا للمادة الخامسة من نظام الأسماء التجارية.

4. البت في طلبك: سيبت المسجل في طلبك خلال عشرة أيام من تاريخ تقديمه. إذا تم قبول طلبك، سيتم نشر الاسم التجاري المقبول حجزه أو قيده.

5. الالتزام بالقوانين: عليك الالتزام بجميع القوانين والأنظمة السعودية المتعلقة بتشغيل الأعمال التجارية.

إذا كنت محاميا أجنبيا وترغب في ممارسة مهنة المحاماة في المملكة، يجب عليك اتباع الشكلين المذكورين في المادة الخمسون من نظام المحاماة.

الرجاء الرجوع إلى نظام الأسماء التجارية (المادة الثالثة والرابعة والخامسة) ونظام المحاماة (المادة الخمسون) للمزيد من المعلومات.
""",

"""تأسيس فرع لشركة أجنبية في المملكة العربية السعودية يتطلب العديد من الخطوات والشروط التي يجب استيفائها وفقا للأنظمة السعودية. وتتلخص هذه الشروط والخطوات كالتالي:

1. الشركة الأجنبية يجب أن تقوم بممارسة نشاطها وأعمالها داخل المملكة من خلال فرع أو مكتب تمثيل أو أي شكل آخر، وذلك وفقا لأحكام نظام الاستثمار الأجنبي والأحكام النظامية الأخرى المتعلقة (المادة السادسة والثلاثون بعد المائتين من نظام الشركات).

2. يعد فرع الشركة الأجنبية أو مكتب تمثيلها داخل المملكة موطنا لها فيما يتعلق بنشاطها وأعمالها داخل المملكة، ويجب أن تطبق عليه جميع الأنظمة المعمول بها في المملكة (المادة التاسعة والثلاثون بعد المائتين من نظام الشركات).

3. يجب تقديم طلب للحصول على ترخيص لمزاولة الأعمال المصرفية في المملكة إلى المؤسسة المختصة، والتي ستقوم بدراسة الطلب وتقديم توصياتها بشأنه لوزير المالية والاقتصاد الوطني (المادة الثالثة من نظام مراقبة البنوك).

4. يجب استيفاء الشروط التي يحددها مجلس الوزراء بناء على اقتراح وزير المالية والاقتصاد الوطني للحصول على الترخيص لتأسيس فرع أو فروع للبنك الأجنبي في المملكة (المادة الثالثة من نظام مراقبة البنوك).

الرجاء ملاحظة أن هذه الشروط تختلف اعتمادًا على نوع الشركة وطبيعة النشاط الذي تعتزم ممارسته. لذا، ينصح بالتواصل مع محامي محلي أو مستشار قانوني للحصول على المشورة المناسبة وفقا للسياق الخاص بالشركة.
""",
"""وثيقة التأمين الشامل للمركبات هي وثيقة تأمين تغطي جميع التلفيات والأضرار التي يمكن أن تحدث للمركبة، سواء كانت ناتجة عن حادث اصطدام أو سرقة أو حريق أو أي أضرار أخرى.

تتضمن وثيقة التأمين الشامل على النقاط التالية:
1. تاريخ عقد التأمين ومكانه.
2. اسم المؤمن والمؤمن له وموطنيهما.
3. محل التأمين.
4. وصف التغطية التأمينية وحدودها واستثناءاتها ومدتها ونطاقها الجغرافي.
5. مبلغ التأمين وقسطه.
6. أي بيان أخر يحدده اللوائح.

وهذا يتوافق مع المادة الرابعة والتسعين بعد المائتين من النظام البحري التجاري.
""",
"""وثيقة التأمين الإلزامي للمركبات هي وثيقة تُبرم بين صاحب المركبة وشركة التأمين، وتتضمن التغطية الضرورية للتكاليف التي قد تنشأ عن الأضرار التي قد تلحق بالأطراف الثالثة كنتيجة لحوادث المرور التي قد يتسبب فيها صاحب المركبة.

وفقًا للنظام السعودي، هناك بعض النقاط الأساسية المتعلقة بوثيقة التأمين الإلزامي، وهي:

1. لا يجوز تسيير المركبات قبل الحصول على وثيقة التأمين.
2. يجب أن تكون الوثيقة سارية المفعول.
3. يجب أن تكون الوثيقة صادرة من شركة تأمين مرخص لها العمل في المملكة.
4. تغطي وثيقة التأمين الإلزامي الأضرار التي قد تلحق بالأطراف الثالثة نتيجة لحوادث المرور.
5. الالتزام بتجديد وثيقة التأمين عند انتهاء صلاحيتها.

ويمكن الاستعانة بهذه المعلومات من المادة الثامنة من نظام المرور السعودي.
""",

"""وفقاً للأنظمة السعودية، يمكنك تقديم طلب لإعادة النظر في الحكم القضائي إذا كانت لديك أدلة جديدة قوية، مثل الأوراق التي ذكرت. ولكن يجب أن تعرف أن هذا الإجراء ليس بسيطاً ويتطلب تلبية مجموعة من الشروط والأحكام.

التفاصيل الدقيقة لهذا الإجراء قد تختلف بناءً على طبيعة القضية، ولكن عادة ما تشمل الخطوات التالية:

1. تقديم طلب للمحكمة التي أصدرت الحكم، مشيراً فيه إلى الأدلة الجديدة التي ظهرت بعد صدور الحكم.
2. تقديم الأوراق أو الأدلة الجديدة التي تدعم طلبك.
3. يجب أن تكون الأدلة التي تقدمها قوية بما فيه الكفاية لتغيير الحكم، وليس مجرد تأكيد للأدلة التي تم عرضها بالفعل.

يرجى ملاحظة أن هذه العملية يجب أن تتم في إطار القانون ومع مراعاة جميع القواعد والأنظمة القانونية. وقد يكون من الجيد الحصول على المشورة القانونية من محامٍ قبل الشروع في هذه العملية.

فيما يتعلق بالانظمة المرجعية، النظام الأساسي للحكم في المملكة العربية السعودية، وبخاصة المواد 70 و 71 و 82، تشير إلى الطرق التي يمكن من خلالها تقديم الانظمة وتعديلها ونشرها، بالإضافة إلى القيود المفروضة على تعطيل تنفيذ هذه الأحكام. والمادة الخامسة والعشرون من نظام هيئة البيعة تتعلق بتعديل أحكام هذا النظام بأمر ملكي.
""",
"""في حال وجود أخطاء في صك الحكم، تتبع الإجراءات التالية:

1. يمكن تقديم طلب للمحكمة لتصحيح الأخطاء المادية البحتة الكتابية أو الحسابية في الصك، كما هو موضح في المادة الحادية والسبعون بعد المائة من نظام المرافعات الشرعية.

2. في حال كانت الأخطاء تتعلق بالسهو أو النواقص التي لم تؤثر في نفس الحكم ولا متعلقاته، يمكن للهيئة إعادة الصك إلى المحكمة لتصحيح النواقص، وفقاً للمادة (548) من النظام التجاري (نظام المحكمة التجارية).

3. في حالة تعدد الأحكام في الصك، يجب على الهيئة التدقيق في كل الأحكام وإعطاء قرارها نحو كل حكم منها بالتصديق أو النقض، حسب المادة (24) من نظام تركيز مسؤوليات القضاء الشرعي.

4. في حالة فقدان سجل الصك أو تلفه، يمكن إعادة تسجيله إذا طابق الصك أساسه المستند إليه، وفقاً للمادة الخامسة والأربعون من نظام التوثيق.

هذه الإجراءات تتوافق مع المواد المشار إليها في أنظمة المملكة العربية السعودية.
""",
"""المرافعة في الأنظمة السعودية تتم كتابيًا بحسب المادة الخامسة والستون من نظام المرافعات الشرعية بعد أن تم تعديلها بموجب المرسوم الملكي رقم م/78 وتاريخ 1442/9/10هـ. التعديل جاء كالتالي:

1. تكون إجراءات نظر الدعوى والمرافعة فيها كتابية. وللمحكمة - من تلقاء نفسها أو بناءً على طلب أحد الخصوم - أن تسمع ما لدي الأطراف مشافهة. وتثبت المحكمة ذلك في محضر الجلسة.

2. على المحكمة أن تعطي الخصوم المهل المناسبة، للاطلاع على المستندات، كلما اقتضت الحال ذلك.

ومع ذلك، يتم السماح بالمرافعة الشفهية في بعض الأحيان، حيث يمكن للمحكمة أن تسمع ما لدى الأطراف مشافهة إذا رأت ذلك مناسبًا أو بناءً على طلب من أحد الخصوم.

المادة المشار إليها هي المادة الخامسة والستون من نظام المرافعات الشرعية بعد التعديل.
""",
"""الاستفادة من الوقف تتطلب العديد من الخطوات والإجراءات القانونية بناءً على الأنظمة السعودية، وبناءً على السياق المقدم، يمكنك اتباع الخطوات التالية:

1. التأكد من طبيعة الوقف: يجب معرفة طبيعة الوقف والنصوص النظامية الخاصة به، وذلك وفقا للمادة الثامنة والتسعون بعد الستمائة من نظام المعاملات المدنية.

2. التحقق من الحق في الانتفاع: بناءً على المادة الثالثة والتسعون بعد الستمائة من نظام المعاملات المدنية، فإنه لا يسمع دعوى المطالبة بحق الانتفاع إذا انقضت عليه عدم استعماله مدة عشر سنوات.

3. استغلال ثمار الوقف: في حال كان لديك حق الانتفاع، فإن ثمار الشيء المنتفع به من حق المنتفع مدة انتفاعه، وفقاً للمادة الثانية والثمانون بعد الستمائة من نظام المعاملات المدنية.

4. اللجوء إلى القضاء: في حال وجود أي صعوبات أو نزاعات، يجوز للمحكمة المختصة - لاعتبارات تقدرها - وقف تنفيذ العقوبة المحكوم بها، وفقاً للمادة الثانية والثمانون من نظام المرور.

تذكر، يجب استشارة المختصين القانونيين أو المحامين للحصول على مشورة قانونية دقيقة وواضحة.
""",
"""المكتب يتعامل مع العديد من القضايا القانونية التي تواجه الأفراد والشركات، وذلك وفقًا لما هو متاح في القانون السعودي. وهذه القضايا تشمل:

1. قضايا الترافع: يتم الترافع عن الغير أمام المحاكم وديوان المظالم واللجان المشكلة بموجب الأنظمة والأوامر والقرارات لنظر القضايا الداخلة في اختصاصها كما ينص عليها النظام في المادة الأولى.

2. الاستشارات الشرعية والنظامية: يتم تقديم الاستشارات القانونية والشرعية للأفراد والشركات تبعًا للقانون السعودي.

3. قضايا الشرف والكرامة: يتعامل المكتب أيضاً مع القضايا التي تتعلق بالشرف والكرامة، وذلك حسب ما هو موضح في المادة الثانية عشرة من نظام المحاماة.

4. القضايا التي تتطلب الخبرة: يمكن للمكتب التعامل مع القضايا التي تتطلب خبرة معينة، مثل القضايا التي يتم تقديم الرأي فيها بصفة خبير، وفقاً للمادة السابعة عشرة من نظام المحاماة.

لكن يجب الانتباه إلى أن هذه القضايا يجب ألا تتعارض مع طبيعة ونوع الترخيص الذي أصدر للمكتب، كما هو موضح في المادة الخامسة والخمسون من نظام المحاماة.

المصدر: نظام المحاماة، المادة الأولى، الثانية عشرة، السابعة عشرة، الخامسة والخمسون.
""",
"""المدة المطلوبة لتنفيذ قرار في قضية عمالية تعتمد على الظروف المحددة للقضية. وفقاً للمادة 72 من نظام العمل في المملكة العربية السعودية، يتم إعلام العامل بالقرار الخاص بتوقيع الجزاء عليه كتابياً, وإذا امتنع عن الاستلام أو كان غائباً، فيتم إرسال الإشعار إلى عنوانه المسجل في الملف.

بعد استلام القرار، للعامل حق التظلم لدى الجهة المختصة لدى صاحب العمل خلال 30 يوماً - باستثناء أيام العطل الرسمية - من تاريخ إبلاغه بالقرار. إذا تم رفض التظلم أو لم يتم البت فيه خلال 15 يومًا من تقديمه، يحق للعامل الاعتراض أمام المحاكم العمالية على القرار الخاص بتوقيع الجزاء عليه خلال 30 يوماً - باستثناء أيام العطل الرسمية - من تاريخ رفض التظلم أو انتهاء المدة المحددة للبت في التظلم، أيهما أقرب.

هذا وفقاً للمادة 72 من نظام العمل بعد التعديل الذي صدر بالمرسوم الملكي رقم م44 وتاريخ 144628ه والذي يعمل به من تاريخ 1446820ه.
""",
"""وفقاً للنص الذي قدمت، يجب أن يتم رفع إيقاف الخدمات تلقائياً من خلال الربط الإلكتروني بين المنصة الإلكترونية والجهة الحكومية طالبة الإيقاف، وذلك خلال مدة لا تتجاوز 24 ساعة من الموافقة على إلغاء إيقاف الخدمات.

هذا وفقاً للضوابط المذكورة في السياق المقدم، ورغم أنه لم يتم ذكر رقم المادة أو النظام الذي يتم الاستناد إليه، فإنه يمكن القول أن هذه الضوابط تتعلق بإيقاف الخدمات الحكومية في المملكة العربية السعودية.
""",
"""الجواب على سؤالك يعتمد على النظام المعتمد في الهيئة المقدمة للخدمة. بشكل عام، لا يوجد وقت محدد في الأنظمة السعودية للرد على الاستشارة القانونية. ولكن بناءً على الممارسة العامة، يتم الرد على الاستشارات القانونية في غضون أيام قليلة إلى أسبوعين، حسب تعقيد الاستشارة والهيئة المعنية.

من الجدير بالذكر أن الأنظمة المذكورة في السياق تتعلق بأمور محددة مثل التحقيقات الجنائية، ورد الخبير، والطلبات المستعجلة والاعتراض على القرارات الغيابية، وهي لا تنطبق بشكل مباشر على الاستشارات القانونية.

في كل الأحوال، ينصح دائماً بالتواصل مع المحامي أو الهيئة القانونية المعنية للحصول على معلومات أكثر دقة حول الجدول الزمني المتوقع للرد على الاستشارة القانونية.
""",
""""تأسيس الشركة المهنية المختلطة في النظام السعودي يتطلب العديد من الشروط والضوابط التي يمكن تلخيصها فيما يلي:

1. يجب أن يكون المؤسسون أشخاص مرخص لهم في ممارسة مهنة حرة واحدة أو أكثر حسبما ورد في المادة المائتان من نظام الشركات.

2. يمكن لشخص مرخص له في ممارسة مهنة حرة واحدة أن يؤسس شركة مهنية مساهمة أو مساهمة مبسطة أو ذات مسؤولية محدودة من شخص واحد لممارسة مهنته من خلالها.

3. يمكن أن يشارك في الشركة المهنية - عدا شركة التضامن وشركة التوصية البسيطة بصفة الشريك المتضامن - شخص ذو صفة طبيعية من غير المرخص لهم بممارسة المهنة أو المهن الحرة محل نشاطها، أو شخص ذو صفة اعتبارية.

4. يجب أن تستوفى الشروط والضوابط التي تحددها اللوائح كما ورد في المادة المائتان من نظام الشركات.

5. يجب أن تتم مراعاة القواعد العامة لإدارة هذا النوع من الشركات المهنية بما يصون استقلال الشركاء أو المساهمين المهنيين في ممارسة مهنتهم حسبما ورد في المادة المائتان من نظام الشركات.

6. يجب أن يتم تأسيس الشركة المهنية وفقا لإجراءات التأسيس المقررة لشكل الشركة كما ورد في المادة الثانية بعد المائتين من نظام الشركات.

الاستناد: نظام الشركات السعودي - المادة المائتان والمادة الثانية بعد المائتين.
""",
 """تحويل المؤسسة إلى شركة يتم وفقًا لأحكام نظام الشركات في المملكة العربية السعودية وتتضمن الخطوات التالية:

1. القرار بالتحول: يجب أن يكون هناك قرار من صاحب المؤسسة بتحويلها إلى شركة.

2. استيفاء الشروط: يجب استيفاء شروط التأسيس والقيد والشهر المقررة للشكل الذي سيتم التحول إليه.

3. نقل الأصول: يمكن لصاحب المؤسسة نقل أصوله إلى أي شكل من أشكال الشركات التي سيتم تأسيسها بناءً على أحكام النظام.

4. الديون والتزامات: لا يترتب على التأسيس إبراء ذمة أصحاب المؤسسات الفردية من مسؤولياتهم عن الديون والتزامات المؤسسات الفردية السابقة، إلا في حال قبول الدائنين ذلك صراحة.

5. التسجيل في السجل التجاري: يجب قيد الشركة الجديدة في السجل التجاري لتصبح مؤسسة تأسيساً صحيحاً.

النظام المستند إليه هو نظام الشركات في المملكة العربية السعودية وهذا يشمل المادة العشرون بعد المائتين، المادة الحادية والعشرون بعد المائتين، المادة الخامسة عشرة بعد المائتين، والمادة الخامسة والستون من نظام الشركات.
""",
"""شهادة المنشأ هي وثيقة تثبت أن سلعة محددة تم إنتاجها أو تصنيعها في دولة معينة. هذه الشهادة تحتاج عادة عند التصدير إلى دول أخرى. في المملكة العربية السعودية، يجب توفر الشروط الأتية للحصول على شهادة المنشأ:

1. يجب أن يكون الشركة أو المؤسسة المصدرة مسجلة في الغرفة التجارية.
2. يجب أن تكون السلع المصدرة قد تم إنتاجها أو تصنيعها في المملكة العربية السعودية.
3. يجب تقديم الفواتير التجارية المتعلقة بالسلع التي ستصدر.
4. يجب أن تكون السلع المصدرة مطابقة للمعايير واللوائح المحلية والدولية.
5. يجب تقديم طلب رسمي للحصول على شهادة المنشأ من الغرفة التجارية.

الرجاء العلم أن هذه الشروط قد تختلف بناءً على القوانين واللوائح المحلية والدولية وتحديداً تلك المتعلقة بالتجارة الدولية والتصدير. لذا، يفضل استشارة محام أو مستشار قانوني للحصول على المعلومات الدقيقة والمحدثة. لا يوجد نظام معين أو مادة تتعلق بشهادة المنشأ في الأنظمة السعودية المشار إليها في السياق المقدم.
""",

"""تكلفة الرسوم الحكومية لتسجيل علامة تجارية في المملكة العربية السعودية حسب نظام العلامات التجارية تتضمن:

1. الف ريال لتقديم طلب تسجيل علامة تجارية عن فئة واحدة.

2. ثلاثة آلاف ريال لتسجيل العلامة التجارية عن فئة واحدة.

وبالتالي، تكلفة تسجيل العلامة التجارية تكون بمجموع 4000 ريال سعودي. هذا يتضمن رسوم تقديم الطلب ورسوم التسجيل نفسه.

(المرجع: نظام العلامات التجارية، المادة الحادية والأربعون)
""",

"""لا، المحاكم التجارية لا تختص بالنظر في دعاوى العقار. وذلك وفقا للأنظمة السعودية، حيث يمكن توضيح الأمر كالتالي:

1. وفقا للمادة الحادية والثلاثون من نظام المرافعات الشرعية، فإن المحاكم العامة هي التي تختص بنظر الدعاوى المتعلقة بالعقار.

2. وفقا للمادة الثالثة من النظام التجاري (نظام المحكمة التجارية)، فإن بيع الأرض أو العقار لا يعتبر عملاً تجاريًا، وبالتالي لا تختص المحاكم التجارية بالنظر في دعاوى العقارات والإيجارات.

3. وفقا للمادة الخامسة والثلاثون من نظام المرافعات الشرعية، المحاكم التجارية تختص بنظر المنازعات التجارية بين التجار والدعاوى المتعلقة بالأعمال التجارية الأصلية والتبعية.

4. وفقا للمادة التاسعة والثمانين من نظام المحاكم التجارية، فيما لم يرد فيه نص خاص في النظام، تطبق أحكام نظام المرافعات الشرعية على الدعاوى التي تختص بنظرها المحكمة بما لا يخالف طبيعة الدعوى التجارية.

وبناء على الأنظمة المذكورة أعلاه، يمكن القول بأن المحاكم التجارية لا تتعامل مع دعاوى العقار. وتم الاستناد في هذا الرد إلى نظام المرافعات الشرعية (المادة 31 و 35)، والنظام التجاري (المادة 3)، ونظام المحاكم التجارية (المادة 93).
""",

"""يتبع حجز الاسم التجاري في المملكة العربية السعودية عدة خطوات وفقًا للنظام السعودي للأسماء التجارية، وهي:

1. تقديم طلب: يجب على الشخص المعني تقديم طلب حجز الاسم التجاري إلى المسجل، والذي يتضمن البيانات المطلوبة وفقًا للائحة النظام.

2. مراجعة الطلب: بعد تقديم الطلب، يتم مراجعته من قبل المسجل خلال عشرة أيام من تاريخ تقديمه. وفي بعض الحالات التي تحددها اللائحة، يمكن تمديد هذه المدة.

3. الإعلان عن الطلب: بعد القبول، يتم الإعلان عن الاسم التجاري المحجوز أو المقيد في الوسيلة التي تحددها اللائحة.

4. الدفع: يتحمل طالب الحجز أو القيد المقابل المالي للإعلان، إن وجد.

5. الأولوية: في حال وجود أكثر من طلب لحجز أو قيد اسم تجاري معين، يتم منح الأولوية للأسبق في تقديم الطلب.

6. الطعن: في حالة رفض الطلب، يحق للطالب الاعتراض أمام الوزارة خلال ستين يومًا من تاريخ إبلاغه بالرفض.

يمكن العثور على هذه التفاصيل في المادة الخامسة من نظام الأسماء التجارية في المملكة العربية السعودية.""",

"""مدة حماية العلامة التجارية في نظام العلامات التجارية لدول مجلس التعاون لدول الخليج العربية تستمر لمدة عشر سنوات، ويمكن لصاحب الحق، إذا رغب في استمرار الحماية، تقديم طلب تجديد خلال السنة الأخيرة من مدة الحماية، وفقاً للشروط المنصوص عليها في النظام ولائحته التنفيذية. وفي حال عدم تجديد التسجيل خلال الأشهر الست التالية لانتهاء مدة التسجيل، يتم شطب العلامة التجارية من السجل بواسطة الجهة المختصة.

وعند تجديد التسجيل، يتم ذلك دون أي فحص جديد، ويتم الإعلان عنه بالوسيلة التي تحددها اللائحة التنفيذية للنظام، ودون الأخذ بأي اعتراض من الغير.

وفي حالة شطب العلامة التجارية، لا يجوز تسجيلها لصالح الآخرين على المنتجات نفسها أو الخدمات أو على منتجات أو خدمات مشابهة إلا بعد ثلاث سنوات من تاريخ الشطب، إلا إذا نص قرار الشطب على مدة أقل.

وصاحب العلامة التجارية يحق له أن يتخذ الإجراءات المتعلقة بمطالبة المدعي السيئ النية بالتعويض الذي قد يستحق له نتيجة لاتخاذه للإجراءات المنصوص عليها في النظام.

هذا وفقا للمادة 20، المادة 22، المادة 27، و المادة 51 من نظام العلامات التجارية لدول مجلس التعاون لدول الخليج العربية.""",

"""نعم، استخراج الوكالة في المملكة العربية السعودية يحتاج إلى حجز موعد مسبق، وذلك من خلال الخطوات التالية:

1. الدخول على وكالة الوزارة للشؤون القانونية (وزارة العدل) عبر الرابط الإلكتروني.
2. تسجيل الدخول إلى الحساب الشخصي على البوابة.
3. اختيار "الخدمات الإلكترونية" ثم "حجز موعد".
4. اختيار نوع الخدمة المراد الحصول عليها، وفي هذه الحالة هي "وكالة".
5. اختيار التاريخ المناسب للموعد والتأكيد على ذلك.

يجب العلم أن الحجز المبكر للموعد يضمن سرعة الحصول على الوكالة وذلك لأنها تعتبر من الخدمات المطلوبة بكثرة.

يمكن الرجوع إلى المادة 481 من نظام المعاملات المدنية التي تناولت الوكالة في توضيحها لشكل الوكالة والشروط المتعلقة بها.
""",

"""نعم، استخراج الوكالة في المملكة العربية السعودية يتطلب تحديد موعد مسبق، وهذا الأمر يتم عبر نظام "مواعيد" الذي أطلقته وزارة العدل السعودية. يمكن للمستخدمين الدخول إلى النظام وتحديد الموعد المناسب لهم لزيارة المحكمة أو الدائرة القضائية المعنية لاستخراج الوكالة. يهدف هذا النظام إلى تسهيل الإجراءات والتقليل من الزحام في المحاكم والدوائر القضائية.

لكن يجب الإشارة إلى أن السؤال غير متعلق مباشرة بالنصوص القانونية المذكورة في السياق، حيث أن هذه النصوص تتعلق بأحكام وشروط الوكالة والشركات، وليس بإجراءات استخراج الوكالة.
""",

"""السؤال المطروح ليس له علاقة بالمواد القانونية المقدمة في السياق. ولكن بشكل عام، في المملكة العربية السعودية، يتطلب استخراج الوكالة القانونية التوجه إلى ديوان الوكالات في وزارة العدل وتقديم الطلب المناسب. قد يتم ذلك عبر النظام الإلكتروني للوزارة، وفي بعض الأحيان، سيكون من الأفضل حجز موعد مسبق لتسهيل الإجراءات وتجنب الانتظار. يتوجب على الشخص المراد منحه الوكالة الحضور شخصياً إلى ديوان الوكالات أيضًا.

يرجى الرجوع إلى الموقع الرسمي لوزارة العدل السعودية أو الاتصال بالوزارة مباشرة للحصول على المعلومات الأكثر دقة وتحديثاً حول الإجراءات المطلوبة لاستخراج الوكالة.
""",
"""تتنوع تكاليف الخدمات القانونية في السعودية بناءً على نوع الخدمة المطلوبة والموضوع الذي تتعلق به الدعوى، وهذا ما يتضح من خلال النظام واللوائح التي ذكرت:

1. حسب المادة السابعة من اللائحة التنفيذية لنظام التكاليف القضائية، تكون التكاليف على النحو التالي:
   - طلب ذي المصلحه تسليمه نسخه مصدقه من اوراق الدعوي أو سجلاتها أو الوثائق أو الاوراق التي تحت يد المحكمه؛ 100 ريال.
   - طلب ذي المصلحه الاطلاع على اوراق الدعوى أو سجلاتها؛ 50 ريال.
   - طلب نسخة بديلة للوثائق القضائية؛ 100 ريال.

2. وفقاً للمادة الثالثة من اللائحة التنفيذية لنظام التكاليف القضائية، تتراوح تكاليف الدعاوى غير المحددة القيمة بين 1,000 ريال للدعاوى المحكمة العمالية و10,000 ريال للدعاوى الجزائية الخاصة.

3. بناءً على المادة الثانية من اللائحة التنفيذية لنظام التكاليف القضائية، التكاليف القضائية للدعاوى المحددة القيمة يتم تقديرها على أساس نسبة من قيمة المطالبة في الدعوى، وتتراوح هذه النسب بين 2% إلى 5% بناءً على قيمة المطالبة.

4. وفقاً للمادة الثامنة من نظام التكاليف القضائية، تكلفة بعض الطلبات المحددة لا تتجاوز 1,000 ريال.

هذه التكاليف تعتمد على النظام واللائحة التنفيذية لنظام التكاليف القضائية في السعودية.

""",
"""سيتم اطلاعك على سير قضيتك بناءً على النظام والمادة التي تتطبق على حالتك.

1. إذا كنت دائنًا في حالة إفلاس، فستتمكن من الاطلاع على تقرير دوري عن سير إجراء التصفية كل ثلاثة أشهر على الأقل، كما هو مذكور في المادة الخامسة عشرة بعد المائة من نظام الإفلاس.

2. في حالة التحقيقات الجزائية، يجب على المحقق أن يبلغك بأوامره وقراراته بشأن التحقيق الذي يجريه خلال ثلاثة أيام من تاريخ صدورها، وذلك حسب المادة الرابعة والسبعون من نظام الإجراءات الجزائية.

3. في حالة المرافعات الشرعية، يجب على الخبير أن يودع تقريره والأوراق المرتبطة بالقضية في إدارة المحكمة وأن يبلغك بذلك في غضون 24 ساعة من الإيداع، كما هو مذكور في المادة السادسة والثلاثون بعد المائة من نظام المرافعات الشرعية.

4. أما إذا كنت الشخص الذي يتم التحقيق معه، فيجب على المحقق أن يبلغك بأمر الحضور قبل 24 ساعة على الأقل من موعد التحقيق، ما لم يستدع الأمر الاستعجال، وفقًا للمادة الخامسة والسبعون من اللائحة التنفيذية لنظام الإجراءات الجزائية.
""",
"""تطوير وتسويق الخدمات القانونية يمكن أن يتم باتباع العديد من الأساليب، بعضها يتضمن:

1. التركيز على التخصص: يجب أن يكون للمحامين والشركات القانونية تخصص معين يتمحور حوله عملهم. هذا يعزز سمعتهم كخبراء في مجال معين، مما يجعلهم الخيار الأول للعملاء الباحثين عن الخدمات القانونية في هذا المجال.

2. توفير خدمة عملاء ممتازة: يجب أن يتم تقديم خدمة عملاء متميزة تتمحور حول تقديم النصائح والمساعدة للعملاء، وذلك لتحقيق رضا العملاء والحفاظ على علاقات طويلة الأمد بهم.

3. استخدام التقنية: الاستفادة من التقنية لتحسين طرق تقديم الخدمات القانونية، مثل استخدام الذكاء الاصطناعي لتحليل البيانات القانونية والسرعة في تقديم الخدمات.

4. التسويق الرقمي: استخدام الشبكات الاجتماعية والمدونات والبريد الإلكتروني وغيرها من الأدوات الرقمية للتسويق وجذب العملاء.

5. التدريب المستمر: يجب على المحامين والشركات القانونية التحديث المستمر لمعرفتهم بالقوانين والأنظمة الجديدة وتطوير مهاراتهم والاطلاع على أفضل الممارسات في المجال القانوني.

6. شراكات استراتيجية: العمل مع شركات أخرى ذات صلة بالمجال القانوني، مثل الشركات العقارية أو الشركات المالية، يمكن أن يوفر فرصًا للتوسع والوصول إلى قاعدة عملاء أكبر.

يرجى العلم أن الأساليب المذكورة أعلاه لا تتعلق مباشرة بالأنظمة السعودية، ولكنها أساليب عامة يمكن تطبيقها في أي سياق قانوني.
""",
"""الخدمات القانونية هي مجموعة من الأنشطة التي يقدمها المحامون أو المشورون القانونيون، وتتنوع لتشمل العديد من المجالات والمهام، مثل :

1. التمثيل القانوني: حيث يقوم المحامي بتمثيل العميل في المحاكم وأمام السلطات القانونية.
2. التشاور والإرشاد القانوني: تقديم المشورة القانونية للعملاء حول القضايا القانونية المعقدة.
3. صياغة العقود والاتفاقيات: تضمن الشروط القانونية المحددة والحقوق والواجبات لكل طرف.
4. التحقيق القانوني: بما في ذلك البحث والتحليل القانوني.
5. التحكيم والوساطة: التفاوض بين الأطراف لحل النزاعات بشكل ودي.
6. خدمات التنفيذ: بما في ذلك تنفيذ الأحكام القضائية والأوامر القانونية.
7. الخدمات المتعلقة بالملكية الفكرية: بما في ذلك تسجيل العلامات التجارية والبراءات وحقوق الطبع والنشر والأسرار التجارية.
8. خدمات الإفلاس والإعادة الهيكلية: بما في ذلك النصح بشأن الإفلاس وإجراءات الإفلاس.

في السياق السعودي، هذه الخدمات تتم بما يتوافق مع الأنظمة السعودية المختلفة، بما في ذلك نظام القضاء، نظام التنفيذ، نظام تركيز مسؤوليات القضاء الشرعي وغيرها من الأنظمة واللوائح ذات الصلة.
""",
"""من خلال السياق المقدم، لا يوجد نص ضمن النظام المحاماة السعودي ينص على أن مكتب المحاماة يجب أن يكون متخصصًا في قضايا معينة. بالإضافة إلى ذلك، يتضح من المادة الأولى من النظام أن مهنة المحاماة تشمل الترافع عن الغير أمام المحاكم وديوان المظالم، واللجان المشكلة بموجب الأنظمة والأوامر والقرارات لنظر القضايا الداخلة في اختصاصها، ومزاولة الاستشارات الشرعية والنظامية.

من هذا يمكن الاستنتاج أن المحامي أو مكتب المحاماة يمكن أن يكون متخصصاً في قضايا معينة بناءً على خبرته وتفضيلاته، ولكن النظام لا يفرض ذلك كشرط. يجب على المحامي أو مكتب المحاماة التقيد بالقواعد والأحكام الواردة في نظام المحاماة بغض النظر عن مجال اختصاصهم.

(المادة الأولى، الخامسة والخمسون من نظام المحاماة)""",
"""الخدمات القانونية المقدمة للأعمال والشركات تختلف بحسب السياق والنظام المرجعي. ولكن بناء على السياق المقدم، يمكننا التعرف على الخدمات التالية:

1. الاستعانة بالجهات العامة أو الخاصة: وفقاً للمادة الخامسة والسبعون بعد المائتين من نظام الشركات، يمكن للجهة المختصة الاستعانة بالجهات العامة أو الخاصة لأداء المهمات المقررة لها في النظام، وإسناد بعضها إلى تلك الجهات.

2. تنظيم مركز الإسناد والتصفية: وفقاً للمادة الثالثة من تنظيم مركز الإسناد والتصفية، يهدف المركز إلى تحقيق التعاون بين الجهات القضائية والحكومية فيما يسند إليه من مهمات تتعلق بالتصفية والبيع من خلال إسنادها إلى الجهات المتخصصة.

3. التحقيق والادعاء في الجرائم: وفقاً للمادة الخامسة والستين بعد المائتين من نظام الشركات، تختص النيابة العامة بالتحقيق والادعاء في الجرائم المنصوص عليها في النظام.

4. تحديد المقابل المالي للخدمات: وفقاً للمادة التاسعة والسبعون بعد المائتين من نظام الشركات، تحدد اللوائح المقابل المالي للخدمات المقدمة من الجهة المختصة تنفيذاً لأحكام النظام.

يمكن الرجوع إلى نصوص الأنظمة المذكورة لمزيد من التفاصيل حول هذه الخدمات.""",
"""فسخ النكاح في المملكة العربية السعودية يمكن أن يتم وفقًا لعدة طرق وأساليب، وهي كالتالي:

1. الخلع: يمكن للزوجين بتراضيهما وبعد الاتفاق على تفاصيل كاملة الإجراءات، أن ينهيا عقد الزواج دون الحاجة إلى حكم قضائي. هذا وفقًا للمادة 96 من نظام الأحوال الشخصية السعودي.

2. شروط الزوجين: يمكن للزوجين أيضًا أن يضعا شروطًا خاصة بهما لفسخ العقد، ويجب أن يكون هذا الشرط مكتوبًا في وثيقة العقد أو مقرو؋ا من الزوجين، وفقًا للمادة 27 من نظام الأحوال الشخصية.

3. الطلب القضائي: في بعض الحالات، يمكن للزوجة أن تطلب من المحكمة فسخ العقد. هذا يمكن أن يحدث إذا حلف الزوج على عدم جماعها لمدة تزيد على أربعة أشهر، أو إذا امتنع عن جماعها لمدة تزيد على أربعة أشهر بدون عذر مشروع. هذا يتم وفقًا للمادة 113 من نظام الأحوال الشخصية.

في كل الحالات، يجب تقديم وثائق مثل عقد الزواج ووثيقة الطلاق والأحكام المتعلقة بالمخالعات والتطليق إلى إحدى مكاتب الأحوال المدنية خلال شهرين من تاريخها لتسجيلها وختمها بخاتم الأحوال المدنية، وفقًا للمادة 46 من نظام الأحوال المدنية.
""",
"""الفرق بين الخلع وفسخ النكاح في النظام السعودي يتمثل في الأمور التالية:

1. الطلب: في الخلع، الزوجة هي التي تطلب الفراق وذلك مقابل عوض تقدمه للزوج كما يشير الى ذلك النظام السعودي في المادة 95 من نظام الأحوال الشخصية. أما في فسخ النكاح، يمكن لأي من الزوجين طلب الفسخ ولا يتطلب وجود عوض.

2. القرار: في الخلع، يجب موافقة الزوج على طلب الزوجة للخلع. بينما في فسخ النكاح، يمكن للقاضي أن يقرر الفسخ بناءً على الأدلة المقدمة.

3. الحاجة لحكم قضائي: في الخلع، لا يتطلب الأمر حكم قضائي إذا توافق الزوجين على الخلع وفقًا للمادة 96 من نظام الأحوال الشخصية. بينما في فسخ النكاح، يتطلب الأمر صدور حكم قضائي.

4. الحالة الصحية: في الخلع، يمكن للزوجة طلب الخلع في أي حالة كانت عليها، بما في ذلك حال حيضها، ونفاسها، والطهر الذي جامعها زوجها فيه كما هو مشار إليه في المادة 98 من نظام الأحوال الشخصية. أما في فسخ النكاح، فلا يوجد شروط محددة بخصوص حالة الزوجة.

5. العوض: في الخلع، يجب أن يكون هناك عوض من الزوجة أو غيرها مقابل الخلع كما هو مبين في المادة 99 من نظام الأحوال الشخصية. أما في فسخ النكاح، فلا يتطلب الأمر عوض.

وهذه الإجابة مستندة على نظام الأحوال الشخصية السعودي، المواد من 95 إلى 99.
""",
"""الطلاق في السعودية يتبع نظام الأحوال الشخصية الذي يحدد الخطوات اللازمة للطلاق. إليك الخطوات التي يجب اتباعها:

1. الرغبة في الطلاق: بناءً على المادة السابعة والسبعون من نظام الأحوال الشخصية، يمكن للزوج أن يعلن الطلاق، ولكن يجب أن يكون ذلك باللفظ الدال على الطلاق.

2. التوثيق: يجب على الزوج توثيق الطلاق أمام الجهة المختصة. هذا يتم وفقا للمادة التسعون من نظام الأحوال الشخصية، ويجب أن يتم خلال مدة أقصاها خمسة عشر يوما من حين البينونة.

3. الخلع: إذا كان الزوج لا يرغب في الطلاق، يمكن للزوجة طلب الخلع. وفقاً للمادة السادسة والتسعون من نظام الأحوال الشخصية، يمكن للزوجة طلب الخلع بتراضي الزوجين على إنهاء العقد، ولا يتطلب ذلك حكمًا قضائيًا.

4. استرداد الجنسية السعودية: إذا كانت الزوجة من النساء الأصيلات في المملكة العربية السعودية وتمت إزالة جنسيتها بسبب الزواج، يمكنها استرداد الجنسية السعودية بعد الطلاق. هذا وفقا للمادة رقم (5) من نظام الجنسية العربية السعودية.

يرجى مراجعة محامٍ للحصول على المشورة القانونية المناسبة قبل اتخاذ أي خطوات.""",
"""لا، الهيئة العمالية ليست مختصة بقضايا الهروب. حسب المادة الرابعة والثلاثون من نظام المرافعات الشرعية، فإن الهيئة العمالية تختص بالأمور التالية:

1. المنازعات المتعلقة بعقود العمل والأجور والحقوق وإصابات العمل والتعويض عنها.
2. المنازعات المتعلقة بفرض صاحب العمل الجزاءات التأديبية على العامل، أو المتعلقة بطلب الإعفاء منها.
3. الدعاوى المرفوعة لفرض العقوبات المنصوص عليها في نظام العمل.
4. المنازعات المترتبة على الفصل من العمل.
5. شكاوى أصحاب العمل والعمال الذين لم تقبل اعتراضاتهم ضد أي قرار صادر من أي جهاز مختص في المؤسسة العامة للتأمينات الاجتماعية، يتعلق بوجوب التسجيل والاشتراكات أو التعويضات.
6. المنازعات المتعلقة بالعمال الخاضعين لأحكام نظام العمل، بمن في ذلك عمال الحكومة.
7. المنازعات الناشئة عن تطبيق نظام العمل ونظام التأمينات الاجتماعية، دون الإخلال باختصاصات المحاكم الأخرى وديوان المظالم.

أما قضايا الهروب، فتتم معالجتها من قبل الجهات المختصة وفق الأنظمة والقوانين المعمول بها في المملكة العربية السعودية. وكما هو مذكور في المادة السادسة والعشرون من اللائحة التنظيمية لدور الأحداث، يجب على الدار إبلاغ الجهات المختصة فوراً عن حالات الهروب لإعادة الفرد إلى الدار.

وبناءً على السياق المقدم، ليس هناك أي ذكر خاص بالهروب في نطاق اختصاصات الهيئة العمالية.""",
"""نعم، بالإمكان رفع دعوى عمالية بعد توقيع المخالصة ولكن بشروط معينة وفقاً للأنظمة السعودية:

1. إذا كانت المخالصة تمت تحت الضغط أو بالإكراه، أو إذا كان العامل غير واعٍ لحقوقه أثناء توقيع المخالصة، يمكنه اللجوء إلى المحكمة لإبطالها.

2. إذا كانت المخالصة تحتوي على تنازلات غير قانونية أو مخالفة للأنظمة، فإنها تعتبر باطلة ويمكن للعامل التقدم بدعوى للحصول على حقوقه.

3. إذا تبين أنه تم التلاعب بالمخالصة أو الغش، فإن المحكمة يمكنها إبطالها والنظر في الدعوى العمالية.

بالإضافة إلى ذلك، يجب أن يكون العامل قد تقدم بدعواه خلال الفترة القانونية المحددة لذلك. وفقاً للمادة (28) من نظام العمل السعودي، يجب على العامل تقديم الدعوى خلال سنة من تاريخ توقيع المخالصة.

يجب الإشارة إلى أن القرار النهائي يعود للمحكمة بناءً على الأدلة والسياق.""",
"""نعم، بالإمكان المطالبة بحقوق العامل بعد نقل الكفالة. وفقًا للأنظمة السعودية، العامل يحتفظ بحقوقه النظامية حتى بعد نقل الكفالة. يتضمن هذا الحقوق المتعلقة بالأجر، الإجازات، التأمين الصحي، النقل، السكن وغيرها من الحقوق التي يقرها نظام العمل السعودي.

الجدير بالذكر أن العامل يحق له الاحتفاظ بحقوقه النظامية كلها والترك دون إشعار، في حال لم يقم صاحب العمل بالوفاء بالتزاماته العقدية أو النظامية الجوهرية أو في حالة الغش أو الاعتداء أو المعاملة الجائرة وغيرها من الحالات الواردة في المادة الحادية والثمانون من نظام العمل.

وبناءً على ذلك، يجب على صاحب العمل الجديد أن يحترم ويحافظ على حقوق العامل المنقولة وأن يلتزم بتوفير الشروط المحددة في العقد ونظام العمل.

مصدر الإجابة: نظام العمل السعودي، المادة الحادية والثمانون.""",
"""كخدمة قانونية، نحن لا نقدم خدمات الخبرة القضائية مباشرة. الخبرة القضائية هي عملية يقوم بها خبير معتمد في مجال معين لتقديم تقرير مفصل للمحكمة بشأن جوانب معينة من القضية التي يمكن أن تتطلب معرفة تقنية أو متخصصة.

وفقًا للمادة الحادية والخمسون من اللائحة التنفيذية لنظام الإجراءات الجزائية في المملكة العربية السعودية، يتم توضيح متطلبات ومهام الخبير في القضايا القضائية. تتضمن هذه المهام تقديم تقرير مفصل عن العمل الذي تم إنجازه، والإجراءات التي تم اتخاذها، والنتائج التي توصل إليها الخبير. إذا كان هناك خلاف بين الخبراء، يجب عليهم تقديم تقرير واحد يتضمن رأي كل خبير والأسباب التي أدت إلى هذا الرأي. ويشمل النظام أيضًا الحقوق والمسؤوليات الأخرى للخبير.

لذا، من الأفضل التواصل مع مكتب خبراء قانوني معتمد إذا كنت بحاجة إلى خدمات الخبرة القضائية.
""",
"""القضايا الجنائية في المملكة العربية السعودية هي القضايا التي تتعلق بالجرائم ضد الأشخاص أو الممتلكات أو الدولة، وهي تخضع لقوانين وأنظمة محددة. القضايا الجنائية تشمل:

1. جرائم القتل والاعتداء الجسدي: تعتبر هذه الجرائم من أكثر الجرائم خطورة وتعاقب عليها بشدة.

2. جرائم السرقة: تتعلق بالاستيلاء على ممتلكات الآخرين بدون إذن.

3. جرائم الاحتيال والغش: تشمل الأعمال التي تهدف إلى الحصول على مال أو ممتلكات من الآخرين بطرق غير شرعية.

4. جرائم الاتجار بالمخدرات: تتعلق بالتعامل بالمواد المخدرة بأي شكل من الأشكال.

5. جرائم الإرهاب: تشمل الأعمال التي تهدف إلى نشر الرعب والخوف بين الناس أو تعريض أمن الدولة للخطر.

6. جرائم الاعتداء على الأملاك العامة: تشمل الأعمال التي تتسبب في تدمير أو تلف الأملاك التابعة للدولة.

7. جرائم الاعتداء على السعوديين في الخارج: تشمل الأعمال التي تهدف إلى الاعتداء على المواطنين السعوديين خارج البلاد.

8. جرائم قانون العمل: تشمل مخالفات قانون العمل مثل الإتاوات، الاحتكار وغيرها.

ويمكن الرجوع للتفاصيل الكاملة في نظام مكافحة جرائم الإرهاب وتمويله- المادة الثالثة، ونظام تركيز مسؤوليات القضاء الشرعي- المادة (82) و(84) ونظام المرافعات الشرعية- المادة السادسة والعشرون.
""",
"""صياغة العقد تتم وفقاً للأنظمة السعودية وذلك بالتأكيد على النقاط التالية:

1. يجب أن يتم تنفيذ العقد طبقاً لما اشتمل عليه وبطريقة تتفق مع ما يوجبه حسن النية، كما هو موضح في المادة الخامسة والتسعون من نظام المعاملات المدنية.

2. يجب أن يشمل العقد بنود محددة وواضحة، مثل تحديد المسؤوليات الفنية والمالية، ميزانية البحث، اسم الباحث الرئيس والباحثين المشاركين، حقوق النشر، تحديد موعد بدء العمل في البحث ومدته، الجدول الزمني للبحث، الية ايقاف البحث أو التخلي عنه، الية حل الخلاف بين الطرفين. كما هو موضح في المادة الحادية عشرة من لائحة البحوث والدراسات في وزارة الصحة.

3. يجب على المتعاقدين الوفاء بما أوجبه العقد عليهما، حيث لا يجوز نقضه أو تعديله إلا بالاتفاق أو بمقتضى نص نظامي، كما هو موضح في المادة الرابعة والتسعون من نظام المعاملات المدنية.

4. يجب أن تصاغ العقود ووثائقها وملحقاتها باللغة العربية، ويجوز استخدام لغة أخرى إلى جانب العربية على أن تكون العربية هي المعتمدة في تفسير العقد وتنفيذه وتحديد مواصفاته ومخططاته والمراسلات المتعلقة به. كما هو موضح في المادة الخامسة والخمسون من نظام المنافسات والمشتريات الحكومية.

وفي الأخير، يجب أن تتم صياغة العقد بطريقة واضحة وشاملة وواقعية ومتفقة مع الأنظمة والعرف وطبيعة العقد.
""",
"""إجراءات التصفية تختلف بحسب النظام الذي يتم تطبيقه، ولكن بشكل عام، يمكن تلخيصها في النقاط التالية:

1. تحديد طريقة تصفية المؤسسة واختيار مصفي لها، وتنتهي عند ذلك مهمة مجلس الإدارة والمدير العام.
2. توقف أعمال المؤسسة عدا ما يلزم لتنفيذ إجراءات التصفية.
3. تتم أعمال التصفية باشراف المصفي وعلى مسؤوليته باعتباره ممثلا للمالكين، وتحت رقابة الوزارة.
4. يدعو الوزارة الجمعية العمومية للانعقاد لإقرار نتائج التصفية.

وفي حالة التصفية وفقاً لنظام الإفلاس، فإنه يتم إجراءات مشابهة لكنها تتضمن أيضاً:

1. بيع أصول التصفية وتوزيع حصيلتها على الدائنين.
2. تقدم الأمين بطلب إنهاء الإجراء إذا لم تكن حصيلة بيع الأصول كافية للوفاء بمصروفات التصفية، أو إذا اكتملت أعمال التصفية.
3. تقضي المحكمة بإنهاء الإجراء وبحل المدين إذا كان شخصاً ذا صفة اعتبارية.

هذا وفقًا للمادة الخامسة والعشرون من نظام المؤسسات الصحفية، والمادة الثانية والعشرون بعد المائة، والمادة التسعون، والمادة الستون بعد المائة من نظام الإفلاس.
""",








],
###### End ###########

"answer": [

      """نعم، يمكن فصل العامل دون إنذار في بعض الحالات المحددة في النظام السعودي للعمل. وفقاً للمادة الثمانون من نظام العمل السعودي بعد التعديل بموجب المرسوم الملكي رقم م 46 وتاريخ 5 6 1436 ه، يجوز لصاحب العمل فسخ العقد دون مكافأة العامل، أو إشعاره، أو تعويضه؛ في الحالات التالية:

1. إذا وقع من العامل اعتداء على صاحب العمل أو المدير المسؤول أو أحد رؤسائه أو مرؤوسيه أثناء العمل أو بسببه.
2. إذا لم يؤد العامل التزاماته الجوهرية المترتبة على عقد العمل أو لم يطع الأوامر المشروعة أو لم يراع عمدا التعليمات.
3. إذا ثبت اتباع العامل سلوكا سيئا، أو ارتكابه عملا مخلا بالشرف أو الأمانة.
4. إذا وقع من العامل عمدا فعل أو تقصير يقصد به الحاق خسارة مادية بصاحب العمل.
5. إذا ثبت أن العامل لجأ إلى التزوير للحصول على العمل.
6. إذا كان العامل معينا تحت الاختبار.
7. إذا تغيب العامل دون سبب مشروع أكثر من ثلاثين يوما خلال السنة العقدية الواحدة أو أكثر من خمسة عشر يوما متتالية.
8. إذا ثبت أن العامل استغل مركزه الوظيفي بطريقة غير مشروعة للحصول على نتائج ومكاسب شخصية.
9. إذا ثبت أن العامل أفشى الأسرار الصناعية أو التجارية الخاصة بالعمل الذي يعمل فيه.

وفي هذه الحالات، يجب على صاحب العمل أن يتيح للعامل الفرصة لكي يبدي أسباب معارضته للفسخ.
""",

    """" الفصل في العمل يعتبر تعسفياً في حالات معينة بحسب نظام العمل السعودي وتحديداً المادة الثالثة والثمانون التي تشير إلى أن الفصل يعتبر تعسفياً في الحالات التالية:

1. إذا لم يكن السبب للفصل متعلقاً بالعامل أو كان خارجاً عن إرادته.

2. إذا كان السبب مباشرة متعلقاً بحالة العامل الفنية أو الصحية نتيجة الإصابة أو المرض.

3. إذا كان العامل قد قدم شكوى أو دعوى ضد صاحب العمل وتعتبر هذه الدعوى سببًا للفصل.

4. إذا كان الفصل نتيجة لأي إجراءات اتخذتها العامل وفقا لحقوقه المنصوص عليها في نظام العمل.

ويجدر بالذكر أن في حالة الفصل التعسفي، يحق للعامل الحصول على تعويض من صاحب العمل يتم حسابه بناءً على الراتب ومدة الخدمة.

وهذا حسب المادة الثالثة والثمانون من نظام العمل في المملكة العربية السعودية.


""",

     """نعم، يحق لصاحب العمل خصم الراتب في بعض الحالات وذلك بناءً على نظام العمل السعودي والمواصفات التالية:

1- استرداد قروض صاحب العمل، مع الشرط أن لا يزيد ما يُحسم من العامل عن 10% من أجره.

2- الاشتراكات في التأمينات الاجتماعية وأي اشتراكات أخرى مستحقة على العامل ومقررة نظامًا.

3- الاشتراكات الخاصة بالعامل في صندوق الادخار والقروض المستحقة للصندوق.

4- الأقساط المتعلقة بأي مشروع يقوم به صاحب العمل لبناء المساكن للعمال أو أي مزايا أخرى.

5- الغرامات التي توقع على العامل بسبب المخالفات التي يرتكبها، وكذلك المبلغ الذي يُقتطع منه مقابل الأضرار التي يتسبب فيها.

6- استيفاء الديون بناءً على حكم قضائي، بحيث لا يزيد ما يُحسم شهريًا عن ربع الأجر المستحق للعامل، إلا إذا كان الحكم يتضمن خلاف ذلك.

ومع ذلك، يجب أن لا يتم الخصم من أجور العامل لقاء حقوق خاصة دون موافقته الخطية، إلا في الحالات المذكورة أعلاه.

هذا المعنى موضح في المادة الثانية والتسعون من نظام العمل السعودي.

""",

    """مدة الإنذار قبل إنهاء العقد تعتمد على نوع العقد والسياق القانوني المطروح:

1- بحسب المادة الحادية والستون من نظام الإفلاس، يجب على الأمين أن يبلغ المتعاقد خطيًا قبل الإنهاء ويكون العقد منقضيًا بعد مرور ثلاثين يومًا من تاريخ التبليغ في الحالات العادية، وتسعين يومًا في حال كان العقد عقد إيجار للعقار الذي يمارس فيه المدين نشاطه.

2- وفقاً للمادة السابعة والثلاثون من اللائحة التنفيذية لنظام الإفلاس، يجب على المدين أن يبلغ المتعاقد بموعد جلسة نظر المحكمة لطلب الإنهاء قبل خمسة أيام على الأقل من موعدها، وبقرار المحكمة بالإنهاء خلال خمسة أيام من تاريخ صدوره إذا لم يحضر المتعاقد الجلسة.

3- في المادة الثانية والثمانون بعد المائة من نظام العمل، يمكن لصاحب العمل إنهاء العقد دون سابق إعلان وبدون تعويض في بعض الحالات المحددة.

لذلك، يتفاوت الإنذار قبل إنهاء العقد حسب السياق القانوني ونوع العقد.
""",

    """حقوق العامل عند انتهاء عقده تشمل العديد من النقاط التي حددتها أنظمة العمل السعودية وهي:

1- يجب على صاحب العمل دفع أجر العامل وتصفية حقوقه خلال أسبوع على الأكثر من تاريخ انتهاء العلاقة العقدية، وإذا كان العامل هو الذي انهى العقد فيجب على صاحب العمل تصفية حقوقه الكاملة خلال مدة لا تزيد على أسبوعين (المادة الثامنة والثمانون).

2- يحق للعامل أن يترك العمل دون إشعار مع احتفاظه بحقوقه النظامية كلها في حالات معينة، مثل عدم وفاء صاحب العمل بالتزاماته العقدية أو النظامية الجوهرية (المادة الحادية والثمانون).

3- يجب على صاحب العمل أن يعطي العامل شهادة خدمة دون مقابل توضح تاريخ بداية ونهاية عمله، والعمل الذي كان يؤديه ومقدار أجره الأخير عندما يطلب العامل ذلك (المادة الرابعة والستون).

4- يجب على صاحب العمل دفع مكافأة للعامل عن مدة خدمته تحسب على أساس أجر نصف شهر عن كل سنة من السنوات الخمس الأولى، وأجر شهر عن كل سنة من السنوات التالية (المادة الرابعة والثمانون).

هذا بناء على نظام العمل الصادر بالمرسوم الملكي رقم (م/51) وتاريخ 23/8/1426هـ.
""",
    """نعم، للعامل حق في الحصول على إجازة سنوية مدفوعة الأجر بناءً على نظام العمل السعودي. النقاط الرئيسية في هذا السياق هي:

1. يستحق العامل إجازة سنوية لا تقل مدتها عن 21 يومًا، وتزيد إلى مدة لا تقل عن 30 يومًا إذا أمضى العامل في خدمة صاحب العمل خمس سنوات متصلة.
2. يجب أن يتمتع العامل بإجازته في سنة استحقاقها، ولا يجوز النزول عنها، أو أن يتقاضى بدلاً نقديًا عوضًا عن الحصول عليها أثناء خدمته.
3. للعامل الحق في الحصول على أجره عن أيام الإجازة المستحقة إذا ترك العمل قبل استعمالها.

هذا ما ورد في المادة التاسعة والعاشرة والحادية عشرة بعد المائة من نظام العمل السعودي.
""",
    """ساعات العمل في المملكة العربية السعودية تخضع لنظام العمل المعمول به وفقاً للمادة 98 والمادة 100 والمادة 188 من هذا النظام. وتتغير الساعات القانونية للعمل بناءً على السياق. وفقاً لهذه المواد، يمكن تلخيص الحد الأقصى لساعات العمل كالتالي:

1. المادة 98: لا يجوز تشغيل العامل أكثر من ثماني ساعات في اليوم الواحد أو أكثر من 48 ساعة في الأسبوع إذا اعتمد صاحب العمل المعيار الأسبوعي. خلال شهر رمضان، تخفض ساعات العمل الفعلية إلى ست ساعات في اليوم أو 36 ساعة في الأسبوع.

2. المادة 100: يمكن لصاحب العمل - بموافقة الوزارة - في المنشآت التي تتطلب طبيعة العمل فيها تناوب العمل، زيادة ساعات العمل على ثماني ساعات في اليوم أو 48 ساعة في الأسبوع، بشرط ألا يتجاوز متوسط ساعات العمل عند حسابه لمدة ثلاثة أسابيع أو أقل على ثماني ساعات يوميا أو 48 ساعة أسبوعيا.

3. المادة 188: لا تزيد ساعات العمل الفعلية التي يمضيها العامل تحت سطح الأرض على سبع ساعات في اليوم. ولا يجوز إبقاء العامل في مكان العمل سواء فوق سطح الأرض أو في باطنها مدة تزيد على عشر ساعات في اليوم.

وفقًا لتلك القواعد، يجب على صاحب العمل الالتزام بتنظيم ساعات العمل وفترات الراحة بحيث لا يعمل العامل أكثر من خمس ساعات متتالية دون فترة للراحة ولا يبقى العامل في مكان العمل أكثر من اثنتي عشرة ساعة في اليوم الواحد (المادة 101).
""",
    """نعم، يمكن للعامل الاستقالة خلال فترة التجربة. وفقاً لنظام العمل السعودي، يتمتع كل من الطرفين (العامل وصاحب العمل) بالحق في إنهاء العقد خلال فترة التجربة. ولكن، يجب الإشارة إلى النقاط التالية:

1. في حال إنهاء العقد خلال فترة التجربة، لا يستحق أي من الطرفين تعويضاً.
2. العامل لا يستحق مكافأة نهاية الخدمة عن فترة التجربة.
3. يجب أن يكون النص على التجربة صريحاً في عقد العمل وتحديدها بوضوح.
4. لا يمكن أن تتجاوز فترة التجربة تسعين يوماً، ولكن باستثناءات محددة يمكن تمديدها لتصل إلى مائة وثمانين يومًا.

وفقًا للمادة الرابعة والخمسون والمادة الثالثة والخمسون من نظام العمل في المملكة العربية السعودية.
""",
    """تعويض المادة السابعة والسبعون من نظام العمل في السعودية يحسب بناءً على النص المذكور، والذي يقدم التوجيهات التالية:

1. إذا كان العقد غير محدد المدة، يحسب التعويض بمعدل أجر 15 يوماً لكل سنة خدمة للعامل.

2. إذا كان العقد محدد المدة، يحسب التعويض بناءً على الأجر المتوقع للمدة المتبقية من العقد.

3. بغض النظر عن نوع العقد، لا يجب أن يقل التعويض المستحق عن أجر العامل لمدة شهرين على الأقل.

هذه الحسابات تكون مباشرة وواضحة في حالة الأجر الثابت، ولكن في حالة الأجر المتغير، قد يتم استخدام متوسط الأجر الشهري خلال الفترة السابقة لتحديد قيمة الأجر.

وفي حالة الإنهاء غير المشروع للعقد، يحق للطرف المتضرر الحصول على تعويض يحدده هيئة تسوية الخلافات العمالية، ويتم النظر في الأضرار المادية والأدبية التي لحقت بالطرف المتضرر، بالإضافة إلى الظروف المحيطة بالإنهاء.

هذه النقاط تستند إلى المادة السابعة والسبعون من نظام العمل بعد التعديل بموجب المرسوم الملكي رقم م 46 وتاريخ 5 6 1436 هـ.
""",
"""نعم، للموظف الحق في الاطلاع على لائحة العمل وفقا للأنظمة السعودية. وهذا الحق مدرج ضمن حقوق العامل والمفتشين في العمل، حيث يتضمن نظام العمل السعودي في المادة الثامنة والتسعين بعد المائة الحقوق التالية:

1- يحق للمفتشين دخول أي منشأة خاضعة لأحكام نظام العمل في أي وقت من أوقات النهار أو الليل، دون إشعار سابق.

2- القيام بأي فحص أو تحقيق لازم للتحقق من سلامة تنفيذ النظام.

3- لهم الحق في الاطلاع على جميع الدفاتر والسجلات والوثائق الأخرى اللازم الاحتفاظ بها طبقا لأحكام نظام العمل والقرارات الصادرة بمقتضاه، والحصول على صور ومستخرجات منها.

4- أخذ عينة أو عينات من المواد المستعملة أو المتداولة في العمليات الصناعية وغيرها الخاضعة للتفتيش، مما يظن أن لها تأثيرا ضارا على صحة العمال أو سلامتهم، وذلك لغرض تحليلها في المختبرات الحكومية، ولمعرفة مدى هذا التأثير، مع إبلاغ صاحب العمل أو ممثله بذلك.

وهذا وفقا لنظام العمل السعودي، المادة الثامنة والتسعين بعد المائة.
""",

"""الآلية لرفع دعوى في المملكة العربية السعودية تتألف من عدة خطوات حسب النظم القانونية السعودية، وهي كما يلي:

1- تقديم الدعوى: يتم تقديم الدعوى من خلال المدعي العام، وذلك بعد موافقة الملك، كما هو مبين في المادة الرابعة من نظام المرافعات الشرعية.

2- الاستجابة للدعوى: بعد مضي ستين يوما من تاريخ نشوء الحق المدعى به، يتم الاستماع للدعوى.

3- النظر في الدعوى: تختص محاكم المملكة بنظر الدعاوى التي ترفع على السعودي ولو لم يكن له محل إقامة عام ومختار في المملكة، باستثناء الدعاوى العينية المتعلقة بعقار خارج المملكة، حسب المادة الرابعة والعشرين من نظام المرافعات الشرعية.

4- رفع الدعوى التأديبية: ترفع الدعوى التأديبية بمذكرة تشتمل على التهمة الموجهة والأدلة المؤيدة لها، وتقدم إلى مجلس التأديب ليصدر قراره، بدعوة المتهم بالحضور أمام المجلس، وفقا للمادة الثامنة عشرة من نظام هيئة التحقيق والادعاء العام (نظام النيابة العامة).

وفي حالة تنفيذ حكم التحكيم، يجب الالتزام بالشروط المبينة في المادة الخامسة والخمسون من نظام التحكيم.

أرجو أن تكون هذه المعلومات مفيدة. في حال كان لديك أي أسئلة أخرى، فلا تتردد في طرحها.
""",
"""المسؤول في رفع الدعوى لدى المحاكم السعودية يعتمد على نوع الدعوى والأطراف المشتركة فيها. وفقا للمواد التي قدمت، يمكن تحديد المسؤولين على النحو التالي:

1. في حالة الدعاوي التي ترفع ضد غير السعودي الذي ليس له مكان إقامة في المملكة، فإن المحاكم السعودية تختص بنظر هذه الدعوى وفقًا للمادة السادسة والعشرون من نظام المرافعات الشرعية.

2. بالنسبة للدعاوي التي ترفع ضد السعوديين ولو لم يكن لديهم مكان إقامة في المملكة، فإن المحاكم السعودية تختص أيضا بنظر هذه الدعوى وفقا للمادة الرابعة والعشرون من نظام المرافعات الشرعية.

3. بالنسبة لدعاوى التعويض الناجمة عن الأضرار التي تسببها الطائرات، فإن ديوان المظالم هو المختص بنظر هذه الدعاوى وفقا للمادة الحادية والخمسون بعد المائة من نظام الطيران المدني.

4. أما بالنسبة للدعاوي التأديبية ضد المحامين، فقد تغيرت القواعد حسب التعديل الأخير للمادة الثلاثون من نظام المحاماة، حيث يصبح وزير العدل هو المسؤول عن تحديد قواعد وإجراءات الضبط ورفع الدعوى التأديبية ونظرها.
""",
"""أتعاب المحاماة في المملكة العربية السعودية تحدد بناءً على عدة قواعد وأنظمة:

1. الاتفاق بين المحامي والموكل: كما هو موضح في المادة السادسة والعشرون من نظام المحاماة، تحدد أتعاب المحامي وطريقة دفعها باتفاق يعقده مع موكله. يمكن للمحامي والموكل الاتفاق بحرية على مبلغ معين وطريقة الدفع.

2. قيمة الجهد المبذول من قبل المحامي: في حالة عدم وجود اتفاق أو إذا كان الاتفاق غير صالح أو تم فسخه، فإن المحكمة التي تنظر في القضية تقدر أتعاب المحامي على أساس الجهد الذي بذله المحامي، كما هو موضح في المادة الثامنة والعشرون من نظام المحاماة.

3. النفع الذي عاد على الموكل: يتم أيضاً أخذ النفع الذي عاد على الموكل في الاعتبار عند تحديد أتعاب المحامي.

4. الدفاع القانوني المجاني: كما هو موضح في المادة السابعة والتسعون من اللائحة التنفيذية لنظام الإجراءات الجزائية، للمحامي المندوب الحق في تقديم شهادة حضوره لكل جلسة للدفاع عن المتهم لتقديمها إلى الوزارة لصرف أتعابه، ولكنه لا يجوز له أن يتقاضى أي مقابل من المتهم.

الرجاء الرجوع إلى الأنظمة المذكورة لمزيد من التفاصيل والمعلومات.
""",
"""لجنة المنازعات المصرفية في السعودية لها صلاحيات محددة تشمل:

1. الفصل في المنازعات والخلافات بين البنوك والعملاء، أو بين البنوك نفسها.
2. الفصل في الشكاوى المقدمة من العملاء ضد البنوك.
3. الفصل في قضايا الاحتيال المصرفي والتزوير.
4. تقديم توصيات لتحسين الأنظمة والتشريعات المصرفية.
5. التحقق من تطبيق البنوك لتعليمات وقواعد البنك المركزي السعودي والتأكد من الامتثال لها.

تم تحديد هذه الصلاحيات في نظام البنك المركزي السعودي وتحديداً المادة الثامنة عشرة من النظام.
""",
"""فتح سجل تجاري في المملكة العربية السعودية يتطلب عدة خطوات وفقا للأنظمة السعودية. هنا هي الخطوات الأساسية التي يجب اتباعها:

1. اختيار الاسم التجاري: يجب عليك اتخاذ اسم تجاري وقيده في السجل التجاري كما هو موضح في المادة الثالثة من نظام الأسماء التجارية. يمكنك حجز الاسم التجاري لفترة مؤقتة لدى المسجل دون قيده في السجل التجاري.

2. تكوين الاسم التجاري: يمكن أن يتكون الاسم التجاري من اسمك الشخصي أو من اسم مميز أو منهما معا وهذا وفقا للمادة الرابعة من نظام الأسماء التجارية.

3. طلب حجز الاسم التجاري أو قيده: يجب تقديم طلب حجز الاسم التجاري أو قيده إلى المسجل، وفقا للمادة الخامسة من نظام الأسماء التجارية.

4. البت في طلبك: سيبت المسجل في طلبك خلال عشرة أيام من تاريخ تقديمه. إذا تم قبول طلبك، سيتم نشر الاسم التجاري المقبول حجزه أو قيده.

5. الالتزام بالقوانين: عليك الالتزام بجميع القوانين والأنظمة السعودية المتعلقة بتشغيل الأعمال التجارية.

إذا كنت محاميا أجنبيا وترغب في ممارسة مهنة المحاماة في المملكة، يجب عليك اتباع الشكلين المذكورين في المادة الخمسون من نظام المحاماة.

الرجاء الرجوع إلى نظام الأسماء التجارية (المادة الثالثة والرابعة والخامسة) ونظام المحاماة (المادة الخمسون) للمزيد من المعلومات.
""",

"""تأسيس فرع لشركة أجنبية في المملكة العربية السعودية يتطلب العديد من الخطوات والشروط التي يجب استيفائها وفقا للأنظمة السعودية. وتتلخص هذه الشروط والخطوات كالتالي:

1. الشركة الأجنبية يجب أن تقوم بممارسة نشاطها وأعمالها داخل المملكة من خلال فرع أو مكتب تمثيل أو أي شكل آخر، وذلك وفقا لأحكام نظام الاستثمار الأجنبي والأحكام النظامية الأخرى المتعلقة (المادة السادسة والثلاثون بعد المائتين من نظام الشركات).

2. يعد فرع الشركة الأجنبية أو مكتب تمثيلها داخل المملكة موطنا لها فيما يتعلق بنشاطها وأعمالها داخل المملكة، ويجب أن تطبق عليه جميع الأنظمة المعمول بها في المملكة (المادة التاسعة والثلاثون بعد المائتين من نظام الشركات).

3. يجب تقديم طلب للحصول على ترخيص لمزاولة الأعمال المصرفية في المملكة إلى المؤسسة المختصة، والتي ستقوم بدراسة الطلب وتقديم توصياتها بشأنه لوزير المالية والاقتصاد الوطني (المادة الثالثة من نظام مراقبة البنوك).

4. يجب استيفاء الشروط التي يحددها مجلس الوزراء بناء على اقتراح وزير المالية والاقتصاد الوطني للحصول على الترخيص لتأسيس فرع أو فروع للبنك الأجنبي في المملكة (المادة الثالثة من نظام مراقبة البنوك).

الرجاء ملاحظة أن هذه الشروط تختلف اعتمادًا على نوع الشركة وطبيعة النشاط الذي تعتزم ممارسته. لذا، ينصح بالتواصل مع محامي محلي أو مستشار قانوني للحصول على المشورة المناسبة وفقا للسياق الخاص بالشركة.
""",
"""وثيقة التأمين الشامل للمركبات هي وثيقة تأمين تغطي جميع التلفيات والأضرار التي يمكن أن تحدث للمركبة، سواء كانت ناتجة عن حادث اصطدام أو سرقة أو حريق أو أي أضرار أخرى.

تتضمن وثيقة التأمين الشامل على النقاط التالية:
1. تاريخ عقد التأمين ومكانه.
2. اسم المؤمن والمؤمن له وموطنيهما.
3. محل التأمين.
4. وصف التغطية التأمينية وحدودها واستثناءاتها ومدتها ونطاقها الجغرافي.
5. مبلغ التأمين وقسطه.
6. أي بيان أخر يحدده اللوائح.

وهذا يتوافق مع المادة الرابعة والتسعين بعد المائتين من النظام البحري التجاري.
""",
"""وثيقة التأمين الإلزامي للمركبات هي وثيقة تُبرم بين صاحب المركبة وشركة التأمين، وتتضمن التغطية الضرورية للتكاليف التي قد تنشأ عن الأضرار التي قد تلحق بالأطراف الثالثة كنتيجة لحوادث المرور التي قد يتسبب فيها صاحب المركبة.

وفقًا للنظام السعودي، هناك بعض النقاط الأساسية المتعلقة بوثيقة التأمين الإلزامي، وهي:

1. لا يجوز تسيير المركبات قبل الحصول على وثيقة التأمين.
2. يجب أن تكون الوثيقة سارية المفعول.
3. يجب أن تكون الوثيقة صادرة من شركة تأمين مرخص لها العمل في المملكة.
4. تغطي وثيقة التأمين الإلزامي الأضرار التي قد تلحق بالأطراف الثالثة نتيجة لحوادث المرور.
5. الالتزام بتجديد وثيقة التأمين عند انتهاء صلاحيتها.

ويمكن الاستعانة بهذه المعلومات من المادة الثامنة من نظام المرور السعودي.
""",

"""وفقاً للأنظمة السعودية، يمكنك تقديم طلب لإعادة النظر في الحكم القضائي إذا كانت لديك أدلة جديدة قوية، مثل الأوراق التي ذكرت. ولكن يجب أن تعرف أن هذا الإجراء ليس بسيطاً ويتطلب تلبية مجموعة من الشروط والأحكام.

التفاصيل الدقيقة لهذا الإجراء قد تختلف بناءً على طبيعة القضية، ولكن عادة ما تشمل الخطوات التالية:

1. تقديم طلب للمحكمة التي أصدرت الحكم، مشيراً فيه إلى الأدلة الجديدة التي ظهرت بعد صدور الحكم.
2. تقديم الأوراق أو الأدلة الجديدة التي تدعم طلبك.
3. يجب أن تكون الأدلة التي تقدمها قوية بما فيه الكفاية لتغيير الحكم، وليس مجرد تأكيد للأدلة التي تم عرضها بالفعل.

يرجى ملاحظة أن هذه العملية يجب أن تتم في إطار القانون ومع مراعاة جميع القواعد والأنظمة القانونية. وقد يكون من الجيد الحصول على المشورة القانونية من محامٍ قبل الشروع في هذه العملية.

فيما يتعلق بالانظمة المرجعية، النظام الأساسي للحكم في المملكة العربية السعودية، وبخاصة المواد 70 و 71 و 82، تشير إلى الطرق التي يمكن من خلالها تقديم الانظمة وتعديلها ونشرها، بالإضافة إلى القيود المفروضة على تعطيل تنفيذ هذه الأحكام. والمادة الخامسة والعشرون من نظام هيئة البيعة تتعلق بتعديل أحكام هذا النظام بأمر ملكي.
""",
"""في حال وجود أخطاء في صك الحكم، تتبع الإجراءات التالية:

1. يمكن تقديم طلب للمحكمة لتصحيح الأخطاء المادية البحتة الكتابية أو الحسابية في الصك، كما هو موضح في المادة الحادية والسبعون بعد المائة من نظام المرافعات الشرعية.

2. في حال كانت الأخطاء تتعلق بالسهو أو النواقص التي لم تؤثر في نفس الحكم ولا متعلقاته، يمكن للهيئة إعادة الصك إلى المحكمة لتصحيح النواقص، وفقاً للمادة (548) من النظام التجاري (نظام المحكمة التجارية).

3. في حالة تعدد الأحكام في الصك، يجب على الهيئة التدقيق في كل الأحكام وإعطاء قرارها نحو كل حكم منها بالتصديق أو النقض، حسب المادة (24) من نظام تركيز مسؤوليات القضاء الشرعي.

4. في حالة فقدان سجل الصك أو تلفه، يمكن إعادة تسجيله إذا طابق الصك أساسه المستند إليه، وفقاً للمادة الخامسة والأربعون من نظام التوثيق.

هذه الإجراءات تتوافق مع المواد المشار إليها في أنظمة المملكة العربية السعودية.
""",
"""المرافعة في الأنظمة السعودية تتم كتابيًا بحسب المادة الخامسة والستون من نظام المرافعات الشرعية بعد أن تم تعديلها بموجب المرسوم الملكي رقم م/78 وتاريخ 1442/9/10هـ. التعديل جاء كالتالي:

1. تكون إجراءات نظر الدعوى والمرافعة فيها كتابية. وللمحكمة - من تلقاء نفسها أو بناءً على طلب أحد الخصوم - أن تسمع ما لدي الأطراف مشافهة. وتثبت المحكمة ذلك في محضر الجلسة.

2. على المحكمة أن تعطي الخصوم المهل المناسبة، للاطلاع على المستندات، كلما اقتضت الحال ذلك.

ومع ذلك، يتم السماح بالمرافعة الشفهية في بعض الأحيان، حيث يمكن للمحكمة أن تسمع ما لدى الأطراف مشافهة إذا رأت ذلك مناسبًا أو بناءً على طلب من أحد الخصوم.

المادة المشار إليها هي المادة الخامسة والستون من نظام المرافعات الشرعية بعد التعديل.
""",
"""الاستفادة من الوقف تتطلب العديد من الخطوات والإجراءات القانونية بناءً على الأنظمة السعودية، وبناءً على السياق المقدم، يمكنك اتباع الخطوات التالية:

1. التأكد من طبيعة الوقف: يجب معرفة طبيعة الوقف والنصوص النظامية الخاصة به، وذلك وفقا للمادة الثامنة والتسعون بعد الستمائة من نظام المعاملات المدنية.

2. التحقق من الحق في الانتفاع: بناءً على المادة الثالثة والتسعون بعد الستمائة من نظام المعاملات المدنية، فإنه لا يسمع دعوى المطالبة بحق الانتفاع إذا انقضت عليه عدم استعماله مدة عشر سنوات.

3. استغلال ثمار الوقف: في حال كان لديك حق الانتفاع، فإن ثمار الشيء المنتفع به من حق المنتفع مدة انتفاعه، وفقاً للمادة الثانية والثمانون بعد الستمائة من نظام المعاملات المدنية.

4. اللجوء إلى القضاء: في حال وجود أي صعوبات أو نزاعات، يجوز للمحكمة المختصة - لاعتبارات تقدرها - وقف تنفيذ العقوبة المحكوم بها، وفقاً للمادة الثانية والثمانون من نظام المرور.

تذكر، يجب استشارة المختصين القانونيين أو المحامين للحصول على مشورة قانونية دقيقة وواضحة.
""",
"""المكتب يتعامل مع العديد من القضايا القانونية التي تواجه الأفراد والشركات، وذلك وفقًا لما هو متاح في القانون السعودي. وهذه القضايا تشمل:

1. قضايا الترافع: يتم الترافع عن الغير أمام المحاكم وديوان المظالم واللجان المشكلة بموجب الأنظمة والأوامر والقرارات لنظر القضايا الداخلة في اختصاصها كما ينص عليها النظام في المادة الأولى.

2. الاستشارات الشرعية والنظامية: يتم تقديم الاستشارات القانونية والشرعية للأفراد والشركات تبعًا للقانون السعودي.

3. قضايا الشرف والكرامة: يتعامل المكتب أيضاً مع القضايا التي تتعلق بالشرف والكرامة، وذلك حسب ما هو موضح في المادة الثانية عشرة من نظام المحاماة.

4. القضايا التي تتطلب الخبرة: يمكن للمكتب التعامل مع القضايا التي تتطلب خبرة معينة، مثل القضايا التي يتم تقديم الرأي فيها بصفة خبير، وفقاً للمادة السابعة عشرة من نظام المحاماة.

لكن يجب الانتباه إلى أن هذه القضايا يجب ألا تتعارض مع طبيعة ونوع الترخيص الذي أصدر للمكتب، كما هو موضح في المادة الخامسة والخمسون من نظام المحاماة.

المصدر: نظام المحاماة، المادة الأولى، الثانية عشرة، السابعة عشرة، الخامسة والخمسون.
""",
"""المدة المطلوبة لتنفيذ قرار في قضية عمالية تعتمد على الظروف المحددة للقضية. وفقاً للمادة 72 من نظام العمل في المملكة العربية السعودية، يتم إعلام العامل بالقرار الخاص بتوقيع الجزاء عليه كتابياً, وإذا امتنع عن الاستلام أو كان غائباً، فيتم إرسال الإشعار إلى عنوانه المسجل في الملف.

بعد استلام القرار، للعامل حق التظلم لدى الجهة المختصة لدى صاحب العمل خلال 30 يوماً - باستثناء أيام العطل الرسمية - من تاريخ إبلاغه بالقرار. إذا تم رفض التظلم أو لم يتم البت فيه خلال 15 يومًا من تقديمه، يحق للعامل الاعتراض أمام المحاكم العمالية على القرار الخاص بتوقيع الجزاء عليه خلال 30 يوماً - باستثناء أيام العطل الرسمية - من تاريخ رفض التظلم أو انتهاء المدة المحددة للبت في التظلم، أيهما أقرب.

هذا وفقاً للمادة 72 من نظام العمل بعد التعديل الذي صدر بالمرسوم الملكي رقم م44 وتاريخ 144628ه والذي يعمل به من تاريخ 1446820ه.
""",
"""وفقاً للنص الذي قدمت، يجب أن يتم رفع إيقاف الخدمات تلقائياً من خلال الربط الإلكتروني بين المنصة الإلكترونية والجهة الحكومية طالبة الإيقاف، وذلك خلال مدة لا تتجاوز 24 ساعة من الموافقة على إلغاء إيقاف الخدمات.

هذا وفقاً للضوابط المذكورة في السياق المقدم، ورغم أنه لم يتم ذكر رقم المادة أو النظام الذي يتم الاستناد إليه، فإنه يمكن القول أن هذه الضوابط تتعلق بإيقاف الخدمات الحكومية في المملكة العربية السعودية.
""",
"""الجواب على سؤالك يعتمد على النظام المعتمد في الهيئة المقدمة للخدمة. بشكل عام، لا يوجد وقت محدد في الأنظمة السعودية للرد على الاستشارة القانونية. ولكن بناءً على الممارسة العامة، يتم الرد على الاستشارات القانونية في غضون أيام قليلة إلى أسبوعين، حسب تعقيد الاستشارة والهيئة المعنية.

من الجدير بالذكر أن الأنظمة المذكورة في السياق تتعلق بأمور محددة مثل التحقيقات الجنائية، ورد الخبير، والطلبات المستعجلة والاعتراض على القرارات الغيابية، وهي لا تنطبق بشكل مباشر على الاستشارات القانونية.

في كل الأحوال، ينصح دائماً بالتواصل مع المحامي أو الهيئة القانونية المعنية للحصول على معلومات أكثر دقة حول الجدول الزمني المتوقع للرد على الاستشارة القانونية.
""",
""""تأسيس الشركة المهنية المختلطة في النظام السعودي يتطلب العديد من الشروط والضوابط التي يمكن تلخيصها فيما يلي:

1. يجب أن يكون المؤسسون أشخاص مرخص لهم في ممارسة مهنة حرة واحدة أو أكثر حسبما ورد في المادة المائتان من نظام الشركات.

2. يمكن لشخص مرخص له في ممارسة مهنة حرة واحدة أن يؤسس شركة مهنية مساهمة أو مساهمة مبسطة أو ذات مسؤولية محدودة من شخص واحد لممارسة مهنته من خلالها.

3. يمكن أن يشارك في الشركة المهنية - عدا شركة التضامن وشركة التوصية البسيطة بصفة الشريك المتضامن - شخص ذو صفة طبيعية من غير المرخص لهم بممارسة المهنة أو المهن الحرة محل نشاطها، أو شخص ذو صفة اعتبارية.

4. يجب أن تستوفى الشروط والضوابط التي تحددها اللوائح كما ورد في المادة المائتان من نظام الشركات.

5. يجب أن تتم مراعاة القواعد العامة لإدارة هذا النوع من الشركات المهنية بما يصون استقلال الشركاء أو المساهمين المهنيين في ممارسة مهنتهم حسبما ورد في المادة المائتان من نظام الشركات.

6. يجب أن يتم تأسيس الشركة المهنية وفقا لإجراءات التأسيس المقررة لشكل الشركة كما ورد في المادة الثانية بعد المائتين من نظام الشركات.

الاستناد: نظام الشركات السعودي - المادة المائتان والمادة الثانية بعد المائتين.
""",
 """تحويل المؤسسة إلى شركة يتم وفقًا لأحكام نظام الشركات في المملكة العربية السعودية وتتضمن الخطوات التالية:

1. القرار بالتحول: يجب أن يكون هناك قرار من صاحب المؤسسة بتحويلها إلى شركة.

2. استيفاء الشروط: يجب استيفاء شروط التأسيس والقيد والشهر المقررة للشكل الذي سيتم التحول إليه.

3. نقل الأصول: يمكن لصاحب المؤسسة نقل أصوله إلى أي شكل من أشكال الشركات التي سيتم تأسيسها بناءً على أحكام النظام.

4. الديون والتزامات: لا يترتب على التأسيس إبراء ذمة أصحاب المؤسسات الفردية من مسؤولياتهم عن الديون والتزامات المؤسسات الفردية السابقة، إلا في حال قبول الدائنين ذلك صراحة.

5. التسجيل في السجل التجاري: يجب قيد الشركة الجديدة في السجل التجاري لتصبح مؤسسة تأسيساً صحيحاً.

النظام المستند إليه هو نظام الشركات في المملكة العربية السعودية وهذا يشمل المادة العشرون بعد المائتين، المادة الحادية والعشرون بعد المائتين، المادة الخامسة عشرة بعد المائتين، والمادة الخامسة والستون من نظام الشركات.
""",
"""شهادة المنشأ هي وثيقة تثبت أن سلعة محددة تم إنتاجها أو تصنيعها في دولة معينة. هذه الشهادة تحتاج عادة عند التصدير إلى دول أخرى. في المملكة العربية السعودية، يجب توفر الشروط الأتية للحصول على شهادة المنشأ:

1. يجب أن يكون الشركة أو المؤسسة المصدرة مسجلة في الغرفة التجارية.
2. يجب أن تكون السلع المصدرة قد تم إنتاجها أو تصنيعها في المملكة العربية السعودية.
3. يجب تقديم الفواتير التجارية المتعلقة بالسلع التي ستصدر.
4. يجب أن تكون السلع المصدرة مطابقة للمعايير واللوائح المحلية والدولية.
5. يجب تقديم طلب رسمي للحصول على شهادة المنشأ من الغرفة التجارية.

الرجاء العلم أن هذه الشروط قد تختلف بناءً على القوانين واللوائح المحلية والدولية وتحديداً تلك المتعلقة بالتجارة الدولية والتصدير. لذا، يفضل استشارة محام أو مستشار قانوني للحصول على المعلومات الدقيقة والمحدثة. لا يوجد نظام معين أو مادة تتعلق بشهادة المنشأ في الأنظمة السعودية المشار إليها في السياق المقدم.
""",

"""تكلفة الرسوم الحكومية لتسجيل علامة تجارية في المملكة العربية السعودية حسب نظام العلامات التجارية تتضمن:

1. الف ريال لتقديم طلب تسجيل علامة تجارية عن فئة واحدة.

2. ثلاثة آلاف ريال لتسجيل العلامة التجارية عن فئة واحدة.

وبالتالي، تكلفة تسجيل العلامة التجارية تكون بمجموع 4000 ريال سعودي. هذا يتضمن رسوم تقديم الطلب ورسوم التسجيل نفسه.

(المرجع: نظام العلامات التجارية، المادة الحادية والأربعون)
""",

"""لا، المحاكم التجارية لا تختص بالنظر في دعاوى العقار. وذلك وفقا للأنظمة السعودية، حيث يمكن توضيح الأمر كالتالي:

1. وفقا للمادة الحادية والثلاثون من نظام المرافعات الشرعية، فإن المحاكم العامة هي التي تختص بنظر الدعاوى المتعلقة بالعقار.

2. وفقا للمادة الثالثة من النظام التجاري (نظام المحكمة التجارية)، فإن بيع الأرض أو العقار لا يعتبر عملاً تجاريًا، وبالتالي لا تختص المحاكم التجارية بالنظر في دعاوى العقارات والإيجارات.

3. وفقا للمادة الخامسة والثلاثون من نظام المرافعات الشرعية، المحاكم التجارية تختص بنظر المنازعات التجارية بين التجار والدعاوى المتعلقة بالأعمال التجارية الأصلية والتبعية.

4. وفقا للمادة التاسعة والثمانين من نظام المحاكم التجارية، فيما لم يرد فيه نص خاص في النظام، تطبق أحكام نظام المرافعات الشرعية على الدعاوى التي تختص بنظرها المحكمة بما لا يخالف طبيعة الدعوى التجارية.

وبناء على الأنظمة المذكورة أعلاه، يمكن القول بأن المحاكم التجارية لا تتعامل مع دعاوى العقار. وتم الاستناد في هذا الرد إلى نظام المرافعات الشرعية (المادة 31 و 35)، والنظام التجاري (المادة 3)، ونظام المحاكم التجارية (المادة 93).
""",

"""يتبع حجز الاسم التجاري في المملكة العربية السعودية عدة خطوات وفقًا للنظام السعودي للأسماء التجارية، وهي:

1. تقديم طلب: يجب على الشخص المعني تقديم طلب حجز الاسم التجاري إلى المسجل، والذي يتضمن البيانات المطلوبة وفقًا للائحة النظام.

2. مراجعة الطلب: بعد تقديم الطلب، يتم مراجعته من قبل المسجل خلال عشرة أيام من تاريخ تقديمه. وفي بعض الحالات التي تحددها اللائحة، يمكن تمديد هذه المدة.

3. الإعلان عن الطلب: بعد القبول، يتم الإعلان عن الاسم التجاري المحجوز أو المقيد في الوسيلة التي تحددها اللائحة.

4. الدفع: يتحمل طالب الحجز أو القيد المقابل المالي للإعلان، إن وجد.

5. الأولوية: في حال وجود أكثر من طلب لحجز أو قيد اسم تجاري معين، يتم منح الأولوية للأسبق في تقديم الطلب.

6. الطعن: في حالة رفض الطلب، يحق للطالب الاعتراض أمام الوزارة خلال ستين يومًا من تاريخ إبلاغه بالرفض.

يمكن العثور على هذه التفاصيل في المادة الخامسة من نظام الأسماء التجارية في المملكة العربية السعودية.""",

"""مدة حماية العلامة التجارية في نظام العلامات التجارية لدول مجلس التعاون لدول الخليج العربية تستمر لمدة عشر سنوات، ويمكن لصاحب الحق، إذا رغب في استمرار الحماية، تقديم طلب تجديد خلال السنة الأخيرة من مدة الحماية، وفقاً للشروط المنصوص عليها في النظام ولائحته التنفيذية. وفي حال عدم تجديد التسجيل خلال الأشهر الست التالية لانتهاء مدة التسجيل، يتم شطب العلامة التجارية من السجل بواسطة الجهة المختصة.

وعند تجديد التسجيل، يتم ذلك دون أي فحص جديد، ويتم الإعلان عنه بالوسيلة التي تحددها اللائحة التنفيذية للنظام، ودون الأخذ بأي اعتراض من الغير.

وفي حالة شطب العلامة التجارية، لا يجوز تسجيلها لصالح الآخرين على المنتجات نفسها أو الخدمات أو على منتجات أو خدمات مشابهة إلا بعد ثلاث سنوات من تاريخ الشطب، إلا إذا نص قرار الشطب على مدة أقل.

وصاحب العلامة التجارية يحق له أن يتخذ الإجراءات المتعلقة بمطالبة المدعي السيئ النية بالتعويض الذي قد يستحق له نتيجة لاتخاذه للإجراءات المنصوص عليها في النظام.

هذا وفقا للمادة 20، المادة 22، المادة 27، و المادة 51 من نظام العلامات التجارية لدول مجلس التعاون لدول الخليج العربية.""",

"""نعم، استخراج الوكالة في المملكة العربية السعودية يحتاج إلى حجز موعد مسبق، وذلك من خلال الخطوات التالية:

1. الدخول على وكالة الوزارة للشؤون القانونية (وزارة العدل) عبر الرابط الإلكتروني.
2. تسجيل الدخول إلى الحساب الشخصي على البوابة.
3. اختيار "الخدمات الإلكترونية" ثم "حجز موعد".
4. اختيار نوع الخدمة المراد الحصول عليها، وفي هذه الحالة هي "وكالة".
5. اختيار التاريخ المناسب للموعد والتأكيد على ذلك.

يجب العلم أن الحجز المبكر للموعد يضمن سرعة الحصول على الوكالة وذلك لأنها تعتبر من الخدمات المطلوبة بكثرة.

يمكن الرجوع إلى المادة 481 من نظام المعاملات المدنية التي تناولت الوكالة في توضيحها لشكل الوكالة والشروط المتعلقة بها.
""",

"""نعم، استخراج الوكالة في المملكة العربية السعودية يتطلب تحديد موعد مسبق، وهذا الأمر يتم عبر نظام "مواعيد" الذي أطلقته وزارة العدل السعودية. يمكن للمستخدمين الدخول إلى النظام وتحديد الموعد المناسب لهم لزيارة المحكمة أو الدائرة القضائية المعنية لاستخراج الوكالة. يهدف هذا النظام إلى تسهيل الإجراءات والتقليل من الزحام في المحاكم والدوائر القضائية.

لكن يجب الإشارة إلى أن السؤال غير متعلق مباشرة بالنصوص القانونية المذكورة في السياق، حيث أن هذه النصوص تتعلق بأحكام وشروط الوكالة والشركات، وليس بإجراءات استخراج الوكالة.
""",

"""السؤال المطروح ليس له علاقة بالمواد القانونية المقدمة في السياق. ولكن بشكل عام، في المملكة العربية السعودية، يتطلب استخراج الوكالة القانونية التوجه إلى ديوان الوكالات في وزارة العدل وتقديم الطلب المناسب. قد يتم ذلك عبر النظام الإلكتروني للوزارة، وفي بعض الأحيان، سيكون من الأفضل حجز موعد مسبق لتسهيل الإجراءات وتجنب الانتظار. يتوجب على الشخص المراد منحه الوكالة الحضور شخصياً إلى ديوان الوكالات أيضًا.

يرجى الرجوع إلى الموقع الرسمي لوزارة العدل السعودية أو الاتصال بالوزارة مباشرة للحصول على المعلومات الأكثر دقة وتحديثاً حول الإجراءات المطلوبة لاستخراج الوكالة.
""",
"""تتنوع تكاليف الخدمات القانونية في السعودية بناءً على نوع الخدمة المطلوبة والموضوع الذي تتعلق به الدعوى، وهذا ما يتضح من خلال النظام واللوائح التي ذكرت:

1. حسب المادة السابعة من اللائحة التنفيذية لنظام التكاليف القضائية، تكون التكاليف على النحو التالي:
   - طلب ذي المصلحه تسليمه نسخه مصدقه من اوراق الدعوي أو سجلاتها أو الوثائق أو الاوراق التي تحت يد المحكمه؛ 100 ريال.
   - طلب ذي المصلحه الاطلاع على اوراق الدعوى أو سجلاتها؛ 50 ريال.
   - طلب نسخة بديلة للوثائق القضائية؛ 100 ريال.

2. وفقاً للمادة الثالثة من اللائحة التنفيذية لنظام التكاليف القضائية، تتراوح تكاليف الدعاوى غير المحددة القيمة بين 1,000 ريال للدعاوى المحكمة العمالية و10,000 ريال للدعاوى الجزائية الخاصة.

3. بناءً على المادة الثانية من اللائحة التنفيذية لنظام التكاليف القضائية، التكاليف القضائية للدعاوى المحددة القيمة يتم تقديرها على أساس نسبة من قيمة المطالبة في الدعوى، وتتراوح هذه النسب بين 2% إلى 5% بناءً على قيمة المطالبة.

4. وفقاً للمادة الثامنة من نظام التكاليف القضائية، تكلفة بعض الطلبات المحددة لا تتجاوز 1,000 ريال.

هذه التكاليف تعتمد على النظام واللائحة التنفيذية لنظام التكاليف القضائية في السعودية.

""",
"""سيتم اطلاعك على سير قضيتك بناءً على النظام والمادة التي تتطبق على حالتك.

1. إذا كنت دائنًا في حالة إفلاس، فستتمكن من الاطلاع على تقرير دوري عن سير إجراء التصفية كل ثلاثة أشهر على الأقل، كما هو مذكور في المادة الخامسة عشرة بعد المائة من نظام الإفلاس.

2. في حالة التحقيقات الجزائية، يجب على المحقق أن يبلغك بأوامره وقراراته بشأن التحقيق الذي يجريه خلال ثلاثة أيام من تاريخ صدورها، وذلك حسب المادة الرابعة والسبعون من نظام الإجراءات الجزائية.

3. في حالة المرافعات الشرعية، يجب على الخبير أن يودع تقريره والأوراق المرتبطة بالقضية في إدارة المحكمة وأن يبلغك بذلك في غضون 24 ساعة من الإيداع، كما هو مذكور في المادة السادسة والثلاثون بعد المائة من نظام المرافعات الشرعية.

4. أما إذا كنت الشخص الذي يتم التحقيق معه، فيجب على المحقق أن يبلغك بأمر الحضور قبل 24 ساعة على الأقل من موعد التحقيق، ما لم يستدع الأمر الاستعجال، وفقًا للمادة الخامسة والسبعون من اللائحة التنفيذية لنظام الإجراءات الجزائية.
""",
"""تطوير وتسويق الخدمات القانونية يمكن أن يتم باتباع العديد من الأساليب، بعضها يتضمن:

1. التركيز على التخصص: يجب أن يكون للمحامين والشركات القانونية تخصص معين يتمحور حوله عملهم. هذا يعزز سمعتهم كخبراء في مجال معين، مما يجعلهم الخيار الأول للعملاء الباحثين عن الخدمات القانونية في هذا المجال.

2. توفير خدمة عملاء ممتازة: يجب أن يتم تقديم خدمة عملاء متميزة تتمحور حول تقديم النصائح والمساعدة للعملاء، وذلك لتحقيق رضا العملاء والحفاظ على علاقات طويلة الأمد بهم.

3. استخدام التقنية: الاستفادة من التقنية لتحسين طرق تقديم الخدمات القانونية، مثل استخدام الذكاء الاصطناعي لتحليل البيانات القانونية والسرعة في تقديم الخدمات.

4. التسويق الرقمي: استخدام الشبكات الاجتماعية والمدونات والبريد الإلكتروني وغيرها من الأدوات الرقمية للتسويق وجذب العملاء.

5. التدريب المستمر: يجب على المحامين والشركات القانونية التحديث المستمر لمعرفتهم بالقوانين والأنظمة الجديدة وتطوير مهاراتهم والاطلاع على أفضل الممارسات في المجال القانوني.

6. شراكات استراتيجية: العمل مع شركات أخرى ذات صلة بالمجال القانوني، مثل الشركات العقارية أو الشركات المالية، يمكن أن يوفر فرصًا للتوسع والوصول إلى قاعدة عملاء أكبر.

يرجى العلم أن الأساليب المذكورة أعلاه لا تتعلق مباشرة بالأنظمة السعودية، ولكنها أساليب عامة يمكن تطبيقها في أي سياق قانوني.
""",
"""الخدمات القانونية هي مجموعة من الأنشطة التي يقدمها المحامون أو المشورون القانونيون، وتتنوع لتشمل العديد من المجالات والمهام، مثل :

1. التمثيل القانوني: حيث يقوم المحامي بتمثيل العميل في المحاكم وأمام السلطات القانونية.
2. التشاور والإرشاد القانوني: تقديم المشورة القانونية للعملاء حول القضايا القانونية المعقدة.
3. صياغة العقود والاتفاقيات: تضمن الشروط القانونية المحددة والحقوق والواجبات لكل طرف.
4. التحقيق القانوني: بما في ذلك البحث والتحليل القانوني.
5. التحكيم والوساطة: التفاوض بين الأطراف لحل النزاعات بشكل ودي.
6. خدمات التنفيذ: بما في ذلك تنفيذ الأحكام القضائية والأوامر القانونية.
7. الخدمات المتعلقة بالملكية الفكرية: بما في ذلك تسجيل العلامات التجارية والبراءات وحقوق الطبع والنشر والأسرار التجارية.
8. خدمات الإفلاس والإعادة الهيكلية: بما في ذلك النصح بشأن الإفلاس وإجراءات الإفلاس.

في السياق السعودي، هذه الخدمات تتم بما يتوافق مع الأنظمة السعودية المختلفة، بما في ذلك نظام القضاء، نظام التنفيذ، نظام تركيز مسؤوليات القضاء الشرعي وغيرها من الأنظمة واللوائح ذات الصلة.
""",
"""من خلال السياق المقدم، لا يوجد نص ضمن النظام المحاماة السعودي ينص على أن مكتب المحاماة يجب أن يكون متخصصًا في قضايا معينة. بالإضافة إلى ذلك، يتضح من المادة الأولى من النظام أن مهنة المحاماة تشمل الترافع عن الغير أمام المحاكم وديوان المظالم، واللجان المشكلة بموجب الأنظمة والأوامر والقرارات لنظر القضايا الداخلة في اختصاصها، ومزاولة الاستشارات الشرعية والنظامية.

من هذا يمكن الاستنتاج أن المحامي أو مكتب المحاماة يمكن أن يكون متخصصاً في قضايا معينة بناءً على خبرته وتفضيلاته، ولكن النظام لا يفرض ذلك كشرط. يجب على المحامي أو مكتب المحاماة التقيد بالقواعد والأحكام الواردة في نظام المحاماة بغض النظر عن مجال اختصاصهم.

(المادة الأولى، الخامسة والخمسون من نظام المحاماة)""",
"""الخدمات القانونية المقدمة للأعمال والشركات تختلف بحسب السياق والنظام المرجعي. ولكن بناء على السياق المقدم، يمكننا التعرف على الخدمات التالية:

1. الاستعانة بالجهات العامة أو الخاصة: وفقاً للمادة الخامسة والسبعون بعد المائتين من نظام الشركات، يمكن للجهة المختصة الاستعانة بالجهات العامة أو الخاصة لأداء المهمات المقررة لها في النظام، وإسناد بعضها إلى تلك الجهات.

2. تنظيم مركز الإسناد والتصفية: وفقاً للمادة الثالثة من تنظيم مركز الإسناد والتصفية، يهدف المركز إلى تحقيق التعاون بين الجهات القضائية والحكومية فيما يسند إليه من مهمات تتعلق بالتصفية والبيع من خلال إسنادها إلى الجهات المتخصصة.

3. التحقيق والادعاء في الجرائم: وفقاً للمادة الخامسة والستين بعد المائتين من نظام الشركات، تختص النيابة العامة بالتحقيق والادعاء في الجرائم المنصوص عليها في النظام.

4. تحديد المقابل المالي للخدمات: وفقاً للمادة التاسعة والسبعون بعد المائتين من نظام الشركات، تحدد اللوائح المقابل المالي للخدمات المقدمة من الجهة المختصة تنفيذاً لأحكام النظام.

يمكن الرجوع إلى نصوص الأنظمة المذكورة لمزيد من التفاصيل حول هذه الخدمات.""",
"""فسخ النكاح في المملكة العربية السعودية يمكن أن يتم وفقًا لعدة طرق وأساليب، وهي كالتالي:

1. الخلع: يمكن للزوجين بتراضيهما وبعد الاتفاق على تفاصيل كاملة الإجراءات، أن ينهيا عقد الزواج دون الحاجة إلى حكم قضائي. هذا وفقًا للمادة 96 من نظام الأحوال الشخصية السعودي.

2. شروط الزوجين: يمكن للزوجين أيضًا أن يضعا شروطًا خاصة بهما لفسخ العقد، ويجب أن يكون هذا الشرط مكتوبًا في وثيقة العقد أو مقرو؋ا من الزوجين، وفقًا للمادة 27 من نظام الأحوال الشخصية.

3. الطلب القضائي: في بعض الحالات، يمكن للزوجة أن تطلب من المحكمة فسخ العقد. هذا يمكن أن يحدث إذا حلف الزوج على عدم جماعها لمدة تزيد على أربعة أشهر، أو إذا امتنع عن جماعها لمدة تزيد على أربعة أشهر بدون عذر مشروع. هذا يتم وفقًا للمادة 113 من نظام الأحوال الشخصية.

في كل الحالات، يجب تقديم وثائق مثل عقد الزواج ووثيقة الطلاق والأحكام المتعلقة بالمخالعات والتطليق إلى إحدى مكاتب الأحوال المدنية خلال شهرين من تاريخها لتسجيلها وختمها بخاتم الأحوال المدنية، وفقًا للمادة 46 من نظام الأحوال المدنية.
""",
"""الفرق بين الخلع وفسخ النكاح في النظام السعودي يتمثل في الأمور التالية:

1. الطلب: في الخلع، الزوجة هي التي تطلب الفراق وذلك مقابل عوض تقدمه للزوج كما يشير الى ذلك النظام السعودي في المادة 95 من نظام الأحوال الشخصية. أما في فسخ النكاح، يمكن لأي من الزوجين طلب الفسخ ولا يتطلب وجود عوض.

2. القرار: في الخلع، يجب موافقة الزوج على طلب الزوجة للخلع. بينما في فسخ النكاح، يمكن للقاضي أن يقرر الفسخ بناءً على الأدلة المقدمة.

3. الحاجة لحكم قضائي: في الخلع، لا يتطلب الأمر حكم قضائي إذا توافق الزوجين على الخلع وفقًا للمادة 96 من نظام الأحوال الشخصية. بينما في فسخ النكاح، يتطلب الأمر صدور حكم قضائي.

4. الحالة الصحية: في الخلع، يمكن للزوجة طلب الخلع في أي حالة كانت عليها، بما في ذلك حال حيضها، ونفاسها، والطهر الذي جامعها زوجها فيه كما هو مشار إليه في المادة 98 من نظام الأحوال الشخصية. أما في فسخ النكاح، فلا يوجد شروط محددة بخصوص حالة الزوجة.

5. العوض: في الخلع، يجب أن يكون هناك عوض من الزوجة أو غيرها مقابل الخلع كما هو مبين في المادة 99 من نظام الأحوال الشخصية. أما في فسخ النكاح، فلا يتطلب الأمر عوض.

وهذه الإجابة مستندة على نظام الأحوال الشخصية السعودي، المواد من 95 إلى 99.
""",
"""الطلاق في السعودية يتبع نظام الأحوال الشخصية الذي يحدد الخطوات اللازمة للطلاق. إليك الخطوات التي يجب اتباعها:

1. الرغبة في الطلاق: بناءً على المادة السابعة والسبعون من نظام الأحوال الشخصية، يمكن للزوج أن يعلن الطلاق، ولكن يجب أن يكون ذلك باللفظ الدال على الطلاق.

2. التوثيق: يجب على الزوج توثيق الطلاق أمام الجهة المختصة. هذا يتم وفقا للمادة التسعون من نظام الأحوال الشخصية، ويجب أن يتم خلال مدة أقصاها خمسة عشر يوما من حين البينونة.

3. الخلع: إذا كان الزوج لا يرغب في الطلاق، يمكن للزوجة طلب الخلع. وفقاً للمادة السادسة والتسعون من نظام الأحوال الشخصية، يمكن للزوجة طلب الخلع بتراضي الزوجين على إنهاء العقد، ولا يتطلب ذلك حكمًا قضائيًا.

4. استرداد الجنسية السعودية: إذا كانت الزوجة من النساء الأصيلات في المملكة العربية السعودية وتمت إزالة جنسيتها بسبب الزواج، يمكنها استرداد الجنسية السعودية بعد الطلاق. هذا وفقا للمادة رقم (5) من نظام الجنسية العربية السعودية.

يرجى مراجعة محامٍ للحصول على المشورة القانونية المناسبة قبل اتخاذ أي خطوات.""",
"""لا، الهيئة العمالية ليست مختصة بقضايا الهروب. حسب المادة الرابعة والثلاثون من نظام المرافعات الشرعية، فإن الهيئة العمالية تختص بالأمور التالية:

1. المنازعات المتعلقة بعقود العمل والأجور والحقوق وإصابات العمل والتعويض عنها.
2. المنازعات المتعلقة بفرض صاحب العمل الجزاءات التأديبية على العامل، أو المتعلقة بطلب الإعفاء منها.
3. الدعاوى المرفوعة لفرض العقوبات المنصوص عليها في نظام العمل.
4. المنازعات المترتبة على الفصل من العمل.
5. شكاوى أصحاب العمل والعمال الذين لم تقبل اعتراضاتهم ضد أي قرار صادر من أي جهاز مختص في المؤسسة العامة للتأمينات الاجتماعية، يتعلق بوجوب التسجيل والاشتراكات أو التعويضات.
6. المنازعات المتعلقة بالعمال الخاضعين لأحكام نظام العمل، بمن في ذلك عمال الحكومة.
7. المنازعات الناشئة عن تطبيق نظام العمل ونظام التأمينات الاجتماعية، دون الإخلال باختصاصات المحاكم الأخرى وديوان المظالم.

أما قضايا الهروب، فتتم معالجتها من قبل الجهات المختصة وفق الأنظمة والقوانين المعمول بها في المملكة العربية السعودية. وكما هو مذكور في المادة السادسة والعشرون من اللائحة التنظيمية لدور الأحداث، يجب على الدار إبلاغ الجهات المختصة فوراً عن حالات الهروب لإعادة الفرد إلى الدار.

وبناءً على السياق المقدم، ليس هناك أي ذكر خاص بالهروب في نطاق اختصاصات الهيئة العمالية.""",
"""نعم، بالإمكان رفع دعوى عمالية بعد توقيع المخالصة ولكن بشروط معينة وفقاً للأنظمة السعودية:

1. إذا كانت المخالصة تمت تحت الضغط أو بالإكراه، أو إذا كان العامل غير واعٍ لحقوقه أثناء توقيع المخالصة، يمكنه اللجوء إلى المحكمة لإبطالها.

2. إذا كانت المخالصة تحتوي على تنازلات غير قانونية أو مخالفة للأنظمة، فإنها تعتبر باطلة ويمكن للعامل التقدم بدعوى للحصول على حقوقه.

3. إذا تبين أنه تم التلاعب بالمخالصة أو الغش، فإن المحكمة يمكنها إبطالها والنظر في الدعوى العمالية.

بالإضافة إلى ذلك، يجب أن يكون العامل قد تقدم بدعواه خلال الفترة القانونية المحددة لذلك. وفقاً للمادة (28) من نظام العمل السعودي، يجب على العامل تقديم الدعوى خلال سنة من تاريخ توقيع المخالصة.

يجب الإشارة إلى أن القرار النهائي يعود للمحكمة بناءً على الأدلة والسياق.""",
"""نعم، بالإمكان المطالبة بحقوق العامل بعد نقل الكفالة. وفقًا للأنظمة السعودية، العامل يحتفظ بحقوقه النظامية حتى بعد نقل الكفالة. يتضمن هذا الحقوق المتعلقة بالأجر، الإجازات، التأمين الصحي، النقل، السكن وغيرها من الحقوق التي يقرها نظام العمل السعودي.

الجدير بالذكر أن العامل يحق له الاحتفاظ بحقوقه النظامية كلها والترك دون إشعار، في حال لم يقم صاحب العمل بالوفاء بالتزاماته العقدية أو النظامية الجوهرية أو في حالة الغش أو الاعتداء أو المعاملة الجائرة وغيرها من الحالات الواردة في المادة الحادية والثمانون من نظام العمل.

وبناءً على ذلك، يجب على صاحب العمل الجديد أن يحترم ويحافظ على حقوق العامل المنقولة وأن يلتزم بتوفير الشروط المحددة في العقد ونظام العمل.

مصدر الإجابة: نظام العمل السعودي، المادة الحادية والثمانون.""",
"""كخدمة قانونية، نحن لا نقدم خدمات الخبرة القضائية مباشرة. الخبرة القضائية هي عملية يقوم بها خبير معتمد في مجال معين لتقديم تقرير مفصل للمحكمة بشأن جوانب معينة من القضية التي يمكن أن تتطلب معرفة تقنية أو متخصصة.

وفقًا للمادة الحادية والخمسون من اللائحة التنفيذية لنظام الإجراءات الجزائية في المملكة العربية السعودية، يتم توضيح متطلبات ومهام الخبير في القضايا القضائية. تتضمن هذه المهام تقديم تقرير مفصل عن العمل الذي تم إنجازه، والإجراءات التي تم اتخاذها، والنتائج التي توصل إليها الخبير. إذا كان هناك خلاف بين الخبراء، يجب عليهم تقديم تقرير واحد يتضمن رأي كل خبير والأسباب التي أدت إلى هذا الرأي. ويشمل النظام أيضًا الحقوق والمسؤوليات الأخرى للخبير.

لذا، من الأفضل التواصل مع مكتب خبراء قانوني معتمد إذا كنت بحاجة إلى خدمات الخبرة القضائية.
""",
"""القضايا الجنائية في المملكة العربية السعودية هي القضايا التي تتعلق بالجرائم ضد الأشخاص أو الممتلكات أو الدولة، وهي تخضع لقوانين وأنظمة محددة. القضايا الجنائية تشمل:

1. جرائم القتل والاعتداء الجسدي: تعتبر هذه الجرائم من أكثر الجرائم خطورة وتعاقب عليها بشدة.

2. جرائم السرقة: تتعلق بالاستيلاء على ممتلكات الآخرين بدون إذن.

3. جرائم الاحتيال والغش: تشمل الأعمال التي تهدف إلى الحصول على مال أو ممتلكات من الآخرين بطرق غير شرعية.

4. جرائم الاتجار بالمخدرات: تتعلق بالتعامل بالمواد المخدرة بأي شكل من الأشكال.

5. جرائم الإرهاب: تشمل الأعمال التي تهدف إلى نشر الرعب والخوف بين الناس أو تعريض أمن الدولة للخطر.

6. جرائم الاعتداء على الأملاك العامة: تشمل الأعمال التي تتسبب في تدمير أو تلف الأملاك التابعة للدولة.

7. جرائم الاعتداء على السعوديين في الخارج: تشمل الأعمال التي تهدف إلى الاعتداء على المواطنين السعوديين خارج البلاد.

8. جرائم قانون العمل: تشمل مخالفات قانون العمل مثل الإتاوات، الاحتكار وغيرها.

ويمكن الرجوع للتفاصيل الكاملة في نظام مكافحة جرائم الإرهاب وتمويله- المادة الثالثة، ونظام تركيز مسؤوليات القضاء الشرعي- المادة (82) و(84) ونظام المرافعات الشرعية- المادة السادسة والعشرون.
""",
"""
صياغة العقد تتم وفقاً للأنظمة السعودية وذلك بالتأكيد على النقاط التالية:

1. يجب أن يتم تنفيذ العقد طبقاً لما اشتمل عليه وبطريقة تتفق مع ما يوجبه حسن النية، كما هو موضح في المادة الخامسة والتسعون من نظام المعاملات المدنية.

2. يجب أن يشمل العقد بنود محددة وواضحة، مثل تحديد المسؤوليات الفنية والمالية، ميزانية البحث، اسم الباحث الرئيس والباحثين المشاركين، حقوق النشر، تحديد موعد بدء العمل في البحث ومدته، الجدول الزمني للبحث، الية ايقاف البحث أو التخلي عنه، الية حل الخلاف بين الطرفين. كما هو موضح في المادة الحادية عشرة من لائحة البحوث والدراسات في وزارة الصحة.

3. يجب على المتعاقدين الوفاء بما أوجبه العقد عليهما، حيث لا يجوز نقضه أو تعديله إلا بالاتفاق أو بمقتضى نص نظامي، كما هو موضح في المادة الرابعة والتسعون من نظام المعاملات المدنية.

4. يجب أن تصاغ العقود ووثائقها وملحقاتها باللغة العربية، ويجوز استخدام لغة أخرى إلى جانب العربية على أن تكون العربية هي المعتمدة في تفسير العقد وتنفيذه وتحديد مواصفاته ومخططاته والمراسلات المتعلقة به. كما هو موضح في المادة الخامسة والخمسون من نظام المنافسات والمشتريات الحكومية.

وفي الأخير، يجب أن تتم صياغة العقد بطريقة واضحة وشاملة وواقعية ومتفقة مع الأنظمة والعرف وطبيعة العقد.""",
"""إجراءات التصفية تختلف بحسب النظام الذي يتم تطبيقه، ولكن بشكل عام، يمكن تلخيصها في النقاط التالية:

1. تحديد طريقة تصفية المؤسسة واختيار مصفي لها، وتنتهي عند ذلك مهمة مجلس الإدارة والمدير العام.
2. توقف أعمال المؤسسة عدا ما يلزم لتنفيذ إجراءات التصفية.
3. تتم أعمال التصفية باشراف المصفي وعلى مسؤوليته باعتباره ممثلا للمالكين، وتحت رقابة الوزارة.
4. يدعو الوزارة الجمعية العمومية للانعقاد لإقرار نتائج التصفية.

وفي حالة التصفية وفقاً لنظام الإفلاس، فإنه يتم إجراءات مشابهة لكنها تتضمن أيضاً:

1. بيع أصول التصفية وتوزيع حصيلتها على الدائنين.
2. تقدم الأمين بطلب إنهاء الإجراء إذا لم تكن حصيلة بيع الأصول كافية للوفاء بمصروفات التصفية، أو إذا اكتملت أعمال التصفية.
3. تقضي المحكمة بإنهاء الإجراء وبحل المدين إذا كان شخصاً ذا صفة اعتبارية.

هذا وفقًا للمادة الخامسة والعشرون من نظام المؤسسات الصحفية، والمادة الثانية والعشرون بعد المائة، والمادة التسعون، والمادة الستون بعد المائة من نظام الإفلاس.
""",



],

}

dataset = Dataset.from_dict(data)

# %%
# !pip install -q openai pandas tqdm

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %% [markdown]
# INTERFACE

# %%
# !pip install -U chainlit
# !pip install pyngrok

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
mkdir -p .chainlit

# %%
# %%writefile app.py
import os
import chainlit as cl
from openai import OpenAI
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

print("✅ app.py loaded")


embeddings = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large")
print("✅ Embedding model loaded")


try:
    db = FAISS.load_local(
        folder_path="New",
        embeddings=embeddings,
        allow_dangerous_deserialization=True
    )
    print("✅ FAISS loaded successfully")
except Exception as e:
    print("❌ Error loading FAISS:", e)
    db = None


client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))


@cl.on_chat_start
async def start():
    await cl.Message(
        content=(
            " **مرحبًا بك في المساعد القانوني الذكي راجح!**\n\n"
            " اسألني أي سؤال عن الأنظمة السعودية.\n"
            " أمثلة:\n"
            "- ما هي حالات الفصل النظامية؟\n"
            "- ما مدة الإجازة السنوية؟\n"
            "- ما نص المادة 80؟\n"
            "- ما مخالفة المادة 37؟"
        )
    ).send()


@cl.on_message
async def main(message: cl.Message):
    user_question = message.content.strip()

    if db is None:
        await cl.Message(content="❌ قاعدة البيانات غير محملة.").send()
        return

    try:
        retrieved_docs = db.similarity_search(user_question, k=4)
        context = "\n\n".join([doc.page_content for doc in retrieved_docs])
    except Exception as e:
        await cl.Message(content=f"❌ خطأ أثناء الاسترجاع:\n{e}").send()
        return

    prompt = f"""أنت مساعد قانوني متخصص في الأنظمة السعودية، وتقوم بالإجابة على أسئلة المستخدمين بناءً على السياق المقدم. أجب على السؤال التالي بطريقة شاملة وواضحة ومبسطة، دون الإخلال بالمعلومة، مع استخدام التعداد عند الحاجة لتوضيح النقاط. في نهاية الإجابة، اذكر اسم النظام ورقم المادة التي تم الاستناد إليها.

    إذا لم تجد المعلومة قل: (المعلومة غير موجودة في قاعدة البيانات).

    ✅ **السياق:**
    {context}

    ❓ **السؤال:**
    {user_question}
    """

    try:
        response = client.chat.completions.create(
            model="gpt-4",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.3
        )
        answer = response.choices[0].message.content
        await cl.Message(content=answer).send()

    except Exception as e:
        await cl.Message(content=f"❌ خطأ في توليد الإجابة:\n{e}").send()

# %%
mkdir -p .chainlit public

# %%
cp /content/RAJEH.png public/logo_dark.png

# %%
ls public

# %%
# %%writefile public/theme.json
# {
#   "custom_fonts": [],
#   "variables": {
#     "dark": {
#       "--background": "0 0% 10%",
#       "--foreground": "0 0% 93%",
#       "--primary": "220 70% 60%",
#       "--secondary": "210 40% 70%",
#       "--accent": "210 50% 45%"
#     }
#   },
#   "logo_url": "/public/logo_dark.png",
#   "title": "⚖️ راجِـح - المساعد القانوني الذكي",
#   "description": "منصة ذكية للاستشارات القانونية المبنية على الأنظمة السعودية"
# }

# %%
# %%writefile .chainlit/config.yaml
# project:
#   name: "⚖️ المساعد القانوني الذكي - راجِـح"
#   description: "منصة ذكية للاستشارات القانونية المبنية على الأنظمة السعودية"
#   language: "ar"
#
# ui:
#   default_theme: "dark"
#   font_family: "Tajawal, 'Noto Kufi Arabic', sans-serif"
#
# branding:
#   app_title: "⚖️ راجِـح"
#   app_logo: "public/logo_dark.png"
#   favicon: "public/logo_dark.png"
#   footer_text: "© 2025 راجِـح - جميع الحقوق محفوظة"

# %%
# !ls /content

# %%
# !pkill -f chainlit || True
# !pkill -f uvicorn || True
# !pkill -f ngrok || True

# %%
# !chainlit run app.py --no-cache --port 8000

# %%
import threading
import subprocess

def run_chainlit():
    subprocess.run(["chainlit", "run", "app.py", "--port", "8000", "--no-cache"])

thread = threading.Thread(target=run_chainlit)
thread.start()

# %%
# !ngrok config add-authtoken "33mTSzrR5CYO3OusnCbKqEfi8Ut_H7WNLRwxkusCWvN5cQAP"
from pyngrok import ngrok

ngrok.kill()
public_url = ngrok.connect(8000)
public_url
